# %% [markdown]
# # Object Detection Demo
# Welcome to the object detection inference walkthrough!  This notebook will walk you step by step through the process of using a pre-trained model to detect objects in an image. Make sure to follow the [installation instructions](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/installation.md) before you start.

# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("../../lib")
from object_detection.utils import ops as utils_ops

if tf.__version__ < '1.4.0':
  raise ImportError('Please upgrade your tensorflow installation to v1.4.* or later!')

# %%
import pickle
import cv2
import csv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %% [markdown]
# ## Env setup

# %%
# This is needed to display the images.
# %matplotlib inline

# %% [markdown]
# ## Object detection imports
# Here are the imports from the object detection module.

# %%
from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util
# Out:
# ../../lib/object_detection/utils/visualization_utils.py:25: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2909, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-0f0a85121700>", line 2, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3051, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   import matplotlib; matplotlib.use('Agg')  # pylint: disable=multiple-statements

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Variables
#
# Any model exported using the `export_inference_graph.py` tool can be loaded here simply by changing `PATH_TO_CKPT` to point to a new .pb file.
#
# By default we use an "SSD with Mobilenet" model here. See the [detection model zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md) for a list of other models that can be run out-of-the-box with varying speeds and accuracies.

# %%
# What model to download.
MODEL_NAME = '../../checkpoints/faster_rcnn_inception_resnet_v2_atrous_oid'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('../../lib/object_detection/data', 'oid_bbox_trainable_label_map.pbtxt')

NUM_CLASSES = 600

# %% [markdown]
# ## Load a (frozen) Tensorflow model into memory.

# %%
od_graph_def = tf.GraphDef()
with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# %% [markdown]
# ## Loading label map
# Label maps map indices to category names, so that when our convolution network predicts `5`, we know that this corresponds to `airplane`.  Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine

# %%
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %% [markdown]
# ## Helper code

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Data Preparation

# %%
keyframe_vid_id_to_seedling_vid_id = {}
seedling_vid_id_to_keyframe_vid_id = {}
keyframe_img_filename_to_seedling_img_id = {}
seedling_img_id_to_keyframe_img_filename = {}

with open('../../../../data/eval_m9/msb.txt', 'r') as fin:
    for line in fin:
        row = line.split()

        keyframe_vid_id = row[0]
        seedling_vid_id = row[1].split('_')[0]
        
        keyframe_vid_id_to_seedling_vid_id[keyframe_vid_id] = seedling_vid_id
        seedling_vid_id_to_keyframe_vid_id[seedling_vid_id] = keyframe_vid_id
        
        seedling_img_id = row[1]
        keyframe_img_filename = row[0] + '_' + seedling_img_id.split('_')[-1] + '.png'
        
        keyframe_img_filename_to_seedling_img_id[keyframe_img_filename] = seedling_img_id
        seedling_img_id_to_keyframe_img_filename[seedling_img_id] = keyframe_img_filename

# %%
with open('../../../../data/eval_m9/keyframes.txt', 'r') as fin:
    test_img_subpaths = [line.strip() for line in fin]

# %%
seedling_img_id_to_keyframe_img_path = {}
for i, item in enumerate(test_img_subpaths):
    keyframe_img_filename = item.split('/')[-1]
    if keyframe_img_filename in keyframe_img_filename_to_seedling_img_id:
        seedling_img_id_to_keyframe_img_path[keyframe_img_filename_to_seedling_img_id[keyframe_img_filename]] = item

# %% [markdown]
# # Detection

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
def run_inference_for_single_image(image):
  # Get handles to input and output tensors
  ops = tf.get_default_graph().get_operations()
  all_tensor_names = {output.name for op in ops for output in op.outputs}
  tensor_dict = {}
  for key in [
      'num_detections', 'detection_boxes', 'detection_scores',
      'detection_classes', 'detection_masks'
  ]:
    tensor_name = key + ':0'
    if tensor_name in all_tensor_names:
      tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
          tensor_name)
  if 'detection_masks' in tensor_dict:
    # The following processing is only for single image
    detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
    detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
    # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
    real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
    detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
    detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
    detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
        detection_masks, detection_boxes, image.shape[0], image.shape[1])
    detection_masks_reframed = tf.cast(
        tf.greater(detection_masks_reframed, 0.5), tf.uint8)
    # Follow the convention by adding back the batch dimension
    tensor_dict['detection_masks'] = tf.expand_dims(
        detection_masks_reframed, 0)
  image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

  # Run inference
  output_dict = sess.run(tensor_dict,
                         feed_dict={image_tensor: np.expand_dims(image, 0)})

  # all outputs are float32 numpy arrays, so convert types as appropriate
  output_dict['num_detections'] = int(output_dict['num_detections'][0])
  output_dict['detection_classes'] = output_dict[
      'detection_classes'][0].astype(np.uint8)
  output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
  output_dict['detection_scores'] = output_dict['detection_scores'][0]
  if 'detection_masks' in output_dict:
        output_dict['detection_masks'] = output_dict['detection_masks'][0]
  return output_dict

# %%
det_results = {}
image_shape = {}
num_imgs = len(seedling_img_id_to_keyframe_img_path)
for i, imgid in enumerate(seedling_img_id_to_keyframe_img_path):
    imgpath = '../../../../data/eval_m9/keyframes/' + seedling_img_id_to_keyframe_img_path[imgid]
    try:
        with open(imgpath, 'rb') as fin:
            #_ = fin.read(1024)
            imgbin = fin.read()
        imgbgr = cv2.imdecode(np.fromstring(imgbin, dtype='uint8'), cv2.IMREAD_COLOR)
        image_np = imgbgr[:,:,[2,1,0]]
        image_shape[imgid] = (image_np.shape[1], image_np.shape[0])
    except Exception as ex:
        print(filename)
        print(ex)
        continue
    
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np)
    
    det_results[imgid] = output_dict
    
    if i % 100 == 0:
        print(f'{i} images processed out of {num_imgs}.')
# Out:
# /home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/__main__.py:10: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
# 0 images processed out of 78893.
# 100 images processed out of 78893.
# 200 images processed out of 78893.
# 300 images processed out of 78893.
# 400 images processed out of 78893.
# 500 images processed out of 78893.
# 600 images processed out of 78893.
# 700 images processed out of 78893.
# 800 images processed out of 78893.
# 900 images processed out of 78893.
# 1000 images processed out of 78893.
# 1100 images processed out of 78893.
# 1200 images processed out of 78893.
# 1300 images processed out of 78893.
# 1400 images processed out of 78893.
# 1500 images processed out of 78893.
# 1600 images processed out of 78893.
# 1700 images processed out of 78893.
# 1800 images processed out of 78893.
# 1900 images processed out of 78893.
# 2000 images processed out of 78893.
# 2100 images processed out of 78893.
# 2200 images processed out of 78893.
# 2300 images processed out of 78893.
# 2400 images processed out of 78893.
# 2500 images processed out of 78893.
# 2600 images processed out of 78893.
# 2700 images processed out of 78893.
# 2800 images processed out of 78893.
# 2900 images processed out of 78893.
# 3000 images processed out of 78893.
# 3100 images processed out of 78893.
# 3200 images processed out of 78893.
# 3300 images processed out of 78893.
# 3400 images processed out of 78893.
# 3500 images processed out of 78893.
# 3600 images processed out of 78893.
# 3700 images processed out of 78893.
# 3800 images processed out of 78893.
# 3900 images processed out of 78893.
# 4000 images processed out of 78893.
# 4100 images processed out of 78893.
# 4200 images processed out of 78893.
# 4300 images processed out of 78893.
# 4400 images processed out of 78893.
# 4500 images processed out of 78893.
# 4600 images processed out of 78893.
# 4700 images processed out of 78893.
# 4800 images processed out of 78893.
# 4900 images processed out of 78893.
# 5000 images processed out of 78893.
# 5100 images processed out of 78893.
# 5200 images processed out of 78893.
# 5300 images processed out of 78893.
# 5400 images processed out of 78893.
# 5500 images processed out of 78893.
# 5600 images processed out of 78893.
# 5700 images processed out of 78893.
# 5800 images processed out of 78893.
# 6000 images processed out of 78893.
# 6100 images processed out of 78893.
# 6200 images processed out of 78893.
# 6300 images processed out of 78893.
# 6400 images processed out of 78893.
# 6500 images processed out of 78893.
# 6600 images processed out of 78893.
# 6700 images processed out of 78893.
# 6800 images processed out of 78893.
# 6900 images processed out of 78893.
# 7000 images processed out of 78893.
# 7100 images processed out of 78893.
# 7200 images processed out of 78893.
# 7300 images processed out of 78893.
# 7400 images processed out of 78893.
# 7500 images processed out of 78893.
# 7600 images processed out of 78893.
# 7700 images processed out of 78893.
# 7800 images processed out of 78893.
# 7900 images processed out of 78893.
# 8000 images processed out of 78893.
# 8100 images processed out of 78893.
# 8200 images processed out of 78893.
# 8300 images processed out of 78893.
# 8400 images processed out of 78893.
# 8500 images processed out of 78893.
# 8600 images processed out of 78893.
# 8700 images processed out of 78893.
# 8800 images processed out of 78893.
# 8900 images processed out of 78893.
# 9000 images processed out of 78893.
# 9100 images processed out of 78893.
# 9200 images processed out of 78893.
# 9300 images processed out of 78893.
# 9400 images processed out of 78893.
# 9500 images processed out of 78893.
# 9600 images processed out of 78893.
# 9700 images processed out of 78893.
# 9800 images processed out of 78893.
# 9900 images processed out of 78893.
# 10000 images processed out of 78893.
# 10100 images processed out of 78893.
# 10200 images processed out of 78893.
# 10300 images processed out of 78893.
# 10400 images processed out of 78893.
# 10500 images processed out of 78893.
# 10600 images processed out of 78893.
# 10700 images processed out of 78893.
# 10800 images processed out of 78893.
# 10900 images processed out of 78893.
# 11000 images processed out of 78893.
# 11100 images processed out of 78893.
# 11200 images processed out of 78893.
# 11300 images processed out of 78893.
# 11400 images processed out of 78893.
# 11500 images processed out of 78893.
# 11600 images processed out of 78893.
# 11700 images processed out of 78893.
# 11800 images processed out of 78893.
# 11900 images processed out of 78893.
# 12000 images processed out of 78893.
# 12100 images processed out of 78893.
# 12200 images processed out of 78893.
# 12300 images processed out of 78893.
# 12400 images processed out of 78893.
# 12500 images processed out of 78893.
# 12600 images processed out of 78893.
# 12700 images processed out of 78893.
# 12800 images processed out of 78893.
# 12900 images processed out of 78893.
# 13000 images processed out of 78893.
# 13100 images processed out of 78893.
# 13200 images processed out of 78893.
# 13300 images processed out of 78893.
# 13400 images processed out of 78893.
# 13500 images processed out of 78893.
# 13600 images processed out of 78893.
# 13700 images processed out of 78893.
# 13800 images processed out of 78893.
# 13900 images processed out of 78893.
# 14000 images processed out of 78893.
# 14100 images processed out of 78893.
# 14200 images processed out of 78893.
# 14300 images processed out of 78893.
# 14400 images processed out of 78893.
# 14500 images processed out of 78893.
# 14600 images processed out of 78893.
# 14700 images processed out of 78893.
# 14800 images processed out of 78893.
# 14900 images processed out of 78893.
# 15000 images processed out of 78893.
# 15100 images processed out of 78893.
# 15200 images processed out of 78893.
# 15300 images processed out of 78893.
# 15400 images processed out of 78893.
# 15500 images processed out of 78893.
# 15600 images processed out of 78893.
# 15700 images processed out of 78893.
# 15800 images processed out of 78893.
# 15900 images processed out of 78893.
# 16000 images processed out of 78893.
# 16100 images processed out of 78893.
# 16200 images processed out of 78893.
# 16300 images processed out of 78893.
# 16400 images processed out of 78893.
# 16500 images processed out of 78893.
# 16600 images processed out of 78893.
# 16700 images processed out of 78893.
# 16800 images processed out of 78893.
# 16900 images processed out of 78893.
# 17000 images processed out of 78893.
# 17100 images processed out of 78893.
# 17200 images processed out of 78893.
# 17300 images processed out of 78893.
# 17400 images processed out of 78893.
# 17500 images processed out of 78893.
# 17600 images processed out of 78893.
# 17700 images processed out of 78893.
# 17800 images processed out of 78893.
# 17900 images processed out of 78893.
# 18000 images processed out of 78893.
# 18100 images processed out of 78893.
# 18200 images processed out of 78893.
# 18300 images processed out of 78893.
# 18400 images processed out of 78893.
# 18500 images processed out of 78893.
# 18600 images processed out of 78893.
# 18700 images processed out of 78893.
# 18800 images processed out of 78893.
# 18900 images processed out of 78893.
# 19000 images processed out of 78893.
# 19100 images processed out of 78893.
# 19200 images processed out of 78893.
# 19300 images processed out of 78893.
# 19400 images processed out of 78893.
# 19500 images processed out of 78893.
# 19600 images processed out of 78893.
# 19700 images processed out of 78893.
# 19800 images processed out of 78893.
# 19900 images processed out of 78893.
# 20000 images processed out of 78893.
# 20100 images processed out of 78893.
# 20200 images processed out of 78893.
# 20300 images processed out of 78893.
# 20400 images processed out of 78893.
# 20500 images processed out of 78893.
# 20600 images processed out of 78893.
# 20700 images processed out of 78893.
# 20800 images processed out of 78893.
# 20900 images processed out of 78893.
# 21000 images processed out of 78893.
# 21100 images processed out of 78893.
# 21200 images processed out of 78893.
# 21300 images processed out of 78893.
# 21400 images processed out of 78893.
# 21500 images processed out of 78893.
# 21600 images processed out of 78893.
# 21700 images processed out of 78893.
# 21800 images processed out of 78893.
# 21900 images processed out of 78893.
# 22000 images processed out of 78893.
# 22100 images processed out of 78893.
# 22200 images processed out of 78893.
# 22300 images processed out of 78893.
# 22400 images processed out of 78893.
# 22500 images processed out of 78893.
# 22600 images processed out of 78893.
# 22700 images processed out of 78893.
# 22800 images processed out of 78893.
# 22900 images processed out of 78893.
# 23000 images processed out of 78893.
# 23100 images processed out of 78893.
# 23200 images processed out of 78893.
# 23300 images processed out of 78893.
# 23400 images processed out of 78893.
# 23500 images processed out of 78893.
# 23600 images processed out of 78893.
# 23700 images processed out of 78893.
# 23800 images processed out of 78893.
# 23900 images processed out of 78893.
# 24000 images processed out of 78893.
# 24100 images processed out of 78893.
# 24200 images processed out of 78893.
# 24300 images processed out of 78893.
# 24400 images processed out of 78893.
# 24500 images processed out of 78893.
# 24600 images processed out of 78893.
# 24700 images processed out of 78893.
# 24800 images processed out of 78893.
# 24900 images processed out of 78893.
# 25000 images processed out of 78893.
# 25100 images processed out of 78893.
# 25200 images processed out of 78893.
# 25300 images processed out of 78893.
# 25400 images processed out of 78893.
# 25500 images processed out of 78893.
# 25600 images processed out of 78893.
# 25700 images processed out of 78893.
# 25800 images processed out of 78893.
# 25900 images processed out of 78893.
# 26000 images processed out of 78893.
# 26100 images processed out of 78893.
# 26200 images processed out of 78893.
# 26300 images processed out of 78893.
# 26400 images processed out of 78893.
# 26500 images processed out of 78893.
# 26600 images processed out of 78893.
# 26700 images processed out of 78893.
# 26800 images processed out of 78893.
# 26900 images processed out of 78893.
# 27000 images processed out of 78893.
# 27100 images processed out of 78893.
# 27200 images processed out of 78893.
# 27300 images processed out of 78893.
# 27400 images processed out of 78893.
# 27500 images processed out of 78893.
# 27600 images processed out of 78893.
# 27700 images processed out of 78893.
# 27800 images processed out of 78893.
# 27900 images processed out of 78893.
# 28000 images processed out of 78893.
# 28100 images processed out of 78893.
# 28200 images processed out of 78893.
# 28300 images processed out of 78893.
# 28400 images processed out of 78893.
# 28500 images processed out of 78893.
# 28600 images processed out of 78893.
# 28700 images processed out of 78893.
# 28800 images processed out of 78893.
# 28900 images processed out of 78893.
# 29000 images processed out of 78893.
# 29100 images processed out of 78893.
# 29200 images processed out of 78893.
# 29300 images processed out of 78893.
# 29400 images processed out of 78893.
# 29500 images processed out of 78893.
# 29600 images processed out of 78893.
# 29700 images processed out of 78893.
# 29800 images processed out of 78893.
# 29900 images processed out of 78893.
# 30000 images processed out of 78893.
# 30100 images processed out of 78893.
# 30200 images processed out of 78893.
# 30300 images processed out of 78893.
# 30400 images processed out of 78893.
# 30500 images processed out of 78893.
# 30600 images processed out of 78893.
# 30700 images processed out of 78893.
# 30800 images processed out of 78893.
# 30900 images processed out of 78893.
# 31000 images processed out of 78893.
# 31100 images processed out of 78893.
# 31200 images processed out of 78893.
# 31300 images processed out of 78893.
# 31400 images processed out of 78893.
# 31500 images processed out of 78893.
# 31600 images processed out of 78893.
# 31700 images processed out of 78893.
# 31800 images processed out of 78893.
# 31900 images processed out of 78893.
# 32100 images processed out of 78893.
# 32200 images processed out of 78893.
# 32300 images processed out of 78893.
# 32400 images processed out of 78893.
# 32500 images processed out of 78893.
# 32600 images processed out of 78893.
# 32700 images processed out of 78893.
# 32800 images processed out of 78893.
# 32900 images processed out of 78893.
# 33000 images processed out of 78893.
# 33100 images processed out of 78893.
# 33200 images processed out of 78893.
# 33300 images processed out of 78893.
# 33400 images processed out of 78893.
# 33500 images processed out of 78893.
# 33600 images processed out of 78893.
# 33700 images processed out of 78893.
# 33800 images processed out of 78893.
# 33900 images processed out of 78893.
# 34000 images processed out of 78893.
# 34100 images processed out of 78893.
# 34200 images processed out of 78893.
# 34300 images processed out of 78893.
# 34400 images processed out of 78893.
# 34500 images processed out of 78893.
# 34600 images processed out of 78893.
# 34700 images processed out of 78893.
# 34800 images processed out of 78893.
# 34900 images processed out of 78893.
# 35000 images processed out of 78893.
# 35100 images processed out of 78893.
# 35200 images processed out of 78893.
# 35300 images processed out of 78893.
# 35400 images processed out of 78893.
# 35500 images processed out of 78893.
# 35600 images processed out of 78893.
# 35700 images processed out of 78893.
# 35800 images processed out of 78893.
# 35900 images processed out of 78893.
# 36000 images processed out of 78893.
# 36100 images processed out of 78893.
# 36200 images processed out of 78893.
# 36300 images processed out of 78893.
# 36400 images processed out of 78893.
# 36500 images processed out of 78893.
# 36600 images processed out of 78893.
# 36700 images processed out of 78893.
# 36800 images processed out of 78893.
# 36900 images processed out of 78893.
# 37000 images processed out of 78893.
# 37100 images processed out of 78893.
# 37200 images processed out of 78893.
# 37300 images processed out of 78893.
# 37400 images processed out of 78893.
# 37500 images processed out of 78893.
# 37600 images processed out of 78893.
# 37700 images processed out of 78893.
# 37800 images processed out of 78893.
# 37900 images processed out of 78893.
# 38000 images processed out of 78893.
# 38100 images processed out of 78893.
# 38200 images processed out of 78893.
# 38300 images processed out of 78893.
# 38400 images processed out of 78893.
# 38500 images processed out of 78893.
# 38600 images processed out of 78893.
# 38700 images processed out of 78893.
# 38800 images processed out of 78893.
# 38900 images processed out of 78893.
# 39000 images processed out of 78893.
# 39100 images processed out of 78893.
# 39200 images processed out of 78893.
# 39300 images processed out of 78893.
# 39400 images processed out of 78893.
# 39500 images processed out of 78893.
# 39600 images processed out of 78893.
# 39700 images processed out of 78893.
# 39800 images processed out of 78893.
# 39900 images processed out of 78893.
# 40000 images processed out of 78893.
# 40100 images processed out of 78893.
# 40200 images processed out of 78893.
# 40300 images processed out of 78893.
# 40400 images processed out of 78893.
# 40500 images processed out of 78893.
# 40600 images processed out of 78893.
# 40700 images processed out of 78893.
# 40800 images processed out of 78893.
# 40900 images processed out of 78893.
# 41000 images processed out of 78893.
# 41100 images processed out of 78893.
# 41200 images processed out of 78893.
# 41300 images processed out of 78893.
# 41400 images processed out of 78893.
# 41500 images processed out of 78893.
# 41600 images processed out of 78893.
# 41700 images processed out of 78893.
# 41800 images processed out of 78893.
# 41900 images processed out of 78893.
# 42000 images processed out of 78893.
# 42100 images processed out of 78893.
# 42200 images processed out of 78893.
# 42300 images processed out of 78893.
# 42400 images processed out of 78893.
# 42500 images processed out of 78893.
# 42600 images processed out of 78893.
# 42700 images processed out of 78893.
# 42800 images processed out of 78893.
# 42900 images processed out of 78893.
# 43000 images processed out of 78893.
# 43100 images processed out of 78893.
# 43200 images processed out of 78893.
# 43300 images processed out of 78893.
# 43400 images processed out of 78893.
# 43500 images processed out of 78893.
# 43600 images processed out of 78893.
# 43700 images processed out of 78893.
# 43800 images processed out of 78893.
# 43900 images processed out of 78893.
# 44000 images processed out of 78893.
# 44100 images processed out of 78893.
# 44200 images processed out of 78893.
# 44300 images processed out of 78893.
# 44400 images processed out of 78893.
# 44500 images processed out of 78893.
# 44600 images processed out of 78893.
# 44700 images processed out of 78893.
# 44800 images processed out of 78893.
# 44900 images processed out of 78893.
# 45000 images processed out of 78893.
# 45100 images processed out of 78893.
# 45200 images processed out of 78893.
# 45300 images processed out of 78893.
# 45400 images processed out of 78893.
# 45500 images processed out of 78893.
# 45600 images processed out of 78893.
# 45700 images processed out of 78893.
# 45800 images processed out of 78893.
# 45900 images processed out of 78893.
# 46000 images processed out of 78893.
# 46100 images processed out of 78893.
# 46200 images processed out of 78893.
# 46300 images processed out of 78893.
# 46400 images processed out of 78893.
# 46500 images processed out of 78893.
# 46600 images processed out of 78893.
# 46700 images processed out of 78893.
# 46800 images processed out of 78893.
# 46900 images processed out of 78893.
# 47000 images processed out of 78893.
# 47100 images processed out of 78893.
# 47200 images processed out of 78893.
# 47300 images processed out of 78893.
# 47400 images processed out of 78893.
# 47500 images processed out of 78893.
# 47600 images processed out of 78893.
# 47700 images processed out of 78893.
# 47800 images processed out of 78893.
# 47900 images processed out of 78893.
# 48000 images processed out of 78893.
# 48100 images processed out of 78893.
# 48200 images processed out of 78893.
# 48300 images processed out of 78893.
# 48400 images processed out of 78893.
# 48500 images processed out of 78893.
# 48600 images processed out of 78893.
# 48700 images processed out of 78893.
# 48800 images processed out of 78893.
# 48900 images processed out of 78893.
# 49000 images processed out of 78893.
# 49100 images processed out of 78893.
# 49200 images processed out of 78893.
# 49300 images processed out of 78893.
# 49400 images processed out of 78893.
# 49500 images processed out of 78893.
# 49600 images processed out of 78893.
# 49700 images processed out of 78893.
# 49800 images processed out of 78893.
# 49900 images processed out of 78893.
# 50000 images processed out of 78893.
# 50100 images processed out of 78893.
# 50200 images processed out of 78893.
# 50300 images processed out of 78893.
# 50400 images processed out of 78893.
# 50500 images processed out of 78893.
# 50600 images processed out of 78893.
# 50700 images processed out of 78893.
# 50800 images processed out of 78893.
# 50900 images processed out of 78893.
# 51000 images processed out of 78893.
# 51100 images processed out of 78893.
# 51200 images processed out of 78893.
# 51300 images processed out of 78893.
# 51400 images processed out of 78893.
# 51500 images processed out of 78893.
# 51600 images processed out of 78893.
# 51700 images processed out of 78893.
# 51800 images processed out of 78893.
# 51900 images processed out of 78893.
# 52000 images processed out of 78893.
# 52100 images processed out of 78893.
# 52200 images processed out of 78893.
# 52300 images processed out of 78893.
# 52400 images processed out of 78893.
# 52500 images processed out of 78893.
# 52600 images processed out of 78893.
# 52700 images processed out of 78893.
# 52800 images processed out of 78893.
# 52900 images processed out of 78893.
# 53000 images processed out of 78893.
# 53100 images processed out of 78893.
# 53200 images processed out of 78893.
# 53300 images processed out of 78893.
# 53400 images processed out of 78893.
# 53500 images processed out of 78893.
# 53600 images processed out of 78893.
# 53700 images processed out of 78893.
# 53800 images processed out of 78893.
# 53900 images processed out of 78893.
# 54000 images processed out of 78893.
# 54100 images processed out of 78893.
# 54200 images processed out of 78893.
# 54300 images processed out of 78893.
# 54400 images processed out of 78893.
# 54500 images processed out of 78893.
# 54600 images processed out of 78893.
# 54700 images processed out of 78893.
# 54800 images processed out of 78893.
# 54900 images processed out of 78893.
# 55000 images processed out of 78893.
# 55100 images processed out of 78893.
# 55200 images processed out of 78893.
# 55300 images processed out of 78893.
# 55400 images processed out of 78893.
# 55500 images processed out of 78893.
# 55600 images processed out of 78893.
# 55700 images processed out of 78893.
# 55800 images processed out of 78893.
# 55900 images processed out of 78893.
# 56000 images processed out of 78893.
# 56100 images processed out of 78893.
# 56200 images processed out of 78893.
# 56300 images processed out of 78893.
# 56400 images processed out of 78893.
# 56500 images processed out of 78893.
# 56600 images processed out of 78893.
# 56700 images processed out of 78893.
# 56800 images processed out of 78893.
# 56900 images processed out of 78893.
# 57000 images processed out of 78893.
# 57100 images processed out of 78893.
# 57200 images processed out of 78893.
# 57300 images processed out of 78893.
# 57400 images processed out of 78893.
# 57500 images processed out of 78893.
# 57600 images processed out of 78893.
# 57700 images processed out of 78893.
# 57800 images processed out of 78893.
# 57900 images processed out of 78893.
# 58000 images processed out of 78893.
# 58100 images processed out of 78893.
# 58200 images processed out of 78893.
# 58300 images processed out of 78893.
# 58400 images processed out of 78893.
# 58500 images processed out of 78893.
# 58600 images processed out of 78893.
# 58700 images processed out of 78893.
# 58800 images processed out of 78893.
# 58900 images processed out of 78893.
# 59000 images processed out of 78893.
# 59100 images processed out of 78893.
# 59200 images processed out of 78893.
# 59300 images processed out of 78893.
# 59400 images processed out of 78893.
# 59500 images processed out of 78893.
# 59600 images processed out of 78893.
# 59700 images processed out of 78893.
# 59800 images processed out of 78893.
# 59900 images processed out of 78893.
# 60000 images processed out of 78893.
# 60100 images processed out of 78893.
# 60200 images processed out of 78893.
# 60300 images processed out of 78893.
# 60400 images processed out of 78893.
# 60500 images processed out of 78893.
# 60600 images processed out of 78893.
# 60700 images processed out of 78893.
# 60800 images processed out of 78893.
# 60900 images processed out of 78893.
# 61000 images processed out of 78893.
# 61100 images processed out of 78893.
# 61200 images processed out of 78893.
# 61300 images processed out of 78893.
# 61400 images processed out of 78893.
# 61500 images processed out of 78893.
# 61600 images processed out of 78893.
# 61700 images processed out of 78893.
# 61800 images processed out of 78893.
# 61900 images processed out of 78893.
# 62000 images processed out of 78893.
# 62100 images processed out of 78893.
# 62200 images processed out of 78893.
# 62300 images processed out of 78893.
# 62400 images processed out of 78893.
# 62500 images processed out of 78893.
# 62600 images processed out of 78893.
# 62700 images processed out of 78893.
# 62800 images processed out of 78893.
# 62900 images processed out of 78893.
# 63000 images processed out of 78893.
# 63100 images processed out of 78893.
# 63200 images processed out of 78893.
# 63300 images processed out of 78893.
# 63400 images processed out of 78893.
# 63500 images processed out of 78893.
# 63600 images processed out of 78893.
# 63700 images processed out of 78893.
# 63800 images processed out of 78893.
# 63900 images processed out of 78893.
# 64000 images processed out of 78893.
# 64100 images processed out of 78893.
# 64200 images processed out of 78893.
# 64300 images processed out of 78893.
# 64400 images processed out of 78893.
# 64500 images processed out of 78893.
# 64600 images processed out of 78893.
# 64700 images processed out of 78893.
# 64800 images processed out of 78893.
# 64900 images processed out of 78893.
# 65000 images processed out of 78893.
# 65100 images processed out of 78893.
# 65200 images processed out of 78893.
# 65300 images processed out of 78893.
# 65400 images processed out of 78893.
# 65500 images processed out of 78893.
# 65600 images processed out of 78893.
# 65700 images processed out of 78893.
# 65800 images processed out of 78893.
# 65900 images processed out of 78893.
# 66000 images processed out of 78893.
# 66100 images processed out of 78893.
# 66200 images processed out of 78893.
# 66300 images processed out of 78893.
# 66400 images processed out of 78893.
# 66500 images processed out of 78893.
# 66600 images processed out of 78893.
# 66700 images processed out of 78893.
# 66800 images processed out of 78893.
# 66900 images processed out of 78893.
# 67000 images processed out of 78893.
# 67100 images processed out of 78893.
# 67200 images processed out of 78893.
# 67300 images processed out of 78893.
# 67400 images processed out of 78893.
# 67500 images processed out of 78893.
# 67600 images processed out of 78893.
# 67700 images processed out of 78893.
# 67800 images processed out of 78893.
# 67900 images processed out of 78893.
# 68000 images processed out of 78893.
# 68100 images processed out of 78893.
# 68200 images processed out of 78893.
# 68300 images processed out of 78893.
# 68400 images processed out of 78893.
# 68500 images processed out of 78893.
# 68600 images processed out of 78893.
# 68700 images processed out of 78893.
# 68800 images processed out of 78893.
# 68900 images processed out of 78893.
# 69000 images processed out of 78893.
# 69100 images processed out of 78893.
# 69200 images processed out of 78893.
# 69300 images processed out of 78893.
# 69400 images processed out of 78893.
# 69500 images processed out of 78893.
# 69600 images processed out of 78893.
# 69700 images processed out of 78893.
# 69800 images processed out of 78893.
# 69900 images processed out of 78893.
# 70000 images processed out of 78893.
# 70100 images processed out of 78893.
# 70200 images processed out of 78893.
# 70300 images processed out of 78893.
# 70400 images processed out of 78893.
# 70500 images processed out of 78893.
# 70600 images processed out of 78893.
# 70700 images processed out of 78893.
# 70800 images processed out of 78893.
# 70900 images processed out of 78893.
# 71000 images processed out of 78893.
# 71100 images processed out of 78893.
# 71200 images processed out of 78893.
# 71300 images processed out of 78893.
# 71400 images processed out of 78893.
# 71500 images processed out of 78893.
# 71600 images processed out of 78893.
# 71700 images processed out of 78893.
# 71800 images processed out of 78893.
# 71900 images processed out of 78893.
# 72000 images processed out of 78893.
# 72100 images processed out of 78893.
# 72200 images processed out of 78893.
# 72300 images processed out of 78893.
# 72400 images processed out of 78893.
# 72500 images processed out of 78893.
# 72600 images processed out of 78893.
# 72700 images processed out of 78893.
# 72800 images processed out of 78893.
# 72900 images processed out of 78893.
# 73000 images processed out of 78893.
# 73100 images processed out of 78893.
# 73200 images processed out of 78893.
# 73300 images processed out of 78893.
# 73400 images processed out of 78893.
# 73500 images processed out of 78893.
# 73600 images processed out of 78893.
# 73700 images processed out of 78893.
# 73800 images processed out of 78893.
# 73900 images processed out of 78893.
# 74000 images processed out of 78893.
# 74100 images processed out of 78893.
# 74200 images processed out of 78893.
# 74300 images processed out of 78893.
# 74400 images processed out of 78893.
# 74500 images processed out of 78893.
# 74600 images processed out of 78893.
# 74700 images processed out of 78893.
# 74800 images processed out of 78893.
# 74900 images processed out of 78893.
# 75000 images processed out of 78893.
# 75100 images processed out of 78893.
# 75200 images processed out of 78893.
# 75300 images processed out of 78893.
# 75400 images processed out of 78893.
# 75500 images processed out of 78893.
# 75600 images processed out of 78893.
# 75700 images processed out of 78893.
# 75800 images processed out of 78893.
# 75900 images processed out of 78893.
# 76000 images processed out of 78893.
# 76100 images processed out of 78893.
# 76200 images processed out of 78893.
# 76300 images processed out of 78893.
# 76400 images processed out of 78893.
# 76500 images processed out of 78893.
# 76600 images processed out of 78893.
# 76700 images processed out of 78893.
# 76800 images processed out of 78893.
# 76900 images processed out of 78893.
# 77000 images processed out of 78893.
# 77100 images processed out of 78893.
# 77200 images processed out of 78893.
# 77300 images processed out of 78893.
# 77400 images processed out of 78893.
# 77500 images processed out of 78893.
# 77600 images processed out of 78893.
# 77700 images processed out of 78893.
# 77800 images processed out of 78893.
# 77900 images processed out of 78893.
# 78000 images processed out of 78893.
# 78100 images processed out of 78893.
# 78200 images processed out of 78893.
# 78300 images processed out of 78893.
# 78400 images processed out of 78893.
# 78500 images processed out of 78893.
# 78600 images processed out of 78893.
# 78700 images processed out of 78893.
# 78800 images processed out of 78893.

# %%
idx2mid = {}
for item in label_map.item:
    idx2mid[item.id] = item.name

# %%
for imgid in det_results:
    det_results[imgid]['detection_boxes'] = det_results[imgid]['detection_boxes'][:,[1,0,3,2]]
    det_results[imgid]['detection_boxes_normalized'] = np.copy(det_results[imgid]['detection_boxes'])
    det_results[imgid]['detection_boxes'] = (det_results[imgid]['detection_boxes'] * np.asarray(image_shape[imgid]*2)).astype('int32')

# %%
det_results_2 = {}
for imgid in det_results:
    det_results_2[imgid] = []
    for ii in range(det_results[imgid]['num_detections']):
        if det_results[imgid]['detection_classes'][ii] == 0 or det_results[imgid]['detection_scores'][ii] == 0:
            continue
        det_results_2[imgid].append({
            'label': idx2mid[det_results[imgid]['detection_classes'][ii]],
            'score': det_results[imgid]['detection_scores'][ii],
            'bbox': det_results[imgid]['detection_boxes'][ii],
            'bbox_normalized': det_results[imgid]['detection_boxes_normalized'][ii],
            'model': 'inception-resnet-faster-rcnn-oi'
        })

# %%
with open('../../results/det_results_m9_keyframes_oi_1.pkl', 'wb') as fout:
    pickle.dump(det_results_2, fout)

# %%
with open('../../../model_fusion/temp/m9_keyframe_imgsize_1.pkl', 'wb') as fout:
    pickle.dump(image_shape, fout)
