# %% [markdown]
# # Object Detection Demo
# Welcome to the object detection inference walkthrough!  This notebook will walk you step by step through the process of using a pre-trained model to detect objects in an image. Make sure to follow the [installation instructions](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/installation.md) before you start.

# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("../../lib")
from object_detection.utils import ops as utils_ops

# %%
import pickle
import cv2
import csv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ## Env setup

# %%
# This is needed to display the images.
# %matplotlib inline

# %% [markdown]
# ## Object detection imports
# Here are the imports from the object detection module.

# %%
from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util
# Out:
# ../../lib/object_detection/utils/visualization_utils.py:25: UserWarning: matplotlib.pyplot as already been imported, this call will have no effect.
#   import matplotlib; matplotlib.use('Agg')  # pylint: disable=multiple-statements

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Variables
#
# Any model exported using the `export_inference_graph.py` tool can be loaded here simply by changing `PATH_TO_CKPT` to point to a new .pb file.
#
# By default we use an "SSD with Mobilenet" model here. See the [detection model zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md) for a list of other models that can be run out-of-the-box with varying speeds and accuracies.

# %%
# What model to download.
MODEL_NAME = '../../checkpoints/faster_rcnn_inception_resnet_v2_atrous_oid'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('../../lib/object_detection/data', 'oid_bbox_trainable_label_map.pbtxt')

NUM_CLASSES = 600

# %% [markdown]
# ## Load a (frozen) Tensorflow model into memory.

# %%
od_graph_def = tf.GraphDef()
with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# %% [markdown]
# ## Loading label map
# Label maps map indices to category names, so that when our convolution network predicts `5`, we know that this corresponds to `airplane`.  Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine

# %%
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %% [markdown]
# ## Helper code

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Data Preparation

# %%
path_prefix = '/home/alireza/workspace/ws-ov-sgp/data/imSitu/images_flat/'
with open('/home/alireza/workspace/ws-ov-sgp/data/imSitu/jpg.txt', 'r') as fin:
    test_img_names = [line.strip() for line in fin]

# %%
test_img_names[0]
# Out:
# 'adjusting_0.jpg'

# %% [markdown]
# # Detection

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
def run_inference_for_single_image(image):
  # Get handles to input and output tensors
  ops = tf.get_default_graph().get_operations()
  all_tensor_names = {output.name for op in ops for output in op.outputs}
  tensor_dict = {}
  for key in [
      'num_detections', 'detection_boxes', 'detection_scores',
      'detection_classes', 'detection_masks'
  ]:
    tensor_name = key + ':0'
    if tensor_name in all_tensor_names:
      tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
          tensor_name)
  if 'detection_masks' in tensor_dict:
    # The following processing is only for single image
    detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
    detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
    # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
    real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
    detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
    detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
    detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
        detection_masks, detection_boxes, image.shape[0], image.shape[1])
    detection_masks_reframed = tf.cast(
        tf.greater(detection_masks_reframed, 0.5), tf.uint8)
    # Follow the convention by adding back the batch dimension
    tensor_dict['detection_masks'] = tf.expand_dims(
        detection_masks_reframed, 0)
  image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

  # Run inference
  output_dict = sess.run(tensor_dict,
                         feed_dict={image_tensor: np.expand_dims(image, 0)})

  # all outputs are float32 numpy arrays, so convert types as appropriate
  output_dict['num_detections'] = int(output_dict['num_detections'][0])
  output_dict['detection_classes'] = output_dict[
      'detection_classes'][0].astype(np.uint8)
  output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
  output_dict['detection_scores'] = output_dict['detection_scores'][0]
  if 'detection_masks' in output_dict:
        output_dict['detection_masks'] = output_dict['detection_masks'][0]
  return output_dict

# %%
det_results = {}
image_shape = {}
num_imgs = len(test_img_names)
for i, imgname in enumerate(test_img_names):
    imgid = imgname
    imgpath = path_prefix + imgname
    try:
        with open(imgpath, 'rb') as fin:
            #_ = fin.read(1024)
            imgbin = fin.read()
        imgbgr = cv2.imdecode(np.fromstring(imgbin, dtype='uint8'), cv2.IMREAD_COLOR)
        image_np = imgbgr[:,:,[2,1,0]]
        image_shape[imgid] = (image_np.shape[1], image_np.shape[0])
    except Exception as ex:
        print(imgid)
        print(ex)
        continue
    
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np)
    
    det_results[imgid] = output_dict
    
    if i % 100 == 0:
        print(f'{i} images processed out of {num_imgs}.')
# Out:
# /home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf_new/lib/python3.6/site-packages/ipykernel/__main__.py:11: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
# 0 images processed out of 126102.
# 100 images processed out of 126102.
# 200 images processed out of 126102.
# 300 images processed out of 126102.
# 400 images processed out of 126102.
# 500 images processed out of 126102.
# 600 images processed out of 126102.
# 700 images processed out of 126102.
# 800 images processed out of 126102.
# 900 images processed out of 126102.
# 1000 images processed out of 126102.
# 1100 images processed out of 126102.
# 1200 images processed out of 126102.
# 1300 images processed out of 126102.
# 1400 images processed out of 126102.
# 1500 images processed out of 126102.
# 1600 images processed out of 126102.
# 1700 images processed out of 126102.
# 1800 images processed out of 126102.
# 1900 images processed out of 126102.
# 2000 images processed out of 126102.
# 2100 images processed out of 126102.
# 2200 images processed out of 126102.
# 2300 images processed out of 126102.
# 2400 images processed out of 126102.
# 2500 images processed out of 126102.
# 2600 images processed out of 126102.
# 2700 images processed out of 126102.
# 2800 images processed out of 126102.
# 2900 images processed out of 126102.
# 3000 images processed out of 126102.
# 3100 images processed out of 126102.
# 3200 images processed out of 126102.
# 3300 images processed out of 126102.
# 3400 images processed out of 126102.
# 3500 images processed out of 126102.
# 3600 images processed out of 126102.
# 3700 images processed out of 126102.
# 3800 images processed out of 126102.
# 3900 images processed out of 126102.
# 4000 images processed out of 126102.
# 4100 images processed out of 126102.
# 4200 images processed out of 126102.
# 4300 images processed out of 126102.
# 4400 images processed out of 126102.
# 4500 images processed out of 126102.
# 4600 images processed out of 126102.
# 4700 images processed out of 126102.
# 4800 images processed out of 126102.
# 4900 images processed out of 126102.
# 5000 images processed out of 126102.
# 5100 images processed out of 126102.
# 5200 images processed out of 126102.
# 5300 images processed out of 126102.
# 5400 images processed out of 126102.
# 5500 images processed out of 126102.
# 5600 images processed out of 126102.
# 5700 images processed out of 126102.
# 5800 images processed out of 126102.
# 5900 images processed out of 126102.
# 6000 images processed out of 126102.
# 6100 images processed out of 126102.
# 6200 images processed out of 126102.
# 6300 images processed out of 126102.
# 6400 images processed out of 126102.
# 6500 images processed out of 126102.
# 6600 images processed out of 126102.
# 6700 images processed out of 126102.
# 6800 images processed out of 126102.
# 6900 images processed out of 126102.
# 7000 images processed out of 126102.
# 7100 images processed out of 126102.
# 7200 images processed out of 126102.
# 7300 images processed out of 126102.
# 7400 images processed out of 126102.
# 7500 images processed out of 126102.
# 7600 images processed out of 126102.
# 7700 images processed out of 126102.
# 7800 images processed out of 126102.
# 7900 images processed out of 126102.
# 8000 images processed out of 126102.
# 8100 images processed out of 126102.
# 8200 images processed out of 126102.
# 8300 images processed out of 126102.
# 8400 images processed out of 126102.
# 8500 images processed out of 126102.
# 8600 images processed out of 126102.
# 8700 images processed out of 126102.
# 8800 images processed out of 126102.
# 8900 images processed out of 126102.
# 9000 images processed out of 126102.
# 9100 images processed out of 126102.
# 9200 images processed out of 126102.
# 9300 images processed out of 126102.
# 9400 images processed out of 126102.
# 9500 images processed out of 126102.
# 9600 images processed out of 126102.
# 9700 images processed out of 126102.
# 9800 images processed out of 126102.
# 9900 images processed out of 126102.
# 10000 images processed out of 126102.
# 10100 images processed out of 126102.
# 10200 images processed out of 126102.
# 10300 images processed out of 126102.
# 10400 images processed out of 126102.
# 10500 images processed out of 126102.
# 10600 images processed out of 126102.
# 10700 images processed out of 126102.
# 10800 images processed out of 126102.
# 10900 images processed out of 126102.
# 11000 images processed out of 126102.
# 11100 images processed out of 126102.
# 11200 images processed out of 126102.
# 11300 images processed out of 126102.
# 11400 images processed out of 126102.
# 11500 images processed out of 126102.
# 11600 images processed out of 126102.
# 11700 images processed out of 126102.
# 11800 images processed out of 126102.
# 11900 images processed out of 126102.
# 12000 images processed out of 126102.
# 12100 images processed out of 126102.
# 12200 images processed out of 126102.
# 12300 images processed out of 126102.
# 12400 images processed out of 126102.
# 12500 images processed out of 126102.
# 12600 images processed out of 126102.
# 12700 images processed out of 126102.
# 12800 images processed out of 126102.
# 12900 images processed out of 126102.
# 13000 images processed out of 126102.
# 13100 images processed out of 126102.
# 13200 images processed out of 126102.
# 13300 images processed out of 126102.
# 13400 images processed out of 126102.
# 13500 images processed out of 126102.
# 13600 images processed out of 126102.
# 13700 images processed out of 126102.
# 13800 images processed out of 126102.
# 13900 images processed out of 126102.
# 14000 images processed out of 126102.
# 14100 images processed out of 126102.
# 14200 images processed out of 126102.
# 14300 images processed out of 126102.
# 14400 images processed out of 126102.
# 14500 images processed out of 126102.
# 14600 images processed out of 126102.
# 14700 images processed out of 126102.
# 14800 images processed out of 126102.
# 14900 images processed out of 126102.
# 15000 images processed out of 126102.
# 15100 images processed out of 126102.
# 15200 images processed out of 126102.
# 15300 images processed out of 126102.
# 15400 images processed out of 126102.
# 15500 images processed out of 126102.
# 15600 images processed out of 126102.
# 15700 images processed out of 126102.
# 15800 images processed out of 126102.
# 15900 images processed out of 126102.
# 16000 images processed out of 126102.
# 16100 images processed out of 126102.
# 16200 images processed out of 126102.
# 16300 images processed out of 126102.
# 16400 images processed out of 126102.
# 16500 images processed out of 126102.
# 16600 images processed out of 126102.
# 16700 images processed out of 126102.
# 16800 images processed out of 126102.
# 16900 images processed out of 126102.
# 17000 images processed out of 126102.
# 17100 images processed out of 126102.
# 17200 images processed out of 126102.
# 17300 images processed out of 126102.
# 17400 images processed out of 126102.
# 17500 images processed out of 126102.
# 17600 images processed out of 126102.
# 17700 images processed out of 126102.
# 17800 images processed out of 126102.
# 17900 images processed out of 126102.
# 18000 images processed out of 126102.
# 18100 images processed out of 126102.
# 18200 images processed out of 126102.
# 18300 images processed out of 126102.
# 18400 images processed out of 126102.
# 18500 images processed out of 126102.
# 18600 images processed out of 126102.
# 18700 images processed out of 126102.
# 18800 images processed out of 126102.
# 18900 images processed out of 126102.
# 19000 images processed out of 126102.
# 19100 images processed out of 126102.
# 19200 images processed out of 126102.
# 19300 images processed out of 126102.
# 19400 images processed out of 126102.
# 19500 images processed out of 126102.
# 19600 images processed out of 126102.
# 19700 images processed out of 126102.
# 19800 images processed out of 126102.
# 19900 images processed out of 126102.
# 20000 images processed out of 126102.
# 20100 images processed out of 126102.
# 20200 images processed out of 126102.
# 20300 images processed out of 126102.
# 20400 images processed out of 126102.
# 20500 images processed out of 126102.
# 20600 images processed out of 126102.
# 20700 images processed out of 126102.
# 20800 images processed out of 126102.
# 20900 images processed out of 126102.
# 21000 images processed out of 126102.
# 21100 images processed out of 126102.
# 21200 images processed out of 126102.
# 21300 images processed out of 126102.
# 21400 images processed out of 126102.
# 21500 images processed out of 126102.
# 21600 images processed out of 126102.
# 21700 images processed out of 126102.
# 21800 images processed out of 126102.
# 21900 images processed out of 126102.
# 22000 images processed out of 126102.
# 22100 images processed out of 126102.
# 22200 images processed out of 126102.
# 22300 images processed out of 126102.
# 22400 images processed out of 126102.
# 22500 images processed out of 126102.
# 22600 images processed out of 126102.
# 22700 images processed out of 126102.
# 22800 images processed out of 126102.
# 22900 images processed out of 126102.
# 23000 images processed out of 126102.
# 23100 images processed out of 126102.
# 23200 images processed out of 126102.
# 23300 images processed out of 126102.
# 23400 images processed out of 126102.
# 23500 images processed out of 126102.
# 23600 images processed out of 126102.
# 23700 images processed out of 126102.
# 23800 images processed out of 126102.
# 23900 images processed out of 126102.
# 24000 images processed out of 126102.
# 24100 images processed out of 126102.
# 24200 images processed out of 126102.
# 24300 images processed out of 126102.
# 24400 images processed out of 126102.
# 24500 images processed out of 126102.
# 24600 images processed out of 126102.
# 24700 images processed out of 126102.
# 24800 images processed out of 126102.
# 24900 images processed out of 126102.
# 25000 images processed out of 126102.
# 25100 images processed out of 126102.
# 25200 images processed out of 126102.
# 25300 images processed out of 126102.
# 25400 images processed out of 126102.
# 25500 images processed out of 126102.
# 25600 images processed out of 126102.
# 25700 images processed out of 126102.
# 25800 images processed out of 126102.
# 25900 images processed out of 126102.
# 26000 images processed out of 126102.
# 26100 images processed out of 126102.
# 26200 images processed out of 126102.
# 26300 images processed out of 126102.
# 26400 images processed out of 126102.
# 26500 images processed out of 126102.
# 26600 images processed out of 126102.
# 26700 images processed out of 126102.
# 26800 images processed out of 126102.
# 26900 images processed out of 126102.
# 27000 images processed out of 126102.
# 27100 images processed out of 126102.
# 27200 images processed out of 126102.
# 27300 images processed out of 126102.
# 27400 images processed out of 126102.
# 27500 images processed out of 126102.
# 27600 images processed out of 126102.
# 27700 images processed out of 126102.
# 27800 images processed out of 126102.
# 27900 images processed out of 126102.
# 28000 images processed out of 126102.
# 28100 images processed out of 126102.
# 28200 images processed out of 126102.
# 28300 images processed out of 126102.
# 28400 images processed out of 126102.
# 28500 images processed out of 126102.
# 28600 images processed out of 126102.
# 28700 images processed out of 126102.
# 28800 images processed out of 126102.
# 28900 images processed out of 126102.
# 29000 images processed out of 126102.
# 29100 images processed out of 126102.
# 29200 images processed out of 126102.
# 29300 images processed out of 126102.
# 29400 images processed out of 126102.
# 29500 images processed out of 126102.
# 29600 images processed out of 126102.
# 29700 images processed out of 126102.
# 29800 images processed out of 126102.
# 29900 images processed out of 126102.
# 30000 images processed out of 126102.
# 30100 images processed out of 126102.
# 30200 images processed out of 126102.
# 30300 images processed out of 126102.
# 30400 images processed out of 126102.
# 30500 images processed out of 126102.
# 30600 images processed out of 126102.
# 30700 images processed out of 126102.
# 30800 images processed out of 126102.
# 30900 images processed out of 126102.
# 31000 images processed out of 126102.
# 31100 images processed out of 126102.
# 31200 images processed out of 126102.
# 31300 images processed out of 126102.
# 31400 images processed out of 126102.
# 31500 images processed out of 126102.
# 31600 images processed out of 126102.
# 31700 images processed out of 126102.
# 31800 images processed out of 126102.
# 31900 images processed out of 126102.
# 32000 images processed out of 126102.
# 32100 images processed out of 126102.
# 32200 images processed out of 126102.
# 32300 images processed out of 126102.
# 32400 images processed out of 126102.
# 32500 images processed out of 126102.
# 32600 images processed out of 126102.
# 32700 images processed out of 126102.
# 32800 images processed out of 126102.
# 32900 images processed out of 126102.
# 33000 images processed out of 126102.
# 33100 images processed out of 126102.
# 33200 images processed out of 126102.
# 33300 images processed out of 126102.
# 33400 images processed out of 126102.
# 33500 images processed out of 126102.
# 33600 images processed out of 126102.
# 33700 images processed out of 126102.
# 33800 images processed out of 126102.
# 33900 images processed out of 126102.
# 34000 images processed out of 126102.
# 34100 images processed out of 126102.
# 34200 images processed out of 126102.
# 34300 images processed out of 126102.
# 34400 images processed out of 126102.
# 34500 images processed out of 126102.
# 34600 images processed out of 126102.
# 34700 images processed out of 126102.
# 34800 images processed out of 126102.
# 34900 images processed out of 126102.
# 35000 images processed out of 126102.
# 35100 images processed out of 126102.
# 35200 images processed out of 126102.
# 35300 images processed out of 126102.
# 35400 images processed out of 126102.
# 35500 images processed out of 126102.
# 35600 images processed out of 126102.
# 35700 images processed out of 126102.
# 35800 images processed out of 126102.
# 35900 images processed out of 126102.
# 36000 images processed out of 126102.
# 36100 images processed out of 126102.
# 36200 images processed out of 126102.
# 36300 images processed out of 126102.
# 36400 images processed out of 126102.
# 36500 images processed out of 126102.
# 36600 images processed out of 126102.
# 36700 images processed out of 126102.
# 36800 images processed out of 126102.
# 36900 images processed out of 126102.
# 37000 images processed out of 126102.
# 37100 images processed out of 126102.
# 37200 images processed out of 126102.
# 37300 images processed out of 126102.
# 37400 images processed out of 126102.
# 37500 images processed out of 126102.
# 37600 images processed out of 126102.
# 37700 images processed out of 126102.
# 37800 images processed out of 126102.
# 37900 images processed out of 126102.
# 38000 images processed out of 126102.
# 38100 images processed out of 126102.
# 38200 images processed out of 126102.
# 38300 images processed out of 126102.
# 38400 images processed out of 126102.
# 38500 images processed out of 126102.
# 38600 images processed out of 126102.
# 38700 images processed out of 126102.
# 38800 images processed out of 126102.
# 38900 images processed out of 126102.
# 39000 images processed out of 126102.
# 39100 images processed out of 126102.
# 39200 images processed out of 126102.
# 39300 images processed out of 126102.
# 39400 images processed out of 126102.
# 39500 images processed out of 126102.
# 39600 images processed out of 126102.
# 39700 images processed out of 126102.
# 39800 images processed out of 126102.
# 39900 images processed out of 126102.
# 40000 images processed out of 126102.
# 40100 images processed out of 126102.
# 40200 images processed out of 126102.
# 40300 images processed out of 126102.
# 40400 images processed out of 126102.
# 40500 images processed out of 126102.
# 40600 images processed out of 126102.
# 40700 images processed out of 126102.
# 40800 images processed out of 126102.
# 40900 images processed out of 126102.
# 41000 images processed out of 126102.
# 41100 images processed out of 126102.
# 41200 images processed out of 126102.
# 41300 images processed out of 126102.
# 41400 images processed out of 126102.
# 41500 images processed out of 126102.
# 41600 images processed out of 126102.
# 41700 images processed out of 126102.
# 41800 images processed out of 126102.
# 41900 images processed out of 126102.
# 42000 images processed out of 126102.
# 42100 images processed out of 126102.
# 42200 images processed out of 126102.
# 42300 images processed out of 126102.
# 42400 images processed out of 126102.
# 42500 images processed out of 126102.
# 42600 images processed out of 126102.
# 42700 images processed out of 126102.
# 42800 images processed out of 126102.
# 42900 images processed out of 126102.
# 43000 images processed out of 126102.
# 43100 images processed out of 126102.
# 43200 images processed out of 126102.
# 43300 images processed out of 126102.
# 43400 images processed out of 126102.
# 43500 images processed out of 126102.
# 43600 images processed out of 126102.
# 43700 images processed out of 126102.
# 43800 images processed out of 126102.
# 43900 images processed out of 126102.
# 44000 images processed out of 126102.
# 44100 images processed out of 126102.
# 44200 images processed out of 126102.
# 44300 images processed out of 126102.
# 44400 images processed out of 126102.
# 44500 images processed out of 126102.
# 44600 images processed out of 126102.
# 44700 images processed out of 126102.
# 44800 images processed out of 126102.
# 44900 images processed out of 126102.
# 45000 images processed out of 126102.
# 45100 images processed out of 126102.
# 45200 images processed out of 126102.
# 45300 images processed out of 126102.
# 45400 images processed out of 126102.
# 45500 images processed out of 126102.
# 45600 images processed out of 126102.
# 45700 images processed out of 126102.
# 45800 images processed out of 126102.
# 45900 images processed out of 126102.
# 46000 images processed out of 126102.
# 46100 images processed out of 126102.
# 46200 images processed out of 126102.
# 46300 images processed out of 126102.
# 46400 images processed out of 126102.
# 46500 images processed out of 126102.
# 46600 images processed out of 126102.
# 46700 images processed out of 126102.
# 46800 images processed out of 126102.
# 46900 images processed out of 126102.
# 47000 images processed out of 126102.
# 47100 images processed out of 126102.
# 47200 images processed out of 126102.
# 47300 images processed out of 126102.
# 47400 images processed out of 126102.
# 47500 images processed out of 126102.
# 47600 images processed out of 126102.
# 47700 images processed out of 126102.
# 47800 images processed out of 126102.
# 47900 images processed out of 126102.
# 48000 images processed out of 126102.
# 48100 images processed out of 126102.
# 48200 images processed out of 126102.
# 48300 images processed out of 126102.
# 48400 images processed out of 126102.
# 48500 images processed out of 126102.
# 48600 images processed out of 126102.
# 48700 images processed out of 126102.
# 48800 images processed out of 126102.
# 48900 images processed out of 126102.
# 49000 images processed out of 126102.
# 49100 images processed out of 126102.
# 49200 images processed out of 126102.
# 49300 images processed out of 126102.
# 49400 images processed out of 126102.
# 49500 images processed out of 126102.
# 49600 images processed out of 126102.
# 49700 images processed out of 126102.
# 49800 images processed out of 126102.
# 49900 images processed out of 126102.
# 50000 images processed out of 126102.
# 50100 images processed out of 126102.
# 50200 images processed out of 126102.
# 50300 images processed out of 126102.
# 50400 images processed out of 126102.
# 50500 images processed out of 126102.
# 50600 images processed out of 126102.
# 50700 images processed out of 126102.
# 50800 images processed out of 126102.
# 50900 images processed out of 126102.
# 51000 images processed out of 126102.
# 51100 images processed out of 126102.
# 51200 images processed out of 126102.
# 51300 images processed out of 126102.
# 51400 images processed out of 126102.
# 51500 images processed out of 126102.
# 51600 images processed out of 126102.
# 51700 images processed out of 126102.
# 51800 images processed out of 126102.
# 51900 images processed out of 126102.
# 52000 images processed out of 126102.
# 52100 images processed out of 126102.
# 52200 images processed out of 126102.
# 52300 images processed out of 126102.
# 52400 images processed out of 126102.
# 52500 images processed out of 126102.
# 52600 images processed out of 126102.
# 52700 images processed out of 126102.
# 52800 images processed out of 126102.
# 52900 images processed out of 126102.
# 53000 images processed out of 126102.
# 53100 images processed out of 126102.
# 53200 images processed out of 126102.
# 53300 images processed out of 126102.
# 53400 images processed out of 126102.
# 53500 images processed out of 126102.
# 53600 images processed out of 126102.
# 53700 images processed out of 126102.
# 53800 images processed out of 126102.
# 53900 images processed out of 126102.
# 54000 images processed out of 126102.
# 54100 images processed out of 126102.
# 54200 images processed out of 126102.
# 54300 images processed out of 126102.
# 54400 images processed out of 126102.
# 54500 images processed out of 126102.
# 54600 images processed out of 126102.
# 54700 images processed out of 126102.
# 54800 images processed out of 126102.
# 54900 images processed out of 126102.
# 55000 images processed out of 126102.
# 55100 images processed out of 126102.
# 55200 images processed out of 126102.
# 55300 images processed out of 126102.
# 55400 images processed out of 126102.
# 55500 images processed out of 126102.
# 55600 images processed out of 126102.
# 55700 images processed out of 126102.
# 55800 images processed out of 126102.
# 55900 images processed out of 126102.
# 56000 images processed out of 126102.
# 56100 images processed out of 126102.
# 56200 images processed out of 126102.
# 56300 images processed out of 126102.
# 56400 images processed out of 126102.
# 56500 images processed out of 126102.
# 56600 images processed out of 126102.
# 56700 images processed out of 126102.
# 56800 images processed out of 126102.
# 56900 images processed out of 126102.
# 57000 images processed out of 126102.
# 57100 images processed out of 126102.
# 57200 images processed out of 126102.
# 57300 images processed out of 126102.
# 57400 images processed out of 126102.
# 57500 images processed out of 126102.
# 57600 images processed out of 126102.
# 57700 images processed out of 126102.
# 57800 images processed out of 126102.
# 57900 images processed out of 126102.
# 58000 images processed out of 126102.
# 58100 images processed out of 126102.
# 58200 images processed out of 126102.
# 58300 images processed out of 126102.
# 58400 images processed out of 126102.
# 58500 images processed out of 126102.
# 58600 images processed out of 126102.
# 58700 images processed out of 126102.
# 58800 images processed out of 126102.
# 58900 images processed out of 126102.
# 59000 images processed out of 126102.
# 59100 images processed out of 126102.
# 59200 images processed out of 126102.
# 59300 images processed out of 126102.
# 59400 images processed out of 126102.
# 59500 images processed out of 126102.
# 59600 images processed out of 126102.
# 59700 images processed out of 126102.
# 59800 images processed out of 126102.
# 59900 images processed out of 126102.
# 60000 images processed out of 126102.
# 60100 images processed out of 126102.
# 60200 images processed out of 126102.
# 60300 images processed out of 126102.
# 60400 images processed out of 126102.
# 60500 images processed out of 126102.
# 60600 images processed out of 126102.
# 60700 images processed out of 126102.
# 60800 images processed out of 126102.
# 60900 images processed out of 126102.
# 61000 images processed out of 126102.
# 61100 images processed out of 126102.
# 61200 images processed out of 126102.
# 61300 images processed out of 126102.
# 61400 images processed out of 126102.
# 61500 images processed out of 126102.
# 61600 images processed out of 126102.
# 61700 images processed out of 126102.
# 61800 images processed out of 126102.
# 61900 images processed out of 126102.
# 62000 images processed out of 126102.
# 62100 images processed out of 126102.
# 62200 images processed out of 126102.
# 62300 images processed out of 126102.
# 62400 images processed out of 126102.
# 62500 images processed out of 126102.
# 62600 images processed out of 126102.
# 62700 images processed out of 126102.
# 62800 images processed out of 126102.
# 62900 images processed out of 126102.
# 63000 images processed out of 126102.
# 63100 images processed out of 126102.
# 63200 images processed out of 126102.
# 63300 images processed out of 126102.
# 63400 images processed out of 126102.
# 63500 images processed out of 126102.
# 63600 images processed out of 126102.
# 63700 images processed out of 126102.
# 63800 images processed out of 126102.
# 63900 images processed out of 126102.
# 64000 images processed out of 126102.
# 64100 images processed out of 126102.
# 64200 images processed out of 126102.
# 64300 images processed out of 126102.
# 64400 images processed out of 126102.
# 64500 images processed out of 126102.
# 64600 images processed out of 126102.
# 64700 images processed out of 126102.
# 64800 images processed out of 126102.
# 64900 images processed out of 126102.
# 65000 images processed out of 126102.
# 65100 images processed out of 126102.
# 65200 images processed out of 126102.
# 65300 images processed out of 126102.
# 65400 images processed out of 126102.
# 65500 images processed out of 126102.
# 65600 images processed out of 126102.
# 65700 images processed out of 126102.
# 65800 images processed out of 126102.
# 65900 images processed out of 126102.
# 66000 images processed out of 126102.
# 66100 images processed out of 126102.
# 66200 images processed out of 126102.
# 66300 images processed out of 126102.
# 66400 images processed out of 126102.
# 66500 images processed out of 126102.
# 66600 images processed out of 126102.
# 66700 images processed out of 126102.
# 66800 images processed out of 126102.
# 66900 images processed out of 126102.
# 67000 images processed out of 126102.
# 67100 images processed out of 126102.
# 67200 images processed out of 126102.
# 67300 images processed out of 126102.
# 67400 images processed out of 126102.
# 67500 images processed out of 126102.
# 67600 images processed out of 126102.
# 67700 images processed out of 126102.
# 67800 images processed out of 126102.
# 67900 images processed out of 126102.
# 68000 images processed out of 126102.
# 68100 images processed out of 126102.
# 68200 images processed out of 126102.
# 68300 images processed out of 126102.
# 68400 images processed out of 126102.
# 68500 images processed out of 126102.
# 68600 images processed out of 126102.
# 68700 images processed out of 126102.
# 68800 images processed out of 126102.
# 68900 images processed out of 126102.
# 69000 images processed out of 126102.
# 69100 images processed out of 126102.
# 69200 images processed out of 126102.
# 69300 images processed out of 126102.
# 69400 images processed out of 126102.
# 69500 images processed out of 126102.
# 69600 images processed out of 126102.
# 69700 images processed out of 126102.
# 69800 images processed out of 126102.
# 69900 images processed out of 126102.
# 70000 images processed out of 126102.
# 70100 images processed out of 126102.
# 70200 images processed out of 126102.
# 70300 images processed out of 126102.
# 70400 images processed out of 126102.
# 70500 images processed out of 126102.
# 70600 images processed out of 126102.
# 70700 images processed out of 126102.
# 70800 images processed out of 126102.
# 70900 images processed out of 126102.
# 71000 images processed out of 126102.
# 71100 images processed out of 126102.
# 71200 images processed out of 126102.
# 71300 images processed out of 126102.
# 71400 images processed out of 126102.
# 71500 images processed out of 126102.
# 71600 images processed out of 126102.
# 71700 images processed out of 126102.
# 71800 images processed out of 126102.
# 71900 images processed out of 126102.
# 72000 images processed out of 126102.
# 72100 images processed out of 126102.
# 72200 images processed out of 126102.
# 72300 images processed out of 126102.
# 72400 images processed out of 126102.
# 72500 images processed out of 126102.
# 72600 images processed out of 126102.
# 72700 images processed out of 126102.
# 72800 images processed out of 126102.
# 72900 images processed out of 126102.
# 73000 images processed out of 126102.
# 73100 images processed out of 126102.
# 73200 images processed out of 126102.
# 73300 images processed out of 126102.
# 73400 images processed out of 126102.
# 73500 images processed out of 126102.
# 73600 images processed out of 126102.
# 73700 images processed out of 126102.
# 73800 images processed out of 126102.
# 73900 images processed out of 126102.
# 74000 images processed out of 126102.
# 74100 images processed out of 126102.
# 74200 images processed out of 126102.
# 74300 images processed out of 126102.
# 74400 images processed out of 126102.
# 74500 images processed out of 126102.
# 74600 images processed out of 126102.
# 74700 images processed out of 126102.
# 74800 images processed out of 126102.
# 74900 images processed out of 126102.
# 75000 images processed out of 126102.
# 75100 images processed out of 126102.
# 75200 images processed out of 126102.
# 75300 images processed out of 126102.
# 75400 images processed out of 126102.
# 75500 images processed out of 126102.
# 75600 images processed out of 126102.
# 75700 images processed out of 126102.
# 75800 images processed out of 126102.
# 75900 images processed out of 126102.
# 76000 images processed out of 126102.
# 76100 images processed out of 126102.
# 76200 images processed out of 126102.
# 76300 images processed out of 126102.
# 76400 images processed out of 126102.
# 76500 images processed out of 126102.
# 76600 images processed out of 126102.
# 76700 images processed out of 126102.
# 76800 images processed out of 126102.
# 76900 images processed out of 126102.
# 77000 images processed out of 126102.
# 77100 images processed out of 126102.
# 77200 images processed out of 126102.
# 77300 images processed out of 126102.
# 77400 images processed out of 126102.
# 77500 images processed out of 126102.
# 77600 images processed out of 126102.
# 77700 images processed out of 126102.
# 77800 images processed out of 126102.
# 77900 images processed out of 126102.
# 78000 images processed out of 126102.
# 78100 images processed out of 126102.
# 78200 images processed out of 126102.
# 78300 images processed out of 126102.
# 78400 images processed out of 126102.
# 78500 images processed out of 126102.
# 78600 images processed out of 126102.
# 78700 images processed out of 126102.
# 78800 images processed out of 126102.
# 78900 images processed out of 126102.
# 79000 images processed out of 126102.
# 79100 images processed out of 126102.
# 79200 images processed out of 126102.
# 79300 images processed out of 126102.
# 79400 images processed out of 126102.
# 79500 images processed out of 126102.
# 79600 images processed out of 126102.
# 79700 images processed out of 126102.
# 79800 images processed out of 126102.
# 79900 images processed out of 126102.
# 80000 images processed out of 126102.
# 80100 images processed out of 126102.
# 80200 images processed out of 126102.
# 80300 images processed out of 126102.
# 80400 images processed out of 126102.
# 80500 images processed out of 126102.
# 80600 images processed out of 126102.
# 80700 images processed out of 126102.
# 80800 images processed out of 126102.
# 80900 images processed out of 126102.
# 81000 images processed out of 126102.
# 81100 images processed out of 126102.
# 81200 images processed out of 126102.
# 81300 images processed out of 126102.
# 81400 images processed out of 126102.
# 81500 images processed out of 126102.
# 81600 images processed out of 126102.
# 81700 images processed out of 126102.
# 81800 images processed out of 126102.
# 81900 images processed out of 126102.
# 82000 images processed out of 126102.
# 82100 images processed out of 126102.
# 82200 images processed out of 126102.
# 82300 images processed out of 126102.
# 82400 images processed out of 126102.
# 82500 images processed out of 126102.
# 82600 images processed out of 126102.
# 82700 images processed out of 126102.
# 82800 images processed out of 126102.
# 82900 images processed out of 126102.
# 83000 images processed out of 126102.
# 83100 images processed out of 126102.
# 83200 images processed out of 126102.
# 83300 images processed out of 126102.
# 83400 images processed out of 126102.
# 83500 images processed out of 126102.
# 83600 images processed out of 126102.
# 83700 images processed out of 126102.
# 83800 images processed out of 126102.
# 83900 images processed out of 126102.
# 84000 images processed out of 126102.
# 84100 images processed out of 126102.
# 84200 images processed out of 126102.
# 84300 images processed out of 126102.
# 84400 images processed out of 126102.
# 84500 images processed out of 126102.
# 84600 images processed out of 126102.
# 84700 images processed out of 126102.
# 84800 images processed out of 126102.
# 84900 images processed out of 126102.
# 85000 images processed out of 126102.
# 85100 images processed out of 126102.
# 85200 images processed out of 126102.
# 85300 images processed out of 126102.
# 85400 images processed out of 126102.
# 85500 images processed out of 126102.
# 85600 images processed out of 126102.
# 85700 images processed out of 126102.
# 85800 images processed out of 126102.
# 85900 images processed out of 126102.
# 86000 images processed out of 126102.
# 86100 images processed out of 126102.
# 86200 images processed out of 126102.
# 86300 images processed out of 126102.
# 86400 images processed out of 126102.
# 86500 images processed out of 126102.
# 86600 images processed out of 126102.
# 86700 images processed out of 126102.
# 86800 images processed out of 126102.
# 86900 images processed out of 126102.
# 87000 images processed out of 126102.
# 87100 images processed out of 126102.
# 87200 images processed out of 126102.
# 87300 images processed out of 126102.
# 87400 images processed out of 126102.
# 87500 images processed out of 126102.
# 87600 images processed out of 126102.
# 87700 images processed out of 126102.
# 87800 images processed out of 126102.
# 87900 images processed out of 126102.
# 88000 images processed out of 126102.
# 88100 images processed out of 126102.
# 88200 images processed out of 126102.
# 88300 images processed out of 126102.
# 88400 images processed out of 126102.
# 88500 images processed out of 126102.
# 88600 images processed out of 126102.
# 88700 images processed out of 126102.
# 88800 images processed out of 126102.
# 88900 images processed out of 126102.
# 89000 images processed out of 126102.
# 89100 images processed out of 126102.
# 89200 images processed out of 126102.
# 89300 images processed out of 126102.
# 89400 images processed out of 126102.
# 89500 images processed out of 126102.
# 89600 images processed out of 126102.
# 89700 images processed out of 126102.
# 89800 images processed out of 126102.
# 89900 images processed out of 126102.
# 90000 images processed out of 126102.
# 90100 images processed out of 126102.
# 90200 images processed out of 126102.
# 90300 images processed out of 126102.
# 90400 images processed out of 126102.
# 90500 images processed out of 126102.
# 90600 images processed out of 126102.
# 90700 images processed out of 126102.
# 90800 images processed out of 126102.
# 90900 images processed out of 126102.
# 91000 images processed out of 126102.
# 91100 images processed out of 126102.
# 91200 images processed out of 126102.
# 91300 images processed out of 126102.
# 91400 images processed out of 126102.
# 91500 images processed out of 126102.
# 91600 images processed out of 126102.
# 91700 images processed out of 126102.
# 91800 images processed out of 126102.
# 91900 images processed out of 126102.
# 92000 images processed out of 126102.
# 92100 images processed out of 126102.
# 92200 images processed out of 126102.
# 92300 images processed out of 126102.
# 92400 images processed out of 126102.
# 92500 images processed out of 126102.
# 92600 images processed out of 126102.
# 92700 images processed out of 126102.
# 92800 images processed out of 126102.
# 92900 images processed out of 126102.
# 93000 images processed out of 126102.
# 93100 images processed out of 126102.
# 93200 images processed out of 126102.
# 93300 images processed out of 126102.
# 93400 images processed out of 126102.
# 93500 images processed out of 126102.
# 93600 images processed out of 126102.
# 93700 images processed out of 126102.
# 93800 images processed out of 126102.
# 93900 images processed out of 126102.
# 94000 images processed out of 126102.
# 94100 images processed out of 126102.
# 94200 images processed out of 126102.
# 94300 images processed out of 126102.
# 94400 images processed out of 126102.
# 94500 images processed out of 126102.
# 94600 images processed out of 126102.
# 94700 images processed out of 126102.
# 94800 images processed out of 126102.
# 94900 images processed out of 126102.
# 95000 images processed out of 126102.
# 95100 images processed out of 126102.
# 95200 images processed out of 126102.
# 95300 images processed out of 126102.
# 95400 images processed out of 126102.
# 95500 images processed out of 126102.
# 95600 images processed out of 126102.
# 95700 images processed out of 126102.
# 95800 images processed out of 126102.
# 95900 images processed out of 126102.
# 96000 images processed out of 126102.
# 96100 images processed out of 126102.
# 96200 images processed out of 126102.
# 96300 images processed out of 126102.
# 96400 images processed out of 126102.
# 96500 images processed out of 126102.
# 96600 images processed out of 126102.
# 96700 images processed out of 126102.
# 96800 images processed out of 126102.
# 96900 images processed out of 126102.
# 97000 images processed out of 126102.
# 97100 images processed out of 126102.
# 97200 images processed out of 126102.
# 97300 images processed out of 126102.
# 97400 images processed out of 126102.
# 97500 images processed out of 126102.
# 97600 images processed out of 126102.
# 97700 images processed out of 126102.
# 97800 images processed out of 126102.
# 97900 images processed out of 126102.
# 98000 images processed out of 126102.
# 98100 images processed out of 126102.
# 98200 images processed out of 126102.
# 98300 images processed out of 126102.
# 98400 images processed out of 126102.
# 98500 images processed out of 126102.
# 98600 images processed out of 126102.
# 98700 images processed out of 126102.
# 98800 images processed out of 126102.
# 98900 images processed out of 126102.
# 99000 images processed out of 126102.
# 99100 images processed out of 126102.
# 99200 images processed out of 126102.
# 99300 images processed out of 126102.
# 99400 images processed out of 126102.
# 99500 images processed out of 126102.
# 99600 images processed out of 126102.
# 99700 images processed out of 126102.
# 99800 images processed out of 126102.
# 99900 images processed out of 126102.
# 100000 images processed out of 126102.
# 100100 images processed out of 126102.
# 100200 images processed out of 126102.
# 100300 images processed out of 126102.
# 100400 images processed out of 126102.
# 100500 images processed out of 126102.
# 100600 images processed out of 126102.
# 100700 images processed out of 126102.
# 100800 images processed out of 126102.
# 100900 images processed out of 126102.
# 101000 images processed out of 126102.
# 101100 images processed out of 126102.
# 101200 images processed out of 126102.
# 101300 images processed out of 126102.
# 101400 images processed out of 126102.
# 101500 images processed out of 126102.
# 101600 images processed out of 126102.
# 101700 images processed out of 126102.
# 101800 images processed out of 126102.
# 101900 images processed out of 126102.
# 102000 images processed out of 126102.
# 102100 images processed out of 126102.
# 102200 images processed out of 126102.
# 102300 images processed out of 126102.
# 102400 images processed out of 126102.
# 102500 images processed out of 126102.
# 102600 images processed out of 126102.
# 102700 images processed out of 126102.
# 102800 images processed out of 126102.
# 102900 images processed out of 126102.
# 103000 images processed out of 126102.
# 103100 images processed out of 126102.
# 103200 images processed out of 126102.
# 103300 images processed out of 126102.
# 103400 images processed out of 126102.
# 103500 images processed out of 126102.
# 103600 images processed out of 126102.
# 103700 images processed out of 126102.
# 103800 images processed out of 126102.
# 103900 images processed out of 126102.
# 104000 images processed out of 126102.
# 104100 images processed out of 126102.
# 104200 images processed out of 126102.
# 104300 images processed out of 126102.
# 104400 images processed out of 126102.
# 104500 images processed out of 126102.
# 104600 images processed out of 126102.
# 104700 images processed out of 126102.
# 104800 images processed out of 126102.
# 104900 images processed out of 126102.
# 105000 images processed out of 126102.
# 105100 images processed out of 126102.
# 105200 images processed out of 126102.
# 105300 images processed out of 126102.
# 105400 images processed out of 126102.
# 105500 images processed out of 126102.
# 105600 images processed out of 126102.
# 105700 images processed out of 126102.
# 105800 images processed out of 126102.
# 105900 images processed out of 126102.
# 106000 images processed out of 126102.
# 106100 images processed out of 126102.
# 106200 images processed out of 126102.
# 106300 images processed out of 126102.
# 106400 images processed out of 126102.
# 106500 images processed out of 126102.
# 106600 images processed out of 126102.
# 106700 images processed out of 126102.
# 106800 images processed out of 126102.
# 106900 images processed out of 126102.
# 107000 images processed out of 126102.
# 107100 images processed out of 126102.
# 107200 images processed out of 126102.
# 107300 images processed out of 126102.
# 107400 images processed out of 126102.
# 107500 images processed out of 126102.
# 107600 images processed out of 126102.
# 107700 images processed out of 126102.
# 107800 images processed out of 126102.
# 107900 images processed out of 126102.
# 108000 images processed out of 126102.
# 108100 images processed out of 126102.
# 108200 images processed out of 126102.
# 108300 images processed out of 126102.
# 108400 images processed out of 126102.
# 108500 images processed out of 126102.
# 108600 images processed out of 126102.
# 108700 images processed out of 126102.
# 108800 images processed out of 126102.
# 108900 images processed out of 126102.
# 109000 images processed out of 126102.
# 109100 images processed out of 126102.
# 109200 images processed out of 126102.
# 109300 images processed out of 126102.
# 109400 images processed out of 126102.
# 109500 images processed out of 126102.
# 109600 images processed out of 126102.
# 109700 images processed out of 126102.
# 109800 images processed out of 126102.
# 109900 images processed out of 126102.
# 110000 images processed out of 126102.
# 110100 images processed out of 126102.
# 110200 images processed out of 126102.
# 110300 images processed out of 126102.
# 110400 images processed out of 126102.
# 110500 images processed out of 126102.
# 110600 images processed out of 126102.
# 110700 images processed out of 126102.
# 110800 images processed out of 126102.
# 110900 images processed out of 126102.
# 111000 images processed out of 126102.
# 111100 images processed out of 126102.
# 111200 images processed out of 126102.
# 111300 images processed out of 126102.
# 111400 images processed out of 126102.
# 111500 images processed out of 126102.
# 111600 images processed out of 126102.
# 111700 images processed out of 126102.
# 111800 images processed out of 126102.
# 111900 images processed out of 126102.
# 112000 images processed out of 126102.
# 112100 images processed out of 126102.
# 112200 images processed out of 126102.
# 112300 images processed out of 126102.
# 112400 images processed out of 126102.
# 112500 images processed out of 126102.
# 112600 images processed out of 126102.
# 112700 images processed out of 126102.
# 112800 images processed out of 126102.
# 112900 images processed out of 126102.
# 113000 images processed out of 126102.
# 113100 images processed out of 126102.
# 113200 images processed out of 126102.
# 113300 images processed out of 126102.
# 113400 images processed out of 126102.
# 113500 images processed out of 126102.
# 113600 images processed out of 126102.
# 113700 images processed out of 126102.
# 113800 images processed out of 126102.
# 113900 images processed out of 126102.
# 114000 images processed out of 126102.
# 114100 images processed out of 126102.
# 114200 images processed out of 126102.
# 114300 images processed out of 126102.
# 114400 images processed out of 126102.
# 114500 images processed out of 126102.
# 114600 images processed out of 126102.
# 114700 images processed out of 126102.
# 114800 images processed out of 126102.
# 114900 images processed out of 126102.
# 115000 images processed out of 126102.
# 115100 images processed out of 126102.
# 115200 images processed out of 126102.
# 115300 images processed out of 126102.
# 115400 images processed out of 126102.
# 115500 images processed out of 126102.
# 115600 images processed out of 126102.
# 115700 images processed out of 126102.
# 115800 images processed out of 126102.
# 115900 images processed out of 126102.
# 116000 images processed out of 126102.
# 116100 images processed out of 126102.
# 116200 images processed out of 126102.
# 116300 images processed out of 126102.
# 116400 images processed out of 126102.
# 116500 images processed out of 126102.
# 116600 images processed out of 126102.
# 116700 images processed out of 126102.
# 116800 images processed out of 126102.
# 116900 images processed out of 126102.
# 117000 images processed out of 126102.
# 117100 images processed out of 126102.
# 117200 images processed out of 126102.
# 117300 images processed out of 126102.
# 117400 images processed out of 126102.
# 117500 images processed out of 126102.
# 117600 images processed out of 126102.
# 117700 images processed out of 126102.
# 117800 images processed out of 126102.
# 117900 images processed out of 126102.
# 118000 images processed out of 126102.
# 118100 images processed out of 126102.
# 118200 images processed out of 126102.
# 118300 images processed out of 126102.
# 118400 images processed out of 126102.
# 118500 images processed out of 126102.
# 118600 images processed out of 126102.
# 118700 images processed out of 126102.
# 118800 images processed out of 126102.
# 118900 images processed out of 126102.
# 119000 images processed out of 126102.
# 119100 images processed out of 126102.
# 119200 images processed out of 126102.
# 119300 images processed out of 126102.
# 119400 images processed out of 126102.
# 119500 images processed out of 126102.
# 119600 images processed out of 126102.
# 119700 images processed out of 126102.
# 119800 images processed out of 126102.
# 119900 images processed out of 126102.
# 120000 images processed out of 126102.
# 120100 images processed out of 126102.
# 120200 images processed out of 126102.
# 120300 images processed out of 126102.
# 120400 images processed out of 126102.
# 120500 images processed out of 126102.
# 120600 images processed out of 126102.
# 120700 images processed out of 126102.
# 120800 images processed out of 126102.
# 120900 images processed out of 126102.
# 121000 images processed out of 126102.
# 121100 images processed out of 126102.
# 121200 images processed out of 126102.
# 121300 images processed out of 126102.
# 121400 images processed out of 126102.
# 121500 images processed out of 126102.
# 121600 images processed out of 126102.
# 121700 images processed out of 126102.
# 121800 images processed out of 126102.
# 121900 images processed out of 126102.
# 122000 images processed out of 126102.
# 122100 images processed out of 126102.
# 122200 images processed out of 126102.
# 122300 images processed out of 126102.
# 122400 images processed out of 126102.
# 122500 images processed out of 126102.
# 122600 images processed out of 126102.
# 122700 images processed out of 126102.
# 122800 images processed out of 126102.
# 122900 images processed out of 126102.
# 123000 images processed out of 126102.
# 123100 images processed out of 126102.
# 123200 images processed out of 126102.
# 123300 images processed out of 126102.
# 123400 images processed out of 126102.
# 123500 images processed out of 126102.
# 123600 images processed out of 126102.
# 123700 images processed out of 126102.
# 123800 images processed out of 126102.
# 123900 images processed out of 126102.
# 124000 images processed out of 126102.
# 124100 images processed out of 126102.
# 124200 images processed out of 126102.
# 124300 images processed out of 126102.
# 124400 images processed out of 126102.
# 124500 images processed out of 126102.
# 124600 images processed out of 126102.
# 124700 images processed out of 126102.
# 124800 images processed out of 126102.
# 124900 images processed out of 126102.
# 125000 images processed out of 126102.
# 125100 images processed out of 126102.
# 125200 images processed out of 126102.
# 125300 images processed out of 126102.
# 125400 images processed out of 126102.
# 125500 images processed out of 126102.
# 125600 images processed out of 126102.
# 125700 images processed out of 126102.
# 125800 images processed out of 126102.
# 125900 images processed out of 126102.
# 126000 images processed out of 126102.
# 126100 images processed out of 126102.

# %%
idx2mid = {}
for item in label_map.item:
    idx2mid[item.id] = item.name

# %%
for imgid in det_results:
    det_results[imgid]['detection_boxes'] = det_results[imgid]['detection_boxes'][:,[1,0,3,2]]
    det_results[imgid]['detection_boxes_normalized'] = np.copy(det_results[imgid]['detection_boxes'])
    det_results[imgid]['detection_boxes'] = (det_results[imgid]['detection_boxes'] * np.asarray(image_shape[imgid]*2)).astype('int32')

# %%
det_results_2 = {}
for imgid in det_results:
    det_results_2[imgid] = []
    for ii in range(det_results[imgid]['num_detections']):
        if det_results[imgid]['detection_classes'][ii] == 0 or det_results[imgid]['detection_scores'][ii] == 0:
            continue
        det_results_2[imgid].append({
            'label': idx2mid[det_results[imgid]['detection_classes'][ii]],
            'score': det_results[imgid]['detection_scores'][ii],
            'bbox': det_results[imgid]['detection_boxes'][ii],
            'bbox_normalized': det_results[imgid]['detection_boxes_normalized'][ii],
            'model': 'inception-resnet-faster-rcnn-oi'
        })

# %%
with open('../../results/det_results_imsitu_oi_1.pkl', 'wb') as fout:
    pickle.dump(det_results_2, fout)

# %%
with open('../../../model_fusion/temp/image_shapes_imsitu.pkl', 'wb') as fout:
    pickle.dump(image_shape, fout)

# %%
with open('../../../wsod/metadata/ont_m18/oi600_to_m18.pkl', 'rb') as fin:
    label_map = pickle.load(fin)

# %%
det_results_filtered = {}
for key, val in det_results_2.items():
    det_results_filtered[key] = []
    for det in val:
        label = label_map.get(det['label'])
        if label == None:
            continue
        det_results_filtered[key].append({
            'label': label,
            'score': det['score'],
            'bbox': det['bbox'],
            'bbox_normalized': det['bbox_normalized'],
            'model': det['model'],            
        })

# %%
with open('../../results/det_results_m18_dryrun_jpg_oi_1_filtered.pkl', 'wb') as fout:
    pickle.dump(det_results_filtered, fout)
