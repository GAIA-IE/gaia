# %% [markdown]
# # Object Detection Demo
# Welcome to the object detection inference walkthrough!  This notebook will walk you step by step through the process of using a pre-trained model to detect objects in an image. Make sure to follow the [installation instructions](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/installation.md) before you start.

# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("../../lib")
from object_detection.utils import ops as utils_ops

if tf.__version__ < '1.4.0':
  raise ImportError('Please upgrade your tensorflow installation to v1.4.* or later!')

# %%
import pickle
import cv2
import csv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ## Env setup

# %%
# This is needed to display the images.
# %matplotlib inline

# %% [markdown]
# ## Object detection imports
# Here are the imports from the object detection module.

# %%
from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util
# Out:
# ../../lib/object_detection/utils/visualization_utils.py:25: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/tornado/ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2909, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-0f0a85121700>", line 2, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3051, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   import matplotlib; matplotlib.use('Agg')  # pylint: disable=multiple-statements

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Variables
#
# Any model exported using the `export_inference_graph.py` tool can be loaded here simply by changing `PATH_TO_CKPT` to point to a new .pb file.
#
# By default we use an "SSD with Mobilenet" model here. See the [detection model zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md) for a list of other models that can be run out-of-the-box with varying speeds and accuracies.

# %%
# What model to download.
MODEL_NAME = '../../checkpoints/faster_rcnn_inception_resnet_v2_atrous_oid'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('../../lib/object_detection/data', 'oid_bbox_trainable_label_map.pbtxt')

NUM_CLASSES = 600

# %% [markdown]
# ## Load a (frozen) Tensorflow model into memory.

# %%
od_graph_def = tf.GraphDef()
with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# %% [markdown]
# ## Loading label map
# Label maps map indices to category names, so that when our convolution network predicts `5`, we know that this corresponds to `airplane`.  Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine

# %%
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %% [markdown]
# ## Helper code

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Data Preparation

# %%
keyframe_vid_id_to_seedling_vid_id = {}
seedling_vid_id_to_keyframe_vid_id = {}
keyframe_img_filename_to_seedling_img_id = {}
seedling_img_id_to_keyframe_img_filename = {}

with open('../../../../data/background/keyframes/msb.txt', 'r') as fin:
    for line in fin:
        row = line.split()

        keyframe_vid_id = row[0]
        seedling_vid_id = row[1].split('_')[0]
        
        keyframe_vid_id_to_seedling_vid_id[keyframe_vid_id] = seedling_vid_id
        seedling_vid_id_to_keyframe_vid_id[seedling_vid_id] = keyframe_vid_id
        
        seedling_img_id = row[1]
        keyframe_img_filename = row[0] + '_' + seedling_img_id.split('_')[-1] + '.png'
        
        keyframe_img_filename_to_seedling_img_id[keyframe_img_filename] = seedling_img_id
        seedling_img_id_to_keyframe_img_filename[seedling_img_id] = keyframe_img_filename

# %%
with open('../../../../data/background/keyframes/keyframes/keyframes.txt', 'r') as fin:
    test_img_subpaths = [line.strip() for line in fin]

# %%
seedling_img_id_to_keyframe_img_path = {}
for i, item in enumerate(test_img_subpaths):
    keyframe_img_filename = item.split('/')[-1]
    if keyframe_img_filename in keyframe_img_filename_to_seedling_img_id:
        seedling_img_id_to_keyframe_img_path[keyframe_img_filename_to_seedling_img_id[keyframe_img_filename]] = item

# %% [markdown]
# # Detection

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
def run_inference_for_single_image(image):
  # Get handles to input and output tensors
  ops = tf.get_default_graph().get_operations()
  all_tensor_names = {output.name for op in ops for output in op.outputs}
  tensor_dict = {}
  for key in [
      'num_detections', 'detection_boxes', 'detection_scores',
      'detection_classes', 'detection_masks'
  ]:
    tensor_name = key + ':0'
    if tensor_name in all_tensor_names:
      tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
          tensor_name)
  if 'detection_masks' in tensor_dict:
    # The following processing is only for single image
    detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
    detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
    # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
    real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
    detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
    detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
    detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
        detection_masks, detection_boxes, image.shape[0], image.shape[1])
    detection_masks_reframed = tf.cast(
        tf.greater(detection_masks_reframed, 0.5), tf.uint8)
    # Follow the convention by adding back the batch dimension
    tensor_dict['detection_masks'] = tf.expand_dims(
        detection_masks_reframed, 0)
  image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

  # Run inference
  output_dict = sess.run(tensor_dict,
                         feed_dict={image_tensor: np.expand_dims(image, 0)})

  # all outputs are float32 numpy arrays, so convert types as appropriate
  output_dict['num_detections'] = int(output_dict['num_detections'][0])
  output_dict['detection_classes'] = output_dict[
      'detection_classes'][0].astype(np.uint8)
  output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
  output_dict['detection_scores'] = output_dict['detection_scores'][0]
  if 'detection_masks' in output_dict:
        output_dict['detection_masks'] = output_dict['detection_masks'][0]
  return output_dict

# %%
det_results = {}
image_shape = {}
num_imgs = len(seedling_img_id_to_keyframe_img_path)
for i, imgid in enumerate(seedling_img_id_to_keyframe_img_path):
    imgpath = '../../../../data/background/keyframes/keyframes/' + seedling_img_id_to_keyframe_img_path[imgid]
    try:
        with open(imgpath, 'rb') as fin:
            #_ = fin.read(1024)
            imgbin = fin.read()
        imgbgr = cv2.imdecode(np.fromstring(imgbin, dtype='uint8'), cv2.IMREAD_COLOR)
        image_np = imgbgr[:,:,[2,1,0]]
        image_shape[imgid] = (image_np.shape[1], image_np.shape[0])
    except Exception as ex:
        print(filename)
        print(ex)
        continue
    
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np)
    
    det_results[imgid] = output_dict
    
    if i % 100 == 0:
        print(f'{i} images processed out of {num_imgs}.')
# Out:
# /home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/__main__.py:10: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
# 0 images processed out of 53203.
# 100 images processed out of 53203.
# 200 images processed out of 53203.
# 300 images processed out of 53203.
# 400 images processed out of 53203.
# 500 images processed out of 53203.
# 600 images processed out of 53203.
# 700 images processed out of 53203.
# 800 images processed out of 53203.
# 900 images processed out of 53203.
# 1000 images processed out of 53203.
# 1100 images processed out of 53203.
# 1200 images processed out of 53203.
# 1300 images processed out of 53203.
# 1400 images processed out of 53203.
# 1500 images processed out of 53203.
# 1600 images processed out of 53203.
# 1700 images processed out of 53203.
# 1800 images processed out of 53203.
# 1900 images processed out of 53203.
# 2000 images processed out of 53203.
# 2100 images processed out of 53203.
# 2200 images processed out of 53203.
# 2300 images processed out of 53203.
# 2400 images processed out of 53203.
# 2500 images processed out of 53203.
# 2600 images processed out of 53203.
# 2700 images processed out of 53203.
# 2800 images processed out of 53203.
# 2900 images processed out of 53203.
# 3000 images processed out of 53203.
# 3100 images processed out of 53203.
# 3200 images processed out of 53203.
# 3300 images processed out of 53203.
# 3400 images processed out of 53203.
# 3500 images processed out of 53203.
# 3600 images processed out of 53203.
# 3700 images processed out of 53203.
# 3800 images processed out of 53203.
# 3900 images processed out of 53203.
# 4000 images processed out of 53203.
# 4100 images processed out of 53203.
# 4200 images processed out of 53203.
# 4300 images processed out of 53203.
# 4400 images processed out of 53203.
# 4500 images processed out of 53203.
# 4600 images processed out of 53203.
# 4700 images processed out of 53203.
# 4800 images processed out of 53203.
# 4900 images processed out of 53203.
# 5000 images processed out of 53203.
# 5100 images processed out of 53203.
# 5200 images processed out of 53203.
# 5300 images processed out of 53203.
# 5400 images processed out of 53203.
# 5500 images processed out of 53203.
# 5600 images processed out of 53203.
# 5700 images processed out of 53203.
# 5800 images processed out of 53203.
# 5900 images processed out of 53203.
# 6000 images processed out of 53203.
# 6100 images processed out of 53203.
# 6200 images processed out of 53203.
# 6300 images processed out of 53203.
# 6400 images processed out of 53203.
# 6500 images processed out of 53203.
# 6600 images processed out of 53203.
# 6700 images processed out of 53203.
# 6800 images processed out of 53203.
# 6900 images processed out of 53203.
# 7000 images processed out of 53203.
# 7100 images processed out of 53203.
# 7200 images processed out of 53203.
# 7300 images processed out of 53203.
# 7400 images processed out of 53203.
# 7500 images processed out of 53203.
# 7600 images processed out of 53203.
# 7700 images processed out of 53203.
# 7800 images processed out of 53203.
# 7900 images processed out of 53203.
# 8000 images processed out of 53203.
# 8100 images processed out of 53203.
# 8200 images processed out of 53203.
# 8300 images processed out of 53203.
# 8400 images processed out of 53203.
# 8500 images processed out of 53203.
# 8600 images processed out of 53203.
# 8700 images processed out of 53203.
# 8800 images processed out of 53203.
# 8900 images processed out of 53203.
# 9000 images processed out of 53203.
# 9100 images processed out of 53203.
# 9200 images processed out of 53203.
# 9300 images processed out of 53203.
# 9400 images processed out of 53203.
# 9500 images processed out of 53203.
# 9600 images processed out of 53203.
# 9700 images processed out of 53203.
# 9800 images processed out of 53203.
# 9900 images processed out of 53203.
# 10000 images processed out of 53203.
# 10100 images processed out of 53203.
# 10200 images processed out of 53203.
# 10300 images processed out of 53203.
# 10400 images processed out of 53203.
# 10500 images processed out of 53203.
# 10600 images processed out of 53203.
# 10700 images processed out of 53203.
# 10800 images processed out of 53203.
# 10900 images processed out of 53203.
# 11000 images processed out of 53203.
# 11100 images processed out of 53203.
# 11200 images processed out of 53203.
# 11300 images processed out of 53203.
# 11400 images processed out of 53203.
# 11500 images processed out of 53203.
# 11600 images processed out of 53203.
# 11700 images processed out of 53203.
# 11800 images processed out of 53203.
# 11900 images processed out of 53203.
# 12000 images processed out of 53203.
# 12100 images processed out of 53203.
# 12200 images processed out of 53203.
# 12300 images processed out of 53203.
# 12400 images processed out of 53203.
# 12500 images processed out of 53203.
# 12600 images processed out of 53203.
# 12700 images processed out of 53203.
# 12800 images processed out of 53203.
# 12900 images processed out of 53203.
# 13000 images processed out of 53203.
# 13100 images processed out of 53203.
# 13200 images processed out of 53203.
# 13300 images processed out of 53203.
# 13400 images processed out of 53203.
# 13500 images processed out of 53203.
# 13600 images processed out of 53203.
# 13700 images processed out of 53203.
# 13800 images processed out of 53203.
# 13900 images processed out of 53203.
# 14000 images processed out of 53203.
# 14100 images processed out of 53203.
# 14200 images processed out of 53203.
# 14300 images processed out of 53203.
# 14400 images processed out of 53203.
# 14500 images processed out of 53203.
# 14600 images processed out of 53203.
# 14700 images processed out of 53203.
# 14800 images processed out of 53203.
# 14900 images processed out of 53203.
# 15000 images processed out of 53203.
# 15100 images processed out of 53203.
# 15200 images processed out of 53203.
# 15300 images processed out of 53203.
# 15400 images processed out of 53203.
# 15500 images processed out of 53203.
# 15600 images processed out of 53203.
# 15700 images processed out of 53203.
# 15800 images processed out of 53203.
# 15900 images processed out of 53203.
# 16000 images processed out of 53203.
# 16100 images processed out of 53203.
# 16200 images processed out of 53203.
# 16300 images processed out of 53203.
# 16400 images processed out of 53203.
# 16500 images processed out of 53203.
# 16600 images processed out of 53203.
# 16700 images processed out of 53203.
# 16800 images processed out of 53203.
# 16900 images processed out of 53203.
# 17000 images processed out of 53203.
# 17100 images processed out of 53203.
# 17200 images processed out of 53203.
# 17300 images processed out of 53203.
# 17400 images processed out of 53203.
# 17500 images processed out of 53203.
# 17600 images processed out of 53203.
# 17700 images processed out of 53203.
# 17800 images processed out of 53203.
# 17900 images processed out of 53203.
# 18000 images processed out of 53203.
# 18100 images processed out of 53203.
# 18200 images processed out of 53203.
# 18300 images processed out of 53203.
# 18400 images processed out of 53203.
# 18500 images processed out of 53203.
# 18600 images processed out of 53203.
# 18700 images processed out of 53203.
# 18800 images processed out of 53203.
# 18900 images processed out of 53203.
# 19000 images processed out of 53203.
# 19100 images processed out of 53203.
# 19200 images processed out of 53203.
# 19300 images processed out of 53203.
# 19400 images processed out of 53203.
# 19500 images processed out of 53203.
# 19600 images processed out of 53203.
# 19700 images processed out of 53203.
# 19800 images processed out of 53203.
# 19900 images processed out of 53203.
# 20000 images processed out of 53203.
# 20100 images processed out of 53203.
# 20200 images processed out of 53203.
# 20300 images processed out of 53203.
# 20400 images processed out of 53203.
# 20500 images processed out of 53203.
# 20600 images processed out of 53203.
# 20700 images processed out of 53203.
# 20800 images processed out of 53203.
# 20900 images processed out of 53203.
# 21000 images processed out of 53203.
# 21100 images processed out of 53203.
# 21200 images processed out of 53203.
# 21300 images processed out of 53203.
# 21400 images processed out of 53203.
# 21500 images processed out of 53203.
# 21600 images processed out of 53203.
# 21700 images processed out of 53203.
# 21800 images processed out of 53203.
# 21900 images processed out of 53203.
# 22000 images processed out of 53203.
# 22100 images processed out of 53203.
# 22200 images processed out of 53203.
# 22300 images processed out of 53203.
# 22400 images processed out of 53203.
# 22500 images processed out of 53203.
# 22600 images processed out of 53203.
# 22700 images processed out of 53203.
# 22800 images processed out of 53203.
# 22900 images processed out of 53203.
# 23000 images processed out of 53203.
# 23100 images processed out of 53203.
# 23200 images processed out of 53203.
# 23300 images processed out of 53203.
# 23400 images processed out of 53203.
# 23500 images processed out of 53203.
# 23600 images processed out of 53203.
# 23700 images processed out of 53203.
# 23800 images processed out of 53203.
# 23900 images processed out of 53203.
# 24000 images processed out of 53203.
# 24100 images processed out of 53203.
# 24200 images processed out of 53203.
# 24300 images processed out of 53203.
# 24400 images processed out of 53203.
# 24500 images processed out of 53203.
# 24600 images processed out of 53203.
# 24700 images processed out of 53203.
# 24800 images processed out of 53203.
# 24900 images processed out of 53203.
# 25000 images processed out of 53203.
# 25100 images processed out of 53203.
# 25200 images processed out of 53203.
# 25300 images processed out of 53203.
# 25400 images processed out of 53203.
# 25500 images processed out of 53203.
# 25600 images processed out of 53203.
# 25700 images processed out of 53203.
# 25800 images processed out of 53203.
# 25900 images processed out of 53203.
# 26000 images processed out of 53203.
# 26100 images processed out of 53203.
# 26200 images processed out of 53203.
# 26300 images processed out of 53203.
# 26400 images processed out of 53203.
# 26500 images processed out of 53203.
# 26600 images processed out of 53203.
# 26700 images processed out of 53203.
# 26800 images processed out of 53203.
# 26900 images processed out of 53203.
# 27000 images processed out of 53203.
# 27100 images processed out of 53203.
# 27200 images processed out of 53203.
# 27300 images processed out of 53203.
# 27400 images processed out of 53203.
# 27500 images processed out of 53203.
# 27600 images processed out of 53203.
# 27700 images processed out of 53203.
# 27800 images processed out of 53203.
# 27900 images processed out of 53203.
# 28000 images processed out of 53203.
# 28100 images processed out of 53203.
# 28200 images processed out of 53203.
# 28300 images processed out of 53203.
# 28400 images processed out of 53203.
# 28500 images processed out of 53203.
# 28600 images processed out of 53203.
# 28700 images processed out of 53203.
# 28800 images processed out of 53203.
# 28900 images processed out of 53203.
# 29000 images processed out of 53203.
# 29100 images processed out of 53203.
# 29200 images processed out of 53203.
# 29300 images processed out of 53203.
# 29400 images processed out of 53203.
# 29500 images processed out of 53203.
# 29600 images processed out of 53203.
# 29700 images processed out of 53203.
# 29800 images processed out of 53203.
# 29900 images processed out of 53203.
# 30000 images processed out of 53203.
# 30100 images processed out of 53203.
# 30200 images processed out of 53203.
# 30300 images processed out of 53203.
# 30400 images processed out of 53203.
# 30500 images processed out of 53203.
# 30600 images processed out of 53203.
# 30700 images processed out of 53203.
# 30800 images processed out of 53203.
# 30900 images processed out of 53203.
# 31000 images processed out of 53203.
# 31100 images processed out of 53203.
# 31200 images processed out of 53203.
# 31300 images processed out of 53203.
# 31400 images processed out of 53203.
# 31500 images processed out of 53203.
# 31600 images processed out of 53203.
# 31700 images processed out of 53203.
# 31800 images processed out of 53203.
# 31900 images processed out of 53203.
# 32000 images processed out of 53203.
# 32100 images processed out of 53203.
# 32200 images processed out of 53203.
# 32300 images processed out of 53203.
# 32400 images processed out of 53203.
# 32500 images processed out of 53203.
# 32600 images processed out of 53203.
# 32700 images processed out of 53203.
# 32800 images processed out of 53203.
# 32900 images processed out of 53203.
# 33000 images processed out of 53203.
# 33100 images processed out of 53203.
# 33200 images processed out of 53203.
# 33300 images processed out of 53203.
# 33400 images processed out of 53203.
# 33500 images processed out of 53203.
# 33600 images processed out of 53203.
# 33700 images processed out of 53203.
# 33800 images processed out of 53203.
# 33900 images processed out of 53203.
# 34000 images processed out of 53203.
# 34100 images processed out of 53203.
# 34200 images processed out of 53203.
# 34300 images processed out of 53203.
# 34400 images processed out of 53203.
# 34500 images processed out of 53203.
# 34600 images processed out of 53203.
# 34700 images processed out of 53203.
# 34800 images processed out of 53203.
# 34900 images processed out of 53203.
# 35000 images processed out of 53203.
# 35100 images processed out of 53203.
# 35200 images processed out of 53203.
# 35300 images processed out of 53203.
# 35400 images processed out of 53203.
# 35500 images processed out of 53203.
# 35600 images processed out of 53203.
# 35700 images processed out of 53203.
# 35800 images processed out of 53203.
# 35900 images processed out of 53203.
# 36000 images processed out of 53203.
# 36100 images processed out of 53203.
# 36200 images processed out of 53203.
# 36300 images processed out of 53203.
# 36400 images processed out of 53203.
# 36500 images processed out of 53203.
# 36600 images processed out of 53203.
# 36700 images processed out of 53203.
# 36800 images processed out of 53203.
# 36900 images processed out of 53203.
# 37000 images processed out of 53203.
# 37100 images processed out of 53203.
# 37200 images processed out of 53203.
# 37300 images processed out of 53203.
# 37400 images processed out of 53203.
# 37500 images processed out of 53203.
# 37600 images processed out of 53203.
# 37700 images processed out of 53203.
# 37800 images processed out of 53203.
# 37900 images processed out of 53203.
# 38000 images processed out of 53203.
# 38100 images processed out of 53203.
# 38200 images processed out of 53203.
# 38300 images processed out of 53203.
# 38400 images processed out of 53203.
# 38500 images processed out of 53203.
# 38600 images processed out of 53203.
# 38700 images processed out of 53203.
# 38800 images processed out of 53203.
# 38900 images processed out of 53203.
# 39000 images processed out of 53203.
# 39100 images processed out of 53203.
# 39200 images processed out of 53203.
# 39300 images processed out of 53203.
# 39400 images processed out of 53203.
# 39500 images processed out of 53203.
# 39600 images processed out of 53203.
# 39700 images processed out of 53203.
# 39800 images processed out of 53203.
# 39900 images processed out of 53203.
# 40000 images processed out of 53203.
# 40100 images processed out of 53203.
# 40200 images processed out of 53203.
# 40300 images processed out of 53203.
# 40400 images processed out of 53203.
# 40500 images processed out of 53203.
# 40600 images processed out of 53203.
# 40700 images processed out of 53203.
# 40800 images processed out of 53203.
# 40900 images processed out of 53203.
# 41000 images processed out of 53203.
# 41100 images processed out of 53203.
# 41200 images processed out of 53203.
# 41300 images processed out of 53203.
# 41400 images processed out of 53203.
# 41500 images processed out of 53203.
# 41600 images processed out of 53203.
# 41700 images processed out of 53203.
# 41800 images processed out of 53203.
# 41900 images processed out of 53203.
# 42000 images processed out of 53203.
# 42100 images processed out of 53203.
# 42200 images processed out of 53203.
# 42300 images processed out of 53203.
# 42400 images processed out of 53203.
# 42500 images processed out of 53203.
# 42600 images processed out of 53203.
# 42700 images processed out of 53203.
# 42800 images processed out of 53203.
# 42900 images processed out of 53203.
# 43000 images processed out of 53203.
# 43100 images processed out of 53203.
# 43200 images processed out of 53203.
# 43300 images processed out of 53203.
# 43400 images processed out of 53203.
# 43500 images processed out of 53203.
# 43600 images processed out of 53203.
# 43700 images processed out of 53203.
# 43800 images processed out of 53203.
# 43900 images processed out of 53203.
# 44000 images processed out of 53203.
# 44100 images processed out of 53203.
# 44200 images processed out of 53203.
# 44300 images processed out of 53203.
# 44400 images processed out of 53203.
# 44500 images processed out of 53203.
# 44600 images processed out of 53203.
# 44700 images processed out of 53203.
# 44800 images processed out of 53203.
# 44900 images processed out of 53203.
# 45000 images processed out of 53203.
# 45100 images processed out of 53203.
# 45200 images processed out of 53203.
# 45300 images processed out of 53203.
# 45400 images processed out of 53203.
# 45500 images processed out of 53203.
# 45600 images processed out of 53203.
# 45700 images processed out of 53203.
# 45800 images processed out of 53203.
# 45900 images processed out of 53203.
# 46000 images processed out of 53203.
# 46100 images processed out of 53203.
# 46200 images processed out of 53203.
# 46300 images processed out of 53203.
# 46400 images processed out of 53203.
# 46500 images processed out of 53203.
# 46600 images processed out of 53203.
# 46700 images processed out of 53203.
# 46800 images processed out of 53203.
# 46900 images processed out of 53203.
# 47000 images processed out of 53203.
# 47100 images processed out of 53203.
# 47200 images processed out of 53203.
# 47300 images processed out of 53203.
# 47400 images processed out of 53203.
# 47500 images processed out of 53203.
# 47600 images processed out of 53203.
# 47700 images processed out of 53203.
# 47800 images processed out of 53203.
# 47900 images processed out of 53203.
# 48000 images processed out of 53203.
# 48100 images processed out of 53203.
# 48200 images processed out of 53203.
# 48300 images processed out of 53203.
# 48400 images processed out of 53203.
# 48500 images processed out of 53203.
# 48600 images processed out of 53203.
# 48700 images processed out of 53203.
# 48800 images processed out of 53203.
# 48900 images processed out of 53203.
# 49000 images processed out of 53203.
# 49100 images processed out of 53203.
# 49200 images processed out of 53203.
# 49300 images processed out of 53203.
# 49400 images processed out of 53203.
# 49500 images processed out of 53203.
# 49600 images processed out of 53203.
# 49700 images processed out of 53203.
# 49800 images processed out of 53203.
# 49900 images processed out of 53203.
# 50000 images processed out of 53203.
# 50100 images processed out of 53203.
# 50200 images processed out of 53203.
# 50300 images processed out of 53203.
# 50400 images processed out of 53203.
# 50500 images processed out of 53203.
# 50600 images processed out of 53203.
# 50700 images processed out of 53203.
# 50800 images processed out of 53203.
# 50900 images processed out of 53203.
# 51000 images processed out of 53203.
# 51100 images processed out of 53203.
# 51200 images processed out of 53203.
# 51300 images processed out of 53203.
# 51400 images processed out of 53203.
# 51500 images processed out of 53203.
# 51600 images processed out of 53203.
# 51700 images processed out of 53203.
# 51800 images processed out of 53203.
# 51900 images processed out of 53203.
# 52000 images processed out of 53203.
# 52100 images processed out of 53203.
# 52200 images processed out of 53203.
# 52300 images processed out of 53203.
# 52400 images processed out of 53203.
# 52500 images processed out of 53203.
# 52600 images processed out of 53203.
# 52700 images processed out of 53203.
# 52800 images processed out of 53203.
# 52900 images processed out of 53203.
# 53000 images processed out of 53203.
# 53100 images processed out of 53203.
# 53200 images processed out of 53203.

# %%
idx2mid = {}
for item in label_map.item:
    idx2mid[item.id] = item.name

# %%
for imgid in det_results:
    det_results[imgid]['detection_boxes'] = det_results[imgid]['detection_boxes'][:,[1,0,3,2]]
    det_results[imgid]['detection_boxes_normalized'] = np.copy(det_results[imgid]['detection_boxes'])
    det_results[imgid]['detection_boxes'] = (det_results[imgid]['detection_boxes'] * np.asarray(image_shape[imgid]*2)).astype('int32')

# %%
det_results_2 = {}
for imgid in det_results:
    det_results_2[imgid] = []
    for ii in range(det_results[imgid]['num_detections']):
        if det_results[imgid]['detection_classes'][ii] == 0 or det_results[imgid]['detection_scores'][ii] == 0:
            continue
        det_results_2[imgid].append({
            'label': idx2mid[det_results[imgid]['detection_classes'][ii]],
            'score': det_results[imgid]['detection_scores'][ii],
            'bbox': det_results[imgid]['detection_boxes'][ii],
            'bbox_normalized': det_results[imgid]['detection_boxes_normalized'][ii],
            'model': 'inception-resnet-faster-rcnn-oi'
        })

# %%
with open('../../results/det_results_background_keyframes_oi_2.pkl', 'wb') as fout:
    pickle.dump(det_results_2, fout)

# %%
with open('../../../model_fusion/temp/background_keyframe_imgsize_2.pkl', 'wb') as fout:
    pickle.dump(image_shape, fout)
