# %%
import pickle
import cv2
import os
import numpy as np

# %%
with open('../../results/det_results_combined_oi_coco_ws_2_corrected.pkl', 'rb') as fin:
    det_results = pickle.load(fin)

# %%
imgsize = {}
for imgid in det_results:
    filename = os.path.join('../../../data/seedling/jpg', imgid)
    with open(filename, 'rb') as fin:
        _ = fin.read(1024)
        imgbin = fin.read()
    imgbgr = cv2.imdecode(np.fromstring(imgbin, dtype='uint8'), cv2.IMREAD_COLOR)
    imgsize[imgid] = (imgbgr.shape[1], imgbgr.shape[0])
# Out:
# /home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/__main__.py:7: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
for imgid in det_results:
    det_results[imgid]['detection_boxes_normalized'] = np.copy(det_results[imgid]['detection_boxes'])
    det_results[imgid]['detection_boxes'] = (det_results[imgid]['detection_boxes'] * np.asarray(imgsize[imgid]*2)).astype('int32')

# %%
det_results['HC0000078.jpg.ldcc']
# Out:
# {'detection_classes': ['/m/07s6nbt',
#   '/m/09j2d',
#   '/m/01g317',
#   '/m/09j2d',
#   '/m/01g317',
#   '/m/0dwx7',
#   '/m/04_tb',
#   '/m/09nm_',
#   '/m/07c52',
#   '/m/01knjb',
#   '/m/04hgtk',
#   '/m/04hgtk',
#   '/m/0bh9flk',
#   '/m/0jb3',
#   '/m/032rk',
#   '/m/071rm',
#   '/m/0bh9flk',
#   '/m/0dv5r',
#   '/m/06c54',
#   '/m/0gxl3',
#   '/m/06c54',
#   '/m/05_5t0l',
#   '/m/04h7h',
#   '/m/01n5jq',
#   '/m/038t8_',
#   '/m/015h_t',
#   '/m/03wvy',
#   '/m/083kb',
#   '/m/034qg',
#   '/m/0jbk',
#   '/m/02q3d5',
#   '/m/06nrc',
#   '/m/07cmd',
#   '/m/04yx4',
#   '/m/04hgtk',
#   '/m/04yx4',
#   '/m/04rky',
#   '/m/04rky',
#   '/m/02p0tk3',
#   '/m/02p0tk3',
#   '/m/0dzct',
#   '/m/0bt_c3',
#   '/m/03bt1vf',
#   '/m/04hgtk',
#   '/m/06z37_',
#   '/m/03bt1vf',
#   '/m/02d9qx'],
#  'detection_scores': [1.0,
#   0.7438925,
#   0.63556397,
#   0.61646515,
#   0.5807669,
#   0.512358537181107,
#   0.4515857936618277,
#   0.4224452503066674,
#   0.4117151444196135,
#   0.2938584760172855,
#   0.2703470383523987,
#   0.26676407456572027,
#   0.2613043302606697,
#   0.25609180682594823,
#   0.2523859750810458,
#   0.2515210517175822,
#   0.23933126170500688,
#   0.23157837976420126,
#   0.2311069931300902,
#   0.22972671412711443,
#   0.2293508339784252,
#   0.22844677968510851,
#   0.226401279664804,
#   0.22546592,
#   0.2199436559320222,
#   0.21058247792471568,
#   0.21026253742577847,
#   0.20966660148243613,
#   0.2095547509239749,
#   0.20216691136361362,
#   0.20046227053127416,
#   0.20039804388083096,
#   0.19739571861743296,
#   0.09026254,
#   0.032147035,
#   0.029647129,
#   0.02582116,
#   0.023534441,
#   0.0069096456,
#   0.006324734,
#   0.0045815357,
#   0.0031069536,
#   0.0026738634,
#   0.0024245884,
#   0.0019997684,
#   0.00166509,
#   0.001361395],
#  'detection_boxes': array([[ 96,  28, 477, 215],
#         [256,  11, 385,  89],
#         [ 71,  14, 219,  91],
#         [ 80,  13, 210,  94],
#         [240,  15, 386,  86],
#         [  0, 118, 227, 358],
#         [  0,   0, 477, 358],
#         [ 36,  69, 229, 278],
#         [  0,   0, 461, 360],
#         [ 36, 117, 201, 358],
#         [  0,  69, 270, 266],
#         [310,  61, 477, 186],
#         [295,   0, 477, 183],
#         [  0,  56, 197, 329],
#         [  0,   0, 477, 358],
#         [ 53,  91, 205, 358],
#         [  0, 112, 192, 358],
#         [  0, 180, 180, 266],
#         [  0, 171, 184, 358],
#         [  0, 133, 214, 302],
#         [  0,  53, 182, 104],
#         [ 92,  85, 278, 220],
#         [ 49,  90, 225, 265],
#         [  0,  42, 434, 336],
#         [ 55, 104, 207, 286],
#         [252,  72, 477, 202],
#         [  0, 109, 184, 282],
#         [  0,  61, 345, 308],
#         [  0,  64, 218, 358],
#         [  0,   0, 477, 261],
#         [  0,  45, 477, 215],
#         [  0,  48, 302, 358],
#         [  0,  49, 477, 305],
#         [242,  10, 381,  93],
#         [ 69,  37, 111,  67],
#         [ 75,  10, 209,  96],
#         [ 73,  10, 207,  93],
#         [244,  12, 375,  91],
#         [235,  11, 384,  92],
#         [ 63,  11, 223,  97],
#         [ 69,  36, 111,  68],
#         [  0,  10, 464, 360],
#         [ 68,   9, 217, 101],
#         [245,  34, 292,  68],
#         [ 55,  36, 443, 311],
#         [233,   5, 385,  94],
#         [  0,  20, 432, 349]], dtype=int32),
#  'detection_models': ['ws',
#   'oi',
#   'oi/J',
#   'oi',
#   'oi/J',
#   'ws',
#   'ws',
#   'ws',
#   'coco/J',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'oi/J',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'oi',
#   'oi',
#   'oi',
#   'oi',
#   'oi',
#   'oi',
#   'oi',
#   'oi/J',
#   'oi',
#   'oi',
#   'oi',
#   'oi',
#   'oi',
#   'oi'],
#  'num_detections': 47,
#  'detection_boxes_normalized': array([[0.20089286, 0.08035714, 0.99553571, 0.59821429],
#         [0.53455532, 0.03331798, 0.80336821, 0.24933238],
#         [0.14819801, 0.04139208, 0.45666474, 0.25289786],
#         [0.16821624, 0.0370432 , 0.43939486, 0.2636039 ],
#         [0.50135893, 0.04362926, 0.8051064 , 0.2405079 ],
#         [0.        , 0.33035714, 0.47321429, 0.99553571],
#         [0.        , 0.        , 0.99553571, 0.99553571],
#         [0.07589286, 0.19196429, 0.47767857, 0.77232143],
#         [0.        , 0.        , 0.9624939 , 1.        ],
#         [0.07589286, 0.32589286, 0.41964286, 0.99553571],
#         [0.        , 0.19196429, 0.5625    , 0.74107143],
#         [0.64732143, 0.16964286, 0.99553571, 0.51785714],
#         [0.61607143, 0.        , 0.99553571, 0.50892857],
#         [0.        , 0.15625   , 0.41071429, 0.91517857],
#         [0.        , 0.        , 0.99553571, 0.99553571],
#         [0.11160714, 0.25446429, 0.42857143, 0.99553571],
#         [0.        , 0.3125    , 0.40178571, 0.99553571],
#         [0.        , 0.5       , 0.375     , 0.74107143],
#         [0.        , 0.47767857, 0.38392857, 0.99553571],
#         [0.        , 0.37053571, 0.44642857, 0.83928571],
#         [0.        , 0.14732143, 0.37946429, 0.29017857],
#         [0.19196429, 0.23660714, 0.58035714, 0.61160714],
#         [0.10267857, 0.25      , 0.46875   , 0.73660714],
#         [0.        , 0.11802658, 0.90513921, 0.93430889],
#         [0.11607143, 0.29017857, 0.43303571, 0.79464286],
#         [0.52678571, 0.20089286, 0.99553571, 0.5625    ],
#         [0.        , 0.30357143, 0.38392857, 0.78571429],
#         [0.        , 0.16964286, 0.71875   , 0.85714286],
#         [0.        , 0.17857143, 0.45535714, 0.99553571],
#         [0.        , 0.        , 0.99553571, 0.72767857],
#         [0.        , 0.125     , 0.99553571, 0.59821429],
#         [0.        , 0.13392857, 0.62946429, 0.99553571],
#         [0.        , 0.13839286, 0.99553571, 0.84821429],
#         [0.50447404, 0.02854332, 0.79465848, 0.25861359],
#         [0.14412765, 0.10291656, 0.23166613, 0.18651602],
#         [0.15670647, 0.02891758, 0.43744832, 0.26732466],
#         [0.15364864, 0.02970127, 0.43201891, 0.25891846],
#         [0.5099768 , 0.03558542, 0.78165591, 0.25439575],
#         [0.49121374, 0.03243113, 0.80088794, 0.25556949],
#         [0.13171096, 0.03164743, 0.46498236, 0.2713834 ],
#         [0.14558803, 0.10234312, 0.23229627, 0.1903263 ],
#         [0.        , 0.02997013, 0.96718222, 1.        ],
#         [0.14301752, 0.0277403 , 0.45291713, 0.28099748],
#         [0.51141828, 0.0967753 , 0.61041534, 0.19067304],
#         [0.1145871 , 0.1008498 , 0.92294466, 0.86515957],
#         [0.48740184, 0.01661093, 0.80315512, 0.26259598],
#         [0.        , 0.0558881 , 0.90189606, 0.96950102]])}

# %%
with open('../../results/det_results_combined_oi_coco_ws_2_post_corrected.pkl', 'wb') as fout:
    pickle.dump(det_results, fout)
