# %%
import pickle
import cv2
import os
import numpy as np

# %%
with open('../../results/det_results_combined_oi_coco_ws_6.pkl', 'rb') as fin:
    det_results = pickle.load(fin)

# %%
imgsize = {}
for imgid in det_results:
    filename = os.path.join('../../../data/seedling/jpg', imgid)
    with open(filename, 'rb') as fin:
        _ = fin.read(1024)
        imgbin = fin.read()
    imgbgr = cv2.imdecode(np.fromstring(imgbin, dtype='uint8'), cv2.IMREAD_COLOR)
    imgsize[imgid] = (imgbgr.shape[1], imgbgr.shape[0])
# Out:
# /home/alireza/home_at_filer2/tools/anaconda3/envs/py3tf/lib/python3.6/site-packages/ipykernel/__main__.py:7: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
for imgid in det_results:
    det_results[imgid]['detection_boxes_normalized'] = np.copy(det_results[imgid]['detection_boxes'])
    det_results[imgid]['detection_boxes'] = (det_results[imgid]['detection_boxes'] * np.asarray(imgsize[imgid]*2)).astype('int32')

# %%
det_results['IC0011WYB.jpg.ldcc']
# Out:
# {'detection_classes': ['/m/0fly7',
#   '/m/0gxl3',
#   '/m/0k65p',
#   '/m/01g317',
#   '/m/014trl',
#   '/m/0lt4_',
#   '/m/06nrc',
#   '/m/083kb',
#   '/m/04ctx',
#   '/m/02gzp',
#   '/m/02rdsp',
#   '/m/034qg',
#   '/m/0ct4f',
#   '/m/032rk',
#   '/m/06c54',
#   '/m/0dv5r',
#   '/m/027qh7f',
#   '/m/0bs7_0t',
#   '/m/01xgg_',
#   '/m/050k8',
#   '/m/01nl4x',
#   '/m/071rm',
#   '/m/02p16m6',
#   '/m/0169zh',
#   '/m/04_x4',
#   '/m/0hg7b',
#   '/m/06y5r',
#   '/m/0fd6q',
#   '/m/02wbm',
#   '/m/0bh9flk',
#   '/m/0jb3',
#   '/m/07cx4',
#   '/m/0c2jj',
#   '/m/0bg2p',
#   '/m/035y33',
#   '/m/02_n6y',
#   '/m/0ytgt',
#   '/m/020kz',
#   '/m/013bml',
#   '/m/09jfs',
#   '/m/0dzct',
#   '/m/016c4t',
#   '/m/04hgtk',
#   '/m/09g5pq',
#   '/m/06q40',
#   '/m/015h_t',
#   '/m/0dzf4',
#   '/m/05r655',
#   '/m/0463sg',
#   '/m/0jyfg',
#   '/m/07k1x',
#   '/m/039xj_',
#   '/m/083kb',
#   '/m/01tcjp',
#   '/m/0138tl',
#   '/m/0hg7b',
#   '/m/06c54',
#   '/m/04yx4',
#   '/m/078n6m',
#   '/m/0dv5r',
#   '/m/02p0tk3',
#   '/m/04rky',
#   '/m/09j2d',
#   '/m/03bt1vf',
#   '/m/0b3fp9',
#   '/m/0d4v4'],
#  'detection_scores': [0.8584707,
#   0.7655040474598366,
#   0.44725877,
#   0.4118608685128769,
#         [ 65,  35, 306, 310],
#         [268, 158, 528, 343],
#         [  0,   0, 696, 464],
#         [180,   4, 593, 407],
#         [240, 161, 367, 257],
#         [208, 167, 363, 330],
#         [212, 155, 361, 368],
#         [224, 140, 370, 326],
#         [228, 138, 378, 357],
#         [200, 131, 374, 358],
#         [213, 143, 384, 337],
#         [201, 175, 374, 328],
#         [221, 167, 375, 336],
#         [203, 122, 402, 373],
#         [ 87,   0, 566, 437],
#         [208, 143, 382, 363],
#         [217, 164, 364, 343],
#         [ 88,   0, 601, 427],
#         [ 84,   0, 552, 454],
#         [ 72,   4, 591, 396],
#         [ 71,  16, 570, 403],
#         [177, 123, 353, 359],
#         [221, 155, 359, 358]], dtype=int32),
#  'detection_models': ['oi/J',
#   'ws',
#   'oi/J',
#   'coco/J',
#   'oi/J',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'oi/J',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'ws',
#   'oi/J',
#   'oi/J',
#   'oi/J',
#   'oi/J',
#   'oi/J',
#   'oi/J',
#   'oi/J',
#   'oi/J',
#   'oi',
#   'oi/J',
#   'oi',
#   'oi',
#   'oi',
#   'oi',
#   'oi/J',
#   'oi',
#   'oi/J',
#   'oi',
#   'oi',
#   'oi'],
#  'num_detections': 66,
#  'detection_boxes_normalized': array([[0.31053621, 0.36993048, 0.51614678, 0.70161867],
#         [0.39732143, 0.32142857, 0.71428571, 0.66517857],
#         [0.18523405, 0.01072002, 0.77521372, 0.43960413],
#         [0.07130903, 0.        , 0.89771986, 0.88194031],
#         [0.33749309, 0.34645301, 0.51263291, 0.58033556],
#         [0.41517857, 0.3125    , 0.79464286, 0.6875    ],
#         [0.39732143, 0.3125    , 0.70535714, 0.65178571],
#         [0.375     , 0.31696429, 0.70982143, 0.64285714],
#         [0.33482143, 0.33035714, 0.66964286, 0.62053571],
#         [0.36160714, 0.32589286, 0.71875   , 0.65625   ],
#         [0.31920016, 0.33259693, 0.53160399, 0.74042273],
#         [0.41964286, 0.32142857, 0.70535714, 0.63839286],
#         [0.39732143, 0.31696429, 0.72767857, 0.65625   ],
#         [0.40625   , 0.32142857, 0.71875   , 0.64285714],
#         [0.40625   , 0.30803571, 0.71875   , 0.63839286],
#         [0.41071429, 0.29017857, 0.79464286, 0.67857143],
#         [0.36160714, 0.30803571, 0.71875   , 0.64732143],
#         [0.30357143, 0.3125    , 0.69196429, 0.65178571],
#         [0.25446429, 0.33035714, 0.67410714, 0.66964286],
#         [0.20089286, 0.33928571, 0.79910714, 0.6875    ],
#         [0.37053571, 0.30357143, 0.70982143, 0.67410714],
#         [0.40625   , 0.31696429, 0.75446429, 0.64732143],
#         [0.13392857, 0.29910714, 0.6875    , 0.78571429],
#         [0.16517857, 0.33928571, 0.79017857, 0.69196429],
#         [0.12053571, 0.33035714, 0.99553571, 0.73214286],
#         [0.36160714, 0.28125   , 0.65178571, 0.60714286],
#         [0.35267857, 0.3125    , 0.71428571, 0.65178571],
#         [0.125     , 0.33482143, 0.45535714, 0.63839286],
#         [0.15178571, 0.33928571, 0.70089286, 0.70982143],
#         [0.20535714, 0.32142857, 0.68303571, 0.63839286],
#         [0.41964286, 0.27678571, 0.77232143, 0.63839286],
#         [0.25892857, 0.32142857, 0.71875   , 0.69642857],
#         [0.25      , 0.20982143, 0.59821429, 0.57589286],
#         [0.38392857, 0.26339286, 0.76339286, 0.6875    ],
#         [0.15625   , 0.        , 0.57142857, 0.41071429],
#         [0.32589286, 0.31696429, 0.80803571, 0.73214286],
#         [0.12053571, 0.30803571, 0.46875   , 0.65178571],
#         [0.41517857, 0.31696429, 0.71875   , 0.59821429],
#         [0.35267857, 0.28571429, 0.65178571, 0.60714286],
#         [0.1875    , 0.13839286, 0.70089286, 0.66071429],
#         [0.        , 0.12053571, 0.3125    , 0.71428571],
#         [0.33928571, 0.33928571, 0.71875   , 0.70982143],
#         [0.        , 0.20089286, 0.99553571, 0.88392857],
#         [0.09375   , 0.07589286, 0.4375    , 0.66517857],
#         [0.38392857, 0.33928571, 0.75446429, 0.73660714],
#         [0.        , 0.        , 0.99553571, 0.99553571],
#         [0.2579717 , 0.01030832, 0.84830415, 0.87230545],
#         [0.34369498, 0.34604213, 0.52462173, 0.55184746],
#         [0.298435  , 0.35907546, 0.5188868 , 0.70825613],
#         [0.30415756, 0.33285788, 0.516976  , 0.78909928],
#         [0.32009226, 0.30050963, 0.5287177 , 0.69814044],
#         [0.32713756, 0.29617372, 0.54055291, 0.76614153],
#         [0.28707373, 0.28230938, 0.53435349, 0.76787674],
#         [0.30555654, 0.30666351, 0.54873353, 0.72242129],
#         [0.28839406, 0.37616989, 0.53456402, 0.70417863],
#         [0.31711686, 0.35938781, 0.53613168, 0.72126204],
#         [0.29136378, 0.26264468, 0.57484567, 0.7999981 ],
#         [0.12565982, 0.        , 0.8092742 , 0.93587011],
#         [0.29724449, 0.30640504, 0.54635787, 0.77873039],
#         [0.31078485, 0.35321662, 0.52089328, 0.73497272],
#         [0.12598071, 0.        , 0.85963565, 0.91465706],
#         [0.12106817, 0.        , 0.78874344, 0.97272116],
#         [0.10325592, 0.00971138, 0.84494746, 0.84834516],
#         [0.10244988, 0.03563754, 0.81447357, 0.86307335],
#         [0.25408667, 0.26488617, 0.5056361 , 0.77045882],
#         [0.31654587, 0.33384609, 0.51342028, 0.76829422]])}

# %%
with open('../../results/det_results_combined_oi_coco_ws_6_post.pkl', 'wb') as fout:
    pickle.dump(det_results, fout)
