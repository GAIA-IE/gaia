# %%
exp_name = 'dpl_015'

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import torch
import torch.nn as nn
import torchvision
from torch.autograd import Variable
from torch.nn import functional as F

import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
import pickle
import csv
import os
import time
import datetime
import lmdb

from skimage.feature import peak_local_max
import scipy
from scipy import ndimage as ndi
from multiprocessing import Pool

# %%
def save_obj(obj, name ):
    with open( name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open( name + '.pkl', 'rb') as f:
        return pickle.load(f)

now = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
logfile = open(f'../../log/{exp_name}.txt', 'a')
logfile.write(f'\n\n\n\n ----------------- {now} ----------------- \n\n')
logfile.flush()
def log(string, stdout=True):
    if stdout:
        print(string)
    logfile.write(string + '\n')
    logfile.flush()

# %%
with open('../../metadata/ont_300/300_joined_list.csv', 'r') as fin:
    all_labels = [item.strip() for item in fin]
all_labels.append('background')
    
label2idx = {}
for i, l in enumerate(all_labels):
    label2idx[l] = i

# %%
with open('../../../../data/background/my_keyframes/keyframes-0.2.txt', 'r') as fin:
    test_img_ids = [line.strip() for line in fin]

# %%
resnet = torchvision.models.resnet152() # resnet.eval() is very important, do not forget this line during testing!
print(resnet.fc)
resnet.fc = nn.Linear(2048, len(all_labels)-1)
#saved_state_dict = torch.load(os.path.join('data/snapshots/','d2_rel_open_1600.pth'))
saved_state_dict = torch.load(os.path.join('../../snapshots', 'train_015', 'ckpt_5000'))
resnet.load_state_dict(saved_state_dict)
resnet.cuda(0)
resnet.eval()
resnet.float()
# Out:
# Linear(in_features=2048, out_features=1000, bias=True)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=2048, out_features=283, bias=True)
# )

# %%
finalconv_name = 'layer4'

# hook the feature extractor
features_blobs = []
def hook_feature(module, input, output):
    features_blobs.append(output.data.cpu().numpy())

resnet._modules.get(finalconv_name).register_forward_hook(hook_feature)

# get the softmax weight
params = list(resnet.parameters())
weight_softmax = np.squeeze(params[-2].cpu().data.numpy())

# %%
batch_size = 100
model_output = {}
batch = []
batch_keys = []
for i, imgid in enumerate(test_img_ids):
    filename = os.path.join('../../../../data/background/my_keyframes', imgid)
    try:
        with open(filename, 'rb') as fin:
            # _ = fin.read(1024)
            imgbin = fin.read()
        imgbgr = cv2.imdecode(np.fromstring(imgbin, dtype='uint8'), cv2.IMREAD_COLOR)
        imgbgr = cv2.resize(imgbgr, (224, 224))
        imgrgb = imgbgr[:,:,[2,1,0]]        
        assert(imgrgb.shape[0] == 224 and imgrgb.shape[1] == 224 and imgrgb.shape[2] == 3)
    except Exception as ex:
        log(str(ex))
        continue
    
    imgrgb = imgrgb.astype(float)/255.0
    
    imgrgb[:,:,0] = (imgrgb[:,:,0] - 0.485)/0.229
    imgrgb[:,:,1] = (imgrgb[:,:,1] - 0.456)/0.224
    imgrgb[:,:,2] = (imgrgb[:,:,2] - 0.406)/0.225

    imgrgb = imgrgb.transpose((2,0,1))
    batch.append(imgrgb)
    batch_keys.append(imgid)
    
    if len(batch) == batch_size or (i + 1) == len(test_img_ids):
        batch = np.stack(batch)
    
        features_blobs = []
        
        with torch.no_grad():
            inp = torch.from_numpy(batch).float().cuda(0)
            outputs = resnet(inp)
            outputs = torch.cat([outputs, torch.ones(batch.shape[0], 1).cuda(0)], dim=1)
            h_x = F.softmax(outputs).data.squeeze()
            class_probs, class_idx = h_x.sort(1, True)
            class_idx = np.asarray(class_idx)
            class_probs = np.asarray(class_probs)
        
        for ii in range(len(batch_keys)):
            model_output[batch_keys[ii]] = {
                'features_blobs': features_blobs[0][ii],
                'sorted_labels': class_idx[ii],
                'sorted_probs': class_probs[ii],                
            }
        
        batch = []
        batch_keys = []
        log(f'Processed {i + 1} out of {len(test_img_ids)} images.')
# Out:
# /home/alireza/home_at_filer2/tools/anaconda3/envs/py3torch/lib/python3.6/site-packages/ipykernel/__main__.py:11: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
# /home/alireza/home_at_filer2/tools/anaconda3/envs/py3torch/lib/python3.6/site-packages/ipykernel/__main__.py:38: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Processed 100 out of 41187 images.
# Processed 200 out of 41187 images.
# Processed 300 out of 41187 images.
# Processed 400 out of 41187 images.
# Processed 500 out of 41187 images.
# Processed 600 out of 41187 images.
# Processed 700 out of 41187 images.
# Processed 800 out of 41187 images.
# Processed 900 out of 41187 images.
# Processed 1000 out of 41187 images.
# Processed 1100 out of 41187 images.
# Processed 1200 out of 41187 images.
# Processed 1300 out of 41187 images.
# Processed 1400 out of 41187 images.
# Processed 1500 out of 41187 images.
# Processed 1600 out of 41187 images.
# Processed 1700 out of 41187 images.
# Processed 1800 out of 41187 images.
# Processed 1900 out of 41187 images.
# Processed 2000 out of 41187 images.
# Processed 2100 out of 41187 images.
# Processed 2200 out of 41187 images.
# Processed 2300 out of 41187 images.
# Processed 2400 out of 41187 images.
# Processed 2500 out of 41187 images.
# Processed 2600 out of 41187 images.
# Processed 2700 out of 41187 images.
# Processed 2800 out of 41187 images.
# Processed 2900 out of 41187 images.
# Processed 3000 out of 41187 images.
# Processed 3100 out of 41187 images.
# Processed 3200 out of 41187 images.
# Processed 3300 out of 41187 images.
# Processed 3400 out of 41187 images.
# Processed 3500 out of 41187 images.
# Processed 3600 out of 41187 images.
# Processed 3700 out of 41187 images.
# Processed 3800 out of 41187 images.
# Processed 3900 out of 41187 images.
# Processed 4000 out of 41187 images.
# Processed 4100 out of 41187 images.
# Processed 4200 out of 41187 images.
# Processed 4300 out of 41187 images.
# Processed 4400 out of 41187 images.
# Processed 4500 out of 41187 images.
# Processed 4600 out of 41187 images.
# Processed 4700 out of 41187 images.
# Processed 4800 out of 41187 images.
# Processed 4900 out of 41187 images.
# Processed 5000 out of 41187 images.
# Processed 5100 out of 41187 images.
# Processed 5200 out of 41187 images.
# Processed 5300 out of 41187 images.
# Processed 5400 out of 41187 images.
# Processed 5500 out of 41187 images.
# Processed 5600 out of 41187 images.
# Processed 5700 out of 41187 images.
# Processed 5800 out of 41187 images.
# Processed 5900 out of 41187 images.
# Processed 6000 out of 41187 images.
# Processed 6100 out of 41187 images.
# Processed 6200 out of 41187 images.
# Processed 6300 out of 41187 images.
# Processed 6400 out of 41187 images.
# Processed 6500 out of 41187 images.
# Processed 6600 out of 41187 images.
# Processed 6700 out of 41187 images.
# Processed 6800 out of 41187 images.
# Processed 6900 out of 41187 images.
# Processed 7000 out of 41187 images.
# Processed 7100 out of 41187 images.
# Processed 7200 out of 41187 images.
# Processed 7300 out of 41187 images.
# Processed 7400 out of 41187 images.
# Processed 7500 out of 41187 images.
# Processed 7600 out of 41187 images.
# Processed 7700 out of 41187 images.
# Processed 7800 out of 41187 images.
# Processed 7900 out of 41187 images.
# Processed 8000 out of 41187 images.
# Processed 8100 out of 41187 images.
# Processed 8200 out of 41187 images.
# Processed 8300 out of 41187 images.
# Processed 8400 out of 41187 images.
# Processed 8500 out of 41187 images.
# Processed 8600 out of 41187 images.
# Processed 8700 out of 41187 images.
# Processed 8800 out of 41187 images.
# Processed 8900 out of 41187 images.
# Processed 9000 out of 41187 images.
# Processed 9100 out of 41187 images.
# Processed 9200 out of 41187 images.
# Processed 9300 out of 41187 images.
# Processed 9400 out of 41187 images.
# Processed 9500 out of 41187 images.
# Processed 9600 out of 41187 images.
# Processed 9700 out of 41187 images.
# Processed 9800 out of 41187 images.
# Processed 9900 out of 41187 images.
# Processed 10000 out of 41187 images.
# Processed 10100 out of 41187 images.
# Processed 10200 out of 41187 images.
# Processed 10300 out of 41187 images.
# Processed 10400 out of 41187 images.
# Processed 10500 out of 41187 images.
# Processed 10600 out of 41187 images.
# Processed 10700 out of 41187 images.
# Processed 10800 out of 41187 images.
# Processed 10900 out of 41187 images.
# Processed 11000 out of 41187 images.
# Processed 11100 out of 41187 images.
# Processed 11200 out of 41187 images.
# Processed 11300 out of 41187 images.
# Processed 11400 out of 41187 images.
# Processed 11500 out of 41187 images.
# Processed 11600 out of 41187 images.
# Processed 11700 out of 41187 images.
# Processed 11800 out of 41187 images.
# Processed 11900 out of 41187 images.
# Processed 12000 out of 41187 images.
# Processed 12100 out of 41187 images.
# Processed 12200 out of 41187 images.
# Processed 12300 out of 41187 images.
# Processed 12400 out of 41187 images.
# Processed 12500 out of 41187 images.
# Processed 12600 out of 41187 images.
# Processed 12700 out of 41187 images.
# Processed 12800 out of 41187 images.
# Processed 12900 out of 41187 images.
# Processed 13000 out of 41187 images.
# Processed 13100 out of 41187 images.
# Processed 13200 out of 41187 images.
# Processed 13300 out of 41187 images.
# Processed 13400 out of 41187 images.
# Processed 13500 out of 41187 images.
# Processed 13600 out of 41187 images.
# Processed 13700 out of 41187 images.
# Processed 13800 out of 41187 images.
# Processed 13900 out of 41187 images.
# Processed 14000 out of 41187 images.
# Processed 14100 out of 41187 images.
# Processed 14200 out of 41187 images.
# Processed 14300 out of 41187 images.
# Processed 14400 out of 41187 images.
# Processed 14500 out of 41187 images.
# Processed 14600 out of 41187 images.
# Processed 14700 out of 41187 images.
# Processed 14800 out of 41187 images.
# Processed 14900 out of 41187 images.
# Processed 15000 out of 41187 images.
# Processed 15100 out of 41187 images.
# Processed 15200 out of 41187 images.
# Processed 15300 out of 41187 images.
# Processed 15400 out of 41187 images.
# Processed 15500 out of 41187 images.
# Processed 15600 out of 41187 images.
# Processed 15700 out of 41187 images.
# Processed 15800 out of 41187 images.
# Processed 15900 out of 41187 images.
# Processed 16000 out of 41187 images.
# Processed 16100 out of 41187 images.
# Processed 16200 out of 41187 images.
# Processed 16300 out of 41187 images.
# Processed 16400 out of 41187 images.
# Processed 16500 out of 41187 images.
# Processed 16600 out of 41187 images.
# Processed 16700 out of 41187 images.
# Processed 16800 out of 41187 images.
# Processed 16900 out of 41187 images.
# Processed 17000 out of 41187 images.
# Processed 17100 out of 41187 images.
# Processed 17200 out of 41187 images.
# Processed 17300 out of 41187 images.
# Processed 17400 out of 41187 images.
# Processed 17500 out of 41187 images.
# Processed 17600 out of 41187 images.
# Processed 17700 out of 41187 images.
# Processed 17800 out of 41187 images.
# Processed 17900 out of 41187 images.
# Processed 18000 out of 41187 images.
# Processed 18100 out of 41187 images.
# Processed 18200 out of 41187 images.
# Processed 18300 out of 41187 images.
# Processed 18400 out of 41187 images.
# Processed 18500 out of 41187 images.
# Processed 18600 out of 41187 images.
# Processed 18700 out of 41187 images.
# Processed 18800 out of 41187 images.
# Processed 18900 out of 41187 images.
# Processed 19000 out of 41187 images.
# Processed 19100 out of 41187 images.
# Processed 19200 out of 41187 images.
# Processed 19300 out of 41187 images.
# Processed 19400 out of 41187 images.
# Processed 19500 out of 41187 images.
# Processed 19600 out of 41187 images.
# Processed 19700 out of 41187 images.
# Processed 19800 out of 41187 images.
# Processed 19900 out of 41187 images.
# Processed 20000 out of 41187 images.
# Processed 20100 out of 41187 images.
# Processed 20200 out of 41187 images.
# Processed 20300 out of 41187 images.
# Processed 20400 out of 41187 images.
# Processed 20500 out of 41187 images.
# Processed 20600 out of 41187 images.
# Processed 20700 out of 41187 images.
# Processed 20800 out of 41187 images.
# Processed 20900 out of 41187 images.
# Processed 21000 out of 41187 images.
# Processed 21100 out of 41187 images.
# Processed 21200 out of 41187 images.
# Processed 21300 out of 41187 images.
# Processed 21400 out of 41187 images.
# Processed 21500 out of 41187 images.
# Processed 21600 out of 41187 images.
# Processed 21700 out of 41187 images.
# Processed 21800 out of 41187 images.
# Processed 21900 out of 41187 images.
# Processed 22000 out of 41187 images.
# Processed 22100 out of 41187 images.
# Processed 22200 out of 41187 images.
# Processed 22300 out of 41187 images.
# Processed 22400 out of 41187 images.
# Processed 22500 out of 41187 images.
# Processed 22600 out of 41187 images.
# Processed 22700 out of 41187 images.
# Processed 22800 out of 41187 images.
# Processed 22900 out of 41187 images.
# Processed 23000 out of 41187 images.
# Processed 23100 out of 41187 images.
# Processed 23200 out of 41187 images.
# Processed 23300 out of 41187 images.
# Processed 23400 out of 41187 images.
# Processed 23500 out of 41187 images.
# Processed 23600 out of 41187 images.
# Processed 23700 out of 41187 images.
# Processed 23800 out of 41187 images.
# Processed 23900 out of 41187 images.
# Processed 24000 out of 41187 images.
# Processed 24100 out of 41187 images.
# Processed 24200 out of 41187 images.
# Processed 24300 out of 41187 images.
# Processed 24400 out of 41187 images.
# Processed 24500 out of 41187 images.
# Processed 24600 out of 41187 images.
# Processed 24700 out of 41187 images.
# Processed 24800 out of 41187 images.
# Processed 24900 out of 41187 images.
# Processed 25000 out of 41187 images.
# Processed 25100 out of 41187 images.
# Processed 25200 out of 41187 images.
# Processed 25300 out of 41187 images.
# Processed 25400 out of 41187 images.
# Processed 25500 out of 41187 images.
# Processed 25600 out of 41187 images.
# Processed 25700 out of 41187 images.
# Processed 25800 out of 41187 images.
# Processed 25900 out of 41187 images.
# Processed 26000 out of 41187 images.
# Processed 26100 out of 41187 images.
# Processed 26200 out of 41187 images.
# Processed 26300 out of 41187 images.
# Processed 26400 out of 41187 images.
# Processed 26500 out of 41187 images.
# Processed 26600 out of 41187 images.
# Processed 26700 out of 41187 images.
# Processed 26800 out of 41187 images.
# Processed 26900 out of 41187 images.
# Processed 27000 out of 41187 images.
# Processed 27100 out of 41187 images.
# Processed 27200 out of 41187 images.
# Processed 27300 out of 41187 images.
# Processed 27400 out of 41187 images.
# Processed 27500 out of 41187 images.
# Processed 27600 out of 41187 images.
# Processed 27700 out of 41187 images.
# Processed 27800 out of 41187 images.
# Processed 27900 out of 41187 images.
# Processed 28000 out of 41187 images.
# Processed 28100 out of 41187 images.
# Processed 28200 out of 41187 images.
# Processed 28300 out of 41187 images.
# Processed 28400 out of 41187 images.
# Processed 28500 out of 41187 images.
# Processed 28600 out of 41187 images.
# Processed 28700 out of 41187 images.
# Processed 28800 out of 41187 images.
# Processed 28900 out of 41187 images.
# Processed 29000 out of 41187 images.
# Processed 29100 out of 41187 images.
# Processed 29200 out of 41187 images.
# Processed 29300 out of 41187 images.
# Processed 29400 out of 41187 images.
# Processed 29500 out of 41187 images.
# Processed 29600 out of 41187 images.
# Processed 29700 out of 41187 images.
# Processed 29800 out of 41187 images.
# Processed 29900 out of 41187 images.
# Processed 30000 out of 41187 images.
# Processed 30100 out of 41187 images.
# Processed 30200 out of 41187 images.
# Processed 30300 out of 41187 images.
# Processed 30400 out of 41187 images.
# Processed 30500 out of 41187 images.
# Processed 30600 out of 41187 images.
# Processed 30700 out of 41187 images.
# Processed 30800 out of 41187 images.
# Processed 30900 out of 41187 images.
# Processed 31000 out of 41187 images.
# Processed 31100 out of 41187 images.
# Processed 31200 out of 41187 images.
# Processed 31300 out of 41187 images.
# Processed 31400 out of 41187 images.
# Processed 31500 out of 41187 images.
# Processed 31600 out of 41187 images.
# Processed 31700 out of 41187 images.
# Processed 31800 out of 41187 images.
# Processed 31900 out of 41187 images.
# Processed 32000 out of 41187 images.
# Processed 32100 out of 41187 images.
# Processed 32200 out of 41187 images.
# Processed 32300 out of 41187 images.
# Processed 32400 out of 41187 images.
# Processed 32500 out of 41187 images.
# Processed 32600 out of 41187 images.
# Processed 32700 out of 41187 images.
# Processed 32800 out of 41187 images.
# Processed 32900 out of 41187 images.
# Processed 33000 out of 41187 images.
# Processed 33100 out of 41187 images.
# Processed 33200 out of 41187 images.
# Processed 33300 out of 41187 images.
# Processed 33400 out of 41187 images.
# Processed 33500 out of 41187 images.
# Processed 33600 out of 41187 images.
# Processed 33700 out of 41187 images.
# Processed 33800 out of 41187 images.
# Processed 33900 out of 41187 images.
# Processed 34000 out of 41187 images.
# Processed 34100 out of 41187 images.
# Processed 34200 out of 41187 images.
# Processed 34300 out of 41187 images.
# Processed 34400 out of 41187 images.
# Processed 34500 out of 41187 images.
# Processed 34600 out of 41187 images.
# Processed 34700 out of 41187 images.
# Processed 34800 out of 41187 images.
# Processed 34900 out of 41187 images.
# Processed 35000 out of 41187 images.
# Processed 35100 out of 41187 images.
# Processed 35200 out of 41187 images.
# Processed 35300 out of 41187 images.
# Processed 35400 out of 41187 images.
# Processed 35500 out of 41187 images.
# Processed 35600 out of 41187 images.
# Processed 35700 out of 41187 images.
# Processed 35800 out of 41187 images.
# Processed 35900 out of 41187 images.
# Processed 36000 out of 41187 images.
# Processed 36100 out of 41187 images.
# Processed 36200 out of 41187 images.
# Processed 36300 out of 41187 images.
# Processed 36400 out of 41187 images.
# Processed 36500 out of 41187 images.
# Processed 36600 out of 41187 images.
# Processed 36700 out of 41187 images.
# Processed 36800 out of 41187 images.
# Processed 36900 out of 41187 images.
# Processed 37000 out of 41187 images.
# Processed 37100 out of 41187 images.
# Processed 37200 out of 41187 images.
# Processed 37300 out of 41187 images.
# Processed 37400 out of 41187 images.
# Processed 37500 out of 41187 images.
# Processed 37600 out of 41187 images.
# Processed 37700 out of 41187 images.
# Processed 37800 out of 41187 images.
# Processed 37900 out of 41187 images.
# Processed 38000 out of 41187 images.
# Processed 38100 out of 41187 images.
# Processed 38200 out of 41187 images.
# Processed 38300 out of 41187 images.
# Processed 38400 out of 41187 images.
# Processed 38500 out of 41187 images.
# Processed 38600 out of 41187 images.
# Processed 38700 out of 41187 images.
# Processed 38800 out of 41187 images.
# Processed 38900 out of 41187 images.
# Processed 39000 out of 41187 images.
# Processed 39100 out of 41187 images.
# Processed 39200 out of 41187 images.
# Processed 39300 out of 41187 images.
# Processed 39400 out of 41187 images.
# Processed 39500 out of 41187 images.
# Processed 39600 out of 41187 images.
# Processed 39700 out of 41187 images.
# Processed 39800 out of 41187 images.
# Processed 39900 out of 41187 images.
# Processed 40000 out of 41187 images.
# Processed 40100 out of 41187 images.
# Processed 40200 out of 41187 images.
# Processed 40300 out of 41187 images.
# Processed 40400 out of 41187 images.
# Processed 40500 out of 41187 images.
# Processed 40600 out of 41187 images.
# Processed 40700 out of 41187 images.
# Processed 40800 out of 41187 images.
# Processed 40900 out of 41187 images.
# Processed 41000 out of 41187 images.
# Processed 41100 out of 41187 images.
# Processed 41187 out of 41187 images.

# %%
ioa_thr = 0.9
topk_boxes = 20
rel_peak_thr = 0.7
rel_rel_thr = 0.7

# %%
def postprocess(imgid):
    features_blob = model_output[imgid]['features_blobs']
    class_idx = model_output[imgid]['sorted_labels']
    class_probs = model_output[imgid]['sorted_probs']
    
    nc, h, w = features_blob.shape
    all_box_coords = []
    all_box_scores = []
    all_box_labels = []

    for ii in range(class_idx.shape[0]):
        if all_labels[class_idx[ii]] == 'background':
            break
        cam = weight_softmax[class_idx[ii]].dot(features_blob.reshape((nc, h*w)))
        cam = cam.reshape(h, w)
        cam = cam - np.min(cam)
        cam = cam / np.max(cam)

        bboxes = []
        box_scores = []

        peak_coords = peak_local_max(cam, exclude_border=False, threshold_rel=rel_peak_thr)

        heat_resized = cv2.resize(cam,(224, 224))
        peak_coords_resized = ((peak_coords + 0.5) * 224 / np.asarray([[h, w]])).astype('int32')

        for pk_coord in peak_coords_resized:
            pk_value = heat_resized[tuple(pk_coord)]
            mask = heat_resized > pk_value * rel_rel_thr
            labeled, n = ndi.label(mask) 
            l = labeled[tuple(pk_coord)]
            yy, xx = np.where(labeled == l)
            min_x = np.min(xx) / 224
            min_y = np.min(yy) / 224
            max_x = np.max(xx) / 224
            max_y = np.max(yy) / 224
            bboxes.append((min_x, min_y, max_x, max_y))
            box_scores.append(pk_value * class_probs[ii])

        box_idx = np.argsort(-np.asarray(box_scores))
        box_idx = box_idx[:min(topk_boxes, len(box_scores))]
        bboxes = [bboxes[i] for i in box_idx]
        box_scores = [box_scores[i] for i in box_idx]

        to_remove = []
        for iii in range(len(bboxes)):
            for iiii in range(iii):
                if iiii in to_remove:
                    continue
                b1 = bboxes[iii]
                b2 = bboxes[iiii]
                isec = max(min(b1[2], b2[2]) - max(b1[0], b2[0]), 0) * max(min(b1[3], b2[3]) - max(b1[1], b2[1]), 0)
                ioa1 = isec / ((b1[2] - b1[0]) * (b1[3] - b1[1]))
                ioa2 = isec / ((b2[2] - b2[0]) * (b2[3] - b2[1]))
                if ioa1 > ioa_thr and ioa1 == ioa2:
                    to_remove.append(iii)
                elif ioa1 > ioa_thr and ioa1 >= ioa2:
                    to_remove.append(iii)
                elif ioa2 > ioa_thr and ioa2 >= ioa1:
                    to_remove.append(iiii)

        for i in range(len(bboxes)): 
            if i not in to_remove:
                all_box_coords.append(bboxes[i])
                all_box_scores.append(box_scores[i])
                all_box_labels.append(class_idx[ii])
    
    
    sort_idx = np.argsort(-np.asarray(all_box_scores))
    sorted_box_coords = [all_box_coords[i] for i in sort_idx]
    sorted_box_scores = [all_box_scores[i] for i in sort_idx]    
    sorted_box_labels = [all_box_labels[i] for i in sort_idx]    
    
    return imgid, {
        'sorted_boxes': sorted_box_coords,
        'sorted_probs': sorted_box_scores,                
        'sorted_labels': sorted_box_labels,                
    }

# %%
det_results = {}
cnt = 0
with Pool(20) as p:
    for i, res in enumerate(p.imap_unordered(postprocess, model_output.keys())):
        key, val = res
        det_results[key] = val
        cnt += 1
        if cnt % 100 == 0:
            print(f'Postprocessed {cnt} out of {len(model_output)} images.')
# Out:
# Postprocessed 100 out of 41187 images.
# Postprocessed 200 out of 41187 images.
# Postprocessed 300 out of 41187 images.
# Postprocessed 400 out of 41187 images.
# Postprocessed 500 out of 41187 images.
# Postprocessed 600 out of 41187 images.
# Postprocessed 700 out of 41187 images.
# Postprocessed 800 out of 41187 images.
# Postprocessed 900 out of 41187 images.
# Postprocessed 1000 out of 41187 images.
# Postprocessed 1100 out of 41187 images.
# Postprocessed 1200 out of 41187 images.
# Postprocessed 1300 out of 41187 images.
# Postprocessed 1400 out of 41187 images.
# Postprocessed 1500 out of 41187 images.
# Postprocessed 1600 out of 41187 images.
# Postprocessed 1700 out of 41187 images.
# Postprocessed 1800 out of 41187 images.
# Postprocessed 1900 out of 41187 images.
# Postprocessed 2000 out of 41187 images.
# Postprocessed 2100 out of 41187 images.
# Postprocessed 2200 out of 41187 images.
# Postprocessed 2300 out of 41187 images.
# Postprocessed 2400 out of 41187 images.
# Postprocessed 2500 out of 41187 images.
# Postprocessed 2600 out of 41187 images.
# Postprocessed 2700 out of 41187 images.
# Postprocessed 2800 out of 41187 images.
# Postprocessed 2900 out of 41187 images.
# Postprocessed 3000 out of 41187 images.
# Postprocessed 3100 out of 41187 images.
# Postprocessed 3200 out of 41187 images.
# Postprocessed 3300 out of 41187 images.
# Postprocessed 3400 out of 41187 images.
# Postprocessed 3500 out of 41187 images.
# Postprocessed 3600 out of 41187 images.
# Postprocessed 3700 out of 41187 images.
# Postprocessed 3800 out of 41187 images.
# Postprocessed 3900 out of 41187 images.
# Postprocessed 4000 out of 41187 images.
# Postprocessed 4100 out of 41187 images.
# Postprocessed 4200 out of 41187 images.
# Postprocessed 4300 out of 41187 images.
# Postprocessed 4400 out of 41187 images.
# Postprocessed 4500 out of 41187 images.
# Postprocessed 4600 out of 41187 images.
# Postprocessed 4700 out of 41187 images.
# Postprocessed 4800 out of 41187 images.
# Postprocessed 4900 out of 41187 images.
# Postprocessed 5000 out of 41187 images.
# Postprocessed 5100 out of 41187 images.
# Postprocessed 5200 out of 41187 images.
# Postprocessed 5300 out of 41187 images.
# Postprocessed 5400 out of 41187 images.
# Postprocessed 5500 out of 41187 images.
# Postprocessed 5600 out of 41187 images.
# Postprocessed 5700 out of 41187 images.
# Postprocessed 5800 out of 41187 images.
# Postprocessed 5900 out of 41187 images.
# Postprocessed 6000 out of 41187 images.
# Postprocessed 6100 out of 41187 images.
# Postprocessed 6200 out of 41187 images.
# Postprocessed 6300 out of 41187 images.
# Postprocessed 6400 out of 41187 images.
# Postprocessed 6500 out of 41187 images.
# Postprocessed 6600 out of 41187 images.
# Postprocessed 6700 out of 41187 images.
# Postprocessed 6800 out of 41187 images.
# Postprocessed 6900 out of 41187 images.
# Postprocessed 7000 out of 41187 images.
# Postprocessed 7100 out of 41187 images.
# Postprocessed 7200 out of 41187 images.
# Postprocessed 7300 out of 41187 images.
# Postprocessed 7400 out of 41187 images.
# Postprocessed 7500 out of 41187 images.
# Postprocessed 7600 out of 41187 images.
# Postprocessed 7700 out of 41187 images.
# Postprocessed 7800 out of 41187 images.
# Postprocessed 7900 out of 41187 images.
# Postprocessed 8000 out of 41187 images.
# Postprocessed 8100 out of 41187 images.
# Postprocessed 8200 out of 41187 images.
# Postprocessed 8300 out of 41187 images.
# Postprocessed 8400 out of 41187 images.
# Postprocessed 8500 out of 41187 images.
# Postprocessed 8600 out of 41187 images.
# Postprocessed 8700 out of 41187 images.
# Postprocessed 8800 out of 41187 images.
# Postprocessed 8900 out of 41187 images.
# Postprocessed 9000 out of 41187 images.
# Postprocessed 9100 out of 41187 images.
# Postprocessed 9200 out of 41187 images.
# Postprocessed 9300 out of 41187 images.
# Postprocessed 9400 out of 41187 images.
# Postprocessed 9500 out of 41187 images.
# Postprocessed 9600 out of 41187 images.
# Postprocessed 9700 out of 41187 images.
# Postprocessed 9800 out of 41187 images.
# Postprocessed 9900 out of 41187 images.
# Postprocessed 10000 out of 41187 images.
# Postprocessed 10100 out of 41187 images.
# Postprocessed 10200 out of 41187 images.
# Postprocessed 10300 out of 41187 images.
# Postprocessed 10400 out of 41187 images.
# Postprocessed 10500 out of 41187 images.
# Postprocessed 10600 out of 41187 images.
# Postprocessed 10700 out of 41187 images.
# Postprocessed 10800 out of 41187 images.
# Postprocessed 10900 out of 41187 images.
# Postprocessed 11000 out of 41187 images.
# Postprocessed 11100 out of 41187 images.
# Postprocessed 11200 out of 41187 images.
# Postprocessed 11300 out of 41187 images.
# Postprocessed 11400 out of 41187 images.
# Postprocessed 11500 out of 41187 images.
# Postprocessed 11600 out of 41187 images.
# Postprocessed 11700 out of 41187 images.
# Postprocessed 11800 out of 41187 images.
# Postprocessed 11900 out of 41187 images.
# Postprocessed 12000 out of 41187 images.
# Postprocessed 12100 out of 41187 images.
# Postprocessed 12200 out of 41187 images.
# Postprocessed 12300 out of 41187 images.
# Postprocessed 12400 out of 41187 images.
# Postprocessed 12500 out of 41187 images.
# Postprocessed 12600 out of 41187 images.
# Postprocessed 12700 out of 41187 images.
# Postprocessed 12800 out of 41187 images.
# Postprocessed 12900 out of 41187 images.
# Postprocessed 13000 out of 41187 images.
# Postprocessed 13100 out of 41187 images.
# Postprocessed 13200 out of 41187 images.
# Postprocessed 13300 out of 41187 images.
# Postprocessed 13400 out of 41187 images.
# Postprocessed 13500 out of 41187 images.
# Postprocessed 13600 out of 41187 images.
# Postprocessed 13700 out of 41187 images.
# Postprocessed 13800 out of 41187 images.
# Postprocessed 13900 out of 41187 images.
# Postprocessed 14000 out of 41187 images.
# Postprocessed 14100 out of 41187 images.
# Postprocessed 14200 out of 41187 images.
# Postprocessed 14300 out of 41187 images.
# Postprocessed 14400 out of 41187 images.
# Postprocessed 14500 out of 41187 images.
# Postprocessed 14600 out of 41187 images.
# Postprocessed 14700 out of 41187 images.
# Postprocessed 14800 out of 41187 images.
# Postprocessed 14900 out of 41187 images.
# Postprocessed 15000 out of 41187 images.
# Postprocessed 15100 out of 41187 images.
# Postprocessed 15200 out of 41187 images.
# Postprocessed 15300 out of 41187 images.
# Postprocessed 15400 out of 41187 images.
# Postprocessed 15500 out of 41187 images.
# Postprocessed 15600 out of 41187 images.
# Postprocessed 15700 out of 41187 images.
# Postprocessed 15800 out of 41187 images.
# Postprocessed 15900 out of 41187 images.
# Postprocessed 16000 out of 41187 images.
# Postprocessed 16100 out of 41187 images.
# Postprocessed 16200 out of 41187 images.
# Postprocessed 16300 out of 41187 images.
# Postprocessed 16400 out of 41187 images.
# Postprocessed 16500 out of 41187 images.
# Postprocessed 16600 out of 41187 images.
# Postprocessed 16700 out of 41187 images.
# Postprocessed 16800 out of 41187 images.
# Postprocessed 16900 out of 41187 images.
# Postprocessed 17000 out of 41187 images.
# Postprocessed 17100 out of 41187 images.
# Postprocessed 17200 out of 41187 images.
# Postprocessed 17300 out of 41187 images.
# Postprocessed 17400 out of 41187 images.
# Postprocessed 17500 out of 41187 images.
# Postprocessed 17600 out of 41187 images.
# Postprocessed 17700 out of 41187 images.
# Postprocessed 17800 out of 41187 images.
# Postprocessed 17900 out of 41187 images.
# Postprocessed 18000 out of 41187 images.
# Postprocessed 18100 out of 41187 images.
# Postprocessed 18200 out of 41187 images.
# Postprocessed 18300 out of 41187 images.
# Postprocessed 18400 out of 41187 images.
# Postprocessed 18500 out of 41187 images.
# Postprocessed 18600 out of 41187 images.
# Postprocessed 18700 out of 41187 images.
# Postprocessed 18800 out of 41187 images.
# Postprocessed 18900 out of 41187 images.
# Postprocessed 19000 out of 41187 images.
# Postprocessed 19100 out of 41187 images.
# Postprocessed 19200 out of 41187 images.
# Postprocessed 19300 out of 41187 images.
# Postprocessed 19400 out of 41187 images.
# Postprocessed 19500 out of 41187 images.
# Postprocessed 19600 out of 41187 images.
# Postprocessed 19700 out of 41187 images.
# Postprocessed 19800 out of 41187 images.
# Postprocessed 19900 out of 41187 images.
# Postprocessed 20000 out of 41187 images.
# Postprocessed 20100 out of 41187 images.
# Postprocessed 20200 out of 41187 images.
# Postprocessed 20300 out of 41187 images.
# Postprocessed 20400 out of 41187 images.
# Postprocessed 20500 out of 41187 images.
# Postprocessed 20600 out of 41187 images.
# Postprocessed 20700 out of 41187 images.
# Postprocessed 20800 out of 41187 images.
# Postprocessed 20900 out of 41187 images.
# Postprocessed 21000 out of 41187 images.
# Postprocessed 21100 out of 41187 images.
# Postprocessed 21200 out of 41187 images.
# Postprocessed 21300 out of 41187 images.
# Postprocessed 21400 out of 41187 images.
# Postprocessed 21500 out of 41187 images.
# Postprocessed 21600 out of 41187 images.
# Postprocessed 21700 out of 41187 images.
# Postprocessed 21800 out of 41187 images.
# Postprocessed 21900 out of 41187 images.
# Postprocessed 22000 out of 41187 images.
# Postprocessed 22100 out of 41187 images.
# Postprocessed 22200 out of 41187 images.
# Postprocessed 22300 out of 41187 images.
# Postprocessed 22400 out of 41187 images.
# Postprocessed 22500 out of 41187 images.
# Postprocessed 22600 out of 41187 images.
# Postprocessed 22700 out of 41187 images.
# Postprocessed 22800 out of 41187 images.
# Postprocessed 22900 out of 41187 images.
# Postprocessed 23000 out of 41187 images.
# Postprocessed 23100 out of 41187 images.
# Postprocessed 23200 out of 41187 images.
# Postprocessed 23300 out of 41187 images.
# Postprocessed 23400 out of 41187 images.
# Postprocessed 23500 out of 41187 images.
# Postprocessed 23600 out of 41187 images.
# Postprocessed 23700 out of 41187 images.
# Postprocessed 23800 out of 41187 images.
# Postprocessed 23900 out of 41187 images.
# Postprocessed 24000 out of 41187 images.
# Postprocessed 24100 out of 41187 images.
# Postprocessed 24200 out of 41187 images.
# Postprocessed 24300 out of 41187 images.
# Postprocessed 24400 out of 41187 images.
# Postprocessed 24500 out of 41187 images.
# Postprocessed 24600 out of 41187 images.
# Postprocessed 24700 out of 41187 images.
# Postprocessed 24800 out of 41187 images.
# Postprocessed 24900 out of 41187 images.
# Postprocessed 25000 out of 41187 images.
# Postprocessed 25100 out of 41187 images.
# Postprocessed 25200 out of 41187 images.
# Postprocessed 25300 out of 41187 images.
# Postprocessed 25400 out of 41187 images.
# Postprocessed 25500 out of 41187 images.
# Postprocessed 25600 out of 41187 images.
# Postprocessed 25700 out of 41187 images.
# Postprocessed 25800 out of 41187 images.
# Postprocessed 25900 out of 41187 images.
# Postprocessed 26000 out of 41187 images.
# Postprocessed 26100 out of 41187 images.
# Postprocessed 26200 out of 41187 images.
# Postprocessed 26300 out of 41187 images.
# Postprocessed 26400 out of 41187 images.
# Postprocessed 26500 out of 41187 images.
# Postprocessed 26600 out of 41187 images.
# Postprocessed 26700 out of 41187 images.
# Postprocessed 26800 out of 41187 images.
# Postprocessed 26900 out of 41187 images.
# Postprocessed 27000 out of 41187 images.
# Postprocessed 27100 out of 41187 images.
# Postprocessed 27200 out of 41187 images.
# Postprocessed 27300 out of 41187 images.
# Postprocessed 27400 out of 41187 images.
# Postprocessed 27500 out of 41187 images.
# Postprocessed 27600 out of 41187 images.
# Postprocessed 27700 out of 41187 images.
# Postprocessed 27800 out of 41187 images.
# Postprocessed 27900 out of 41187 images.
# Postprocessed 28000 out of 41187 images.
# Postprocessed 28100 out of 41187 images.
# Postprocessed 28200 out of 41187 images.
# Postprocessed 28300 out of 41187 images.
# Postprocessed 28400 out of 41187 images.
# Postprocessed 28500 out of 41187 images.
# Postprocessed 28600 out of 41187 images.
# Postprocessed 28700 out of 41187 images.
# Postprocessed 28800 out of 41187 images.
# Postprocessed 28900 out of 41187 images.
# Postprocessed 29000 out of 41187 images.
# Postprocessed 29100 out of 41187 images.
# Postprocessed 29200 out of 41187 images.
# Postprocessed 29300 out of 41187 images.
# Postprocessed 29400 out of 41187 images.
# Postprocessed 29500 out of 41187 images.
# Postprocessed 29600 out of 41187 images.
# Postprocessed 29700 out of 41187 images.
# Postprocessed 29800 out of 41187 images.
# Postprocessed 29900 out of 41187 images.
# Postprocessed 30000 out of 41187 images.
# Postprocessed 30100 out of 41187 images.
# Postprocessed 30200 out of 41187 images.
# Postprocessed 30300 out of 41187 images.
# Postprocessed 30400 out of 41187 images.
# Postprocessed 30500 out of 41187 images.
# Postprocessed 30600 out of 41187 images.
# Postprocessed 30700 out of 41187 images.
# Postprocessed 30800 out of 41187 images.
# Postprocessed 30900 out of 41187 images.
# Postprocessed 31000 out of 41187 images.
# Postprocessed 31100 out of 41187 images.
# Postprocessed 31200 out of 41187 images.
# Postprocessed 31300 out of 41187 images.
# Postprocessed 31400 out of 41187 images.
# Postprocessed 31500 out of 41187 images.
# Postprocessed 31600 out of 41187 images.
# Postprocessed 31700 out of 41187 images.
# Postprocessed 31800 out of 41187 images.
# Postprocessed 31900 out of 41187 images.
# Postprocessed 32000 out of 41187 images.
# Postprocessed 32100 out of 41187 images.
# Postprocessed 32200 out of 41187 images.
# Postprocessed 32300 out of 41187 images.
# Postprocessed 32400 out of 41187 images.
# Postprocessed 32500 out of 41187 images.
# Postprocessed 32600 out of 41187 images.
# Postprocessed 32700 out of 41187 images.
# Postprocessed 32800 out of 41187 images.
# Postprocessed 32900 out of 41187 images.
# Postprocessed 33000 out of 41187 images.
# Postprocessed 33100 out of 41187 images.
# Postprocessed 33200 out of 41187 images.
# Postprocessed 33300 out of 41187 images.
# Postprocessed 33400 out of 41187 images.
# Postprocessed 33500 out of 41187 images.
# Postprocessed 33600 out of 41187 images.
# Postprocessed 33700 out of 41187 images.
# Postprocessed 33800 out of 41187 images.
# Postprocessed 33900 out of 41187 images.
# Postprocessed 34000 out of 41187 images.
# Postprocessed 34100 out of 41187 images.
# Postprocessed 34200 out of 41187 images.
# Postprocessed 34300 out of 41187 images.
# Postprocessed 34400 out of 41187 images.
# Postprocessed 34500 out of 41187 images.
# Postprocessed 34600 out of 41187 images.
# Postprocessed 34700 out of 41187 images.
# Postprocessed 34800 out of 41187 images.
# Postprocessed 34900 out of 41187 images.
# Postprocessed 35000 out of 41187 images.
# Postprocessed 35100 out of 41187 images.
# Postprocessed 35200 out of 41187 images.
# Postprocessed 35300 out of 41187 images.
# Postprocessed 35400 out of 41187 images.
# Postprocessed 35500 out of 41187 images.
# Postprocessed 35600 out of 41187 images.
# Postprocessed 35700 out of 41187 images.
# Postprocessed 35800 out of 41187 images.
# Postprocessed 35900 out of 41187 images.
# Postprocessed 36000 out of 41187 images.
# Postprocessed 36100 out of 41187 images.
# Postprocessed 36200 out of 41187 images.
# Postprocessed 36300 out of 41187 images.
# Postprocessed 36400 out of 41187 images.
# Postprocessed 36500 out of 41187 images.
# Postprocessed 36600 out of 41187 images.
# Postprocessed 36700 out of 41187 images.
# Postprocessed 36800 out of 41187 images.
# Postprocessed 36900 out of 41187 images.
# Postprocessed 37000 out of 41187 images.
# Postprocessed 37100 out of 41187 images.
# Postprocessed 37200 out of 41187 images.
# Postprocessed 37300 out of 41187 images.
# Postprocessed 37400 out of 41187 images.
# Postprocessed 37500 out of 41187 images.
# Postprocessed 37600 out of 41187 images.
# Postprocessed 37700 out of 41187 images.
# Postprocessed 37800 out of 41187 images.
# Postprocessed 37900 out of 41187 images.
# Postprocessed 38000 out of 41187 images.
# Postprocessed 38100 out of 41187 images.
# Postprocessed 38200 out of 41187 images.
# Postprocessed 38300 out of 41187 images.
# Postprocessed 38400 out of 41187 images.
# Postprocessed 38500 out of 41187 images.
# Postprocessed 38600 out of 41187 images.
# Postprocessed 38700 out of 41187 images.
# Postprocessed 38800 out of 41187 images.
# Postprocessed 38900 out of 41187 images.
# Postprocessed 39000 out of 41187 images.
# Postprocessed 39100 out of 41187 images.
# Postprocessed 39200 out of 41187 images.
# Postprocessed 39300 out of 41187 images.
# Postprocessed 39400 out of 41187 images.
# Postprocessed 39500 out of 41187 images.
# Postprocessed 39600 out of 41187 images.
# Postprocessed 39700 out of 41187 images.
# Postprocessed 39800 out of 41187 images.
# Postprocessed 39900 out of 41187 images.
# Postprocessed 40000 out of 41187 images.
# Postprocessed 40100 out of 41187 images.
# Postprocessed 40200 out of 41187 images.
# Postprocessed 40300 out of 41187 images.
# Postprocessed 40400 out of 41187 images.
# Postprocessed 40500 out of 41187 images.
# Postprocessed 40600 out of 41187 images.
# Postprocessed 40700 out of 41187 images.
# Postprocessed 40800 out of 41187 images.
# Postprocessed 40900 out of 41187 images.
# Postprocessed 41000 out of 41187 images.
# Postprocessed 41100 out of 41187 images.

# %%
for key in det_results:
    det_results[key]['num_detections'] = len(det_results[key]['sorted_labels'])

# %%
det_results_2 = {}
for key, val in det_results.items():
    det_results_2[key] = {
        'num_detections': val['num_detections'],
        'detection_classes': val['sorted_labels'],
        'detection_boxes': val['sorted_boxes'],
        'detection_scores': val['sorted_probs'],
    }

# %%
save_obj(det_results, f'../../results/det_results_{exp_name}')
