# %%
exp_name = 'dpl_016'

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import torch
import torch.nn as nn
import torchvision
from torch.autograd import Variable
from torch.nn import functional as F

import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
import pickle
import csv
import os
import time
import datetime
import lmdb

from skimage.feature import peak_local_max
import scipy
from scipy import ndimage as ndi
from multiprocessing import Pool

# %%
def save_obj(obj, name ):
    with open( name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open( name + '.pkl', 'rb') as f:
        return pickle.load(f)

now = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
logfile = open(f'../../log/{exp_name}.txt', 'a')
logfile.write(f'\n\n\n\n ----------------- {now} ----------------- \n\n')
logfile.flush()
def log(string, stdout=True):
    if stdout:
        print(string)
    logfile.write(string + '\n')
    logfile.flush()

# %%
with open('../../metadata/ont_300/300-classes.csv', 'r') as fin:
    all_labels = [item.strip() for item in fin]
all_labels.append('background')
    
label2idx = {}
for i, l in enumerate(all_labels):
    label2idx[l] = i

# %%
lmdb_path = '../../data/OpenImages/lmdb/test-600.lmdb'
env = lmdb.open(lmdb_path, map_size=1e11, readonly=True, lock=False)
txn = env.begin(write=False)
cursor = txn.cursor()

# %%
with open('../../../model_fusion/temp/test_subset_ws_3.pkl', 'rb') as fin:
    test_img_ids = pickle.load(fin)

# %%
resnet = torchvision.models.resnet152() # resnet.eval() is very important, do not forget this line during testing!
print(resnet.fc)
resnet.fc = nn.Linear(2048, len(all_labels)-1)

resnet.avgpool = nn.AdaptiveAvgPool2d((1, 1))

#saved_state_dict = torch.load(os.path.join('data/snapshots/','d2_rel_open_1600.pth'))
saved_state_dict = torch.load(os.path.join('../../snapshots', 'train_019', 'ckpt_5000'))
resnet.load_state_dict(saved_state_dict)
resnet.cuda(0)
resnet.eval()
resnet.float()
# Out:
# Linear(in_features=2048, out_features=1000, bias=True)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=282, bias=True)
# )

# %%
finalconv_name = 'layer4'

# hook the feature extractor
features_blobs = []
def hook_feature(module, input, output):
    features_blobs.append(output.data.cpu().numpy())

resnet._modules.get(finalconv_name).register_forward_hook(hook_feature)

# get the softmax weight
params = list(resnet.parameters())
weight_softmax = np.squeeze(params[-2].cpu().data.numpy())

# %%
def preproc(im):
    target_size = 256
    max_size = 1024
    im_size_min = np.min(im.shape[0:2])
    im_size_max = np.max(im.shape[0:2])
    im_scale = float(target_size) / float(im_size_min)
    # Prevent the biggest axis from being more than MAX_SIZE
    if np.round(im_scale * im_size_max) > max_size:
        im_scale = float(max_size) / float(im_size_max)
    im = cv2.resize(im, None, None, fx=im_scale, fy=im_scale,
                    interpolation=cv2.INTER_LINEAR)    
    return im

# %%
batch_size = 1
model_output = {}
batch = []
batch_keys = []
img_shape = {}
for i, imgid in enumerate(test_img_ids):
    try:
        imgbin = txn.get(imgid.encode('utf-8'))
        imgbgr = cv2.imdecode(np.fromstring(imgbin, dtype='uint8'), cv2.IMREAD_COLOR)
        
        img_shape[imgid] = (imgbgr.shape[1], imgbgr.shape[0])
        
        imgbgr = preproc(imgbgr)
        imgrgb = imgbgr[:,:,[2,1,0]]
        # assert(imgrgb.shape[0] == 224 and imgrgb.shape[1] == 224 and imgrgb.shape[2] == 3)
    except Exception as ex:
        log(str(ex))
        continue
    
    imgrgb = imgrgb.astype(float)/255.0
    
    imgrgb[:,:,0] = (imgrgb[:,:,0] - 0.485)/0.229
    imgrgb[:,:,1] = (imgrgb[:,:,1] - 0.456)/0.224
    imgrgb[:,:,2] = (imgrgb[:,:,2] - 0.406)/0.225

    imgrgb = imgrgb.transpose((2,0,1))
    batch.append(imgrgb)
    batch_keys.append(imgid)
    
    if len(batch) == batch_size or (i + 1) == len(test_img_ids):
        batch = np.stack(batch)
    
        features_blobs = []
        
        with torch.no_grad():
            inp = torch.from_numpy(batch).float().cuda(0)
            outputs = resnet(inp)
            outputs = torch.cat([outputs, torch.ones(batch.shape[0], 1).cuda(0)], dim=1)
            h_x = F.softmax(outputs)#.data.squeeze()
            class_probs, class_idx = h_x.sort(1, True)
            class_idx = np.asarray(class_idx)
            class_probs = np.asarray(class_probs)
        
        for ii in range(len(batch_keys)):
            model_output[batch_keys[ii]] = {
                'features_blobs': features_blobs[0][ii],
                'sorted_labels': class_idx[ii],
                'sorted_probs': class_probs[ii],                
            }
        
        batch = []
        batch_keys = []
        log(f'Processed {i + 1} out of {len(test_img_ids)} images.')
# Out:
# /home/alireza/home_at_filer2/tools/anaconda3/envs/py3torch/lib/python3.6/site-packages/ipykernel/__main__.py:9: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
# /home/alireza/home_at_filer2/tools/anaconda3/envs/py3torch/lib/python3.6/site-packages/ipykernel/__main__.py:38: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Processed 1 out of 5657 images.
# Processed 2 out of 5657 images.
# Processed 3 out of 5657 images.
# Processed 4 out of 5657 images.
# Processed 5 out of 5657 images.
# Processed 6 out of 5657 images.
# Processed 7 out of 5657 images.
# Processed 8 out of 5657 images.
# Processed 9 out of 5657 images.
# Processed 10 out of 5657 images.
# Processed 11 out of 5657 images.
# Processed 12 out of 5657 images.
# Processed 13 out of 5657 images.
# Processed 14 out of 5657 images.
# Processed 15 out of 5657 images.
# Processed 16 out of 5657 images.
# Processed 17 out of 5657 images.
# Processed 18 out of 5657 images.
# Processed 19 out of 5657 images.
# Processed 20 out of 5657 images.
# Processed 21 out of 5657 images.
# Processed 22 out of 5657 images.
# Processed 23 out of 5657 images.
# Processed 24 out of 5657 images.
# Processed 25 out of 5657 images.
# Processed 26 out of 5657 images.
# Processed 27 out of 5657 images.
# Processed 28 out of 5657 images.
# Processed 29 out of 5657 images.
# Processed 30 out of 5657 images.
# Processed 31 out of 5657 images.
# Processed 32 out of 5657 images.
# Processed 33 out of 5657 images.
# Processed 34 out of 5657 images.
# Processed 35 out of 5657 images.
# Processed 36 out of 5657 images.
# Processed 37 out of 5657 images.
# Processed 38 out of 5657 images.
# Processed 39 out of 5657 images.
# Processed 40 out of 5657 images.
# Processed 41 out of 5657 images.
# Processed 42 out of 5657 images.
# Processed 43 out of 5657 images.
# Processed 44 out of 5657 images.
# Processed 45 out of 5657 images.
# Processed 46 out of 5657 images.
# Processed 47 out of 5657 images.
# Processed 48 out of 5657 images.
# Processed 49 out of 5657 images.
# Processed 50 out of 5657 images.
# Processed 51 out of 5657 images.
# Processed 52 out of 5657 images.
# Processed 53 out of 5657 images.
# Processed 54 out of 5657 images.
# Processed 55 out of 5657 images.
# Processed 56 out of 5657 images.
# Processed 57 out of 5657 images.
# Processed 58 out of 5657 images.
# Processed 59 out of 5657 images.
# Processed 60 out of 5657 images.
# Processed 61 out of 5657 images.
# Processed 62 out of 5657 images.
# Processed 63 out of 5657 images.
# Processed 64 out of 5657 images.
# Processed 65 out of 5657 images.
# Processed 66 out of 5657 images.
# Processed 67 out of 5657 images.
# Processed 68 out of 5657 images.
# Processed 69 out of 5657 images.
# Processed 70 out of 5657 images.
# Processed 71 out of 5657 images.
# Processed 72 out of 5657 images.
# Processed 73 out of 5657 images.
# Processed 74 out of 5657 images.
# Processed 75 out of 5657 images.
# Processed 76 out of 5657 images.
# Processed 77 out of 5657 images.
# Processed 78 out of 5657 images.
# Processed 79 out of 5657 images.
# Processed 80 out of 5657 images.
# Processed 81 out of 5657 images.
# Processed 82 out of 5657 images.
# Processed 83 out of 5657 images.
# Processed 84 out of 5657 images.
# Processed 85 out of 5657 images.
# Processed 86 out of 5657 images.
# Processed 87 out of 5657 images.
# Processed 88 out of 5657 images.
# Processed 89 out of 5657 images.
# Processed 90 out of 5657 images.
# Processed 91 out of 5657 images.
# Processed 92 out of 5657 images.
# Processed 93 out of 5657 images.
# Processed 94 out of 5657 images.
# Processed 95 out of 5657 images.
# Processed 96 out of 5657 images.
# Processed 97 out of 5657 images.
# Processed 98 out of 5657 images.
# Processed 99 out of 5657 images.
# Processed 100 out of 5657 images.
# Processed 101 out of 5657 images.
# Processed 102 out of 5657 images.
# Processed 103 out of 5657 images.
# Processed 104 out of 5657 images.
# Processed 105 out of 5657 images.
# Processed 106 out of 5657 images.
# Processed 107 out of 5657 images.
# Processed 108 out of 5657 images.
# Processed 109 out of 5657 images.
# Processed 110 out of 5657 images.
# Processed 111 out of 5657 images.
# Processed 112 out of 5657 images.
# Processed 113 out of 5657 images.
# Processed 114 out of 5657 images.
# Processed 115 out of 5657 images.
# Processed 116 out of 5657 images.
# Processed 117 out of 5657 images.
# Processed 118 out of 5657 images.
# Processed 119 out of 5657 images.
# Processed 120 out of 5657 images.
# Processed 121 out of 5657 images.
# Processed 122 out of 5657 images.
# Processed 123 out of 5657 images.
# Processed 124 out of 5657 images.
# Processed 125 out of 5657 images.
# Processed 126 out of 5657 images.
# Processed 127 out of 5657 images.
# Processed 128 out of 5657 images.
# Processed 129 out of 5657 images.
# Processed 130 out of 5657 images.
# Processed 131 out of 5657 images.
# Processed 132 out of 5657 images.
# Processed 133 out of 5657 images.
# Processed 134 out of 5657 images.
# Processed 135 out of 5657 images.
# Processed 136 out of 5657 images.
# Processed 137 out of 5657 images.
# Processed 138 out of 5657 images.
# Processed 139 out of 5657 images.
# Processed 140 out of 5657 images.
# Processed 141 out of 5657 images.
# Processed 142 out of 5657 images.
# Processed 143 out of 5657 images.
# Processed 144 out of 5657 images.
# Processed 145 out of 5657 images.
# Processed 146 out of 5657 images.
# Processed 147 out of 5657 images.
# Processed 148 out of 5657 images.
# Processed 149 out of 5657 images.
# Processed 150 out of 5657 images.
# Processed 151 out of 5657 images.
# Processed 152 out of 5657 images.
# Processed 153 out of 5657 images.
# Processed 154 out of 5657 images.
# Processed 155 out of 5657 images.
# Processed 156 out of 5657 images.
# Processed 157 out of 5657 images.
# Processed 158 out of 5657 images.
# Processed 159 out of 5657 images.
# Processed 160 out of 5657 images.
# Processed 161 out of 5657 images.
# Processed 162 out of 5657 images.
# Processed 163 out of 5657 images.
# Processed 164 out of 5657 images.
# Processed 165 out of 5657 images.
# Processed 166 out of 5657 images.
# Processed 167 out of 5657 images.
# Processed 168 out of 5657 images.
# Processed 169 out of 5657 images.
# Processed 170 out of 5657 images.
# Processed 171 out of 5657 images.
# Processed 172 out of 5657 images.
# Processed 173 out of 5657 images.
# Processed 174 out of 5657 images.
# Processed 175 out of 5657 images.
# Processed 176 out of 5657 images.
# Processed 177 out of 5657 images.
# Processed 178 out of 5657 images.
# Processed 179 out of 5657 images.
# Processed 180 out of 5657 images.
# Processed 181 out of 5657 images.
# Processed 182 out of 5657 images.
# Processed 183 out of 5657 images.
# Processed 184 out of 5657 images.
# Processed 185 out of 5657 images.
# Processed 186 out of 5657 images.
# Processed 187 out of 5657 images.
# Processed 188 out of 5657 images.
# Processed 189 out of 5657 images.
# Processed 190 out of 5657 images.
# Processed 191 out of 5657 images.
# Processed 192 out of 5657 images.
# Processed 193 out of 5657 images.
# Processed 194 out of 5657 images.
# Processed 195 out of 5657 images.
# Processed 196 out of 5657 images.
# Processed 197 out of 5657 images.
# Processed 198 out of 5657 images.
# Processed 199 out of 5657 images.
# Processed 200 out of 5657 images.
# Processed 201 out of 5657 images.
# Processed 202 out of 5657 images.
# Processed 203 out of 5657 images.
# Processed 204 out of 5657 images.
# Processed 205 out of 5657 images.
# Processed 206 out of 5657 images.
# Processed 207 out of 5657 images.
# Processed 208 out of 5657 images.
# Processed 209 out of 5657 images.
# Processed 210 out of 5657 images.
# Processed 211 out of 5657 images.
# Processed 212 out of 5657 images.
# Processed 213 out of 5657 images.
# Processed 214 out of 5657 images.
# Processed 215 out of 5657 images.
# Processed 216 out of 5657 images.
# Processed 217 out of 5657 images.
# Processed 218 out of 5657 images.
# Processed 219 out of 5657 images.
# Processed 220 out of 5657 images.
# Processed 221 out of 5657 images.
# Processed 222 out of 5657 images.
# Processed 223 out of 5657 images.
# Processed 224 out of 5657 images.
# Processed 225 out of 5657 images.
# Processed 226 out of 5657 images.
# Processed 227 out of 5657 images.
# Processed 228 out of 5657 images.
# Processed 229 out of 5657 images.
# Processed 230 out of 5657 images.
# Processed 231 out of 5657 images.
# Processed 232 out of 5657 images.
# Processed 233 out of 5657 images.
# Processed 234 out of 5657 images.
# Processed 235 out of 5657 images.
# Processed 236 out of 5657 images.
# Processed 237 out of 5657 images.
# Processed 238 out of 5657 images.
# Processed 239 out of 5657 images.
# Processed 240 out of 5657 images.
# Processed 241 out of 5657 images.
# Processed 242 out of 5657 images.
# Processed 243 out of 5657 images.
# Processed 244 out of 5657 images.
# Processed 245 out of 5657 images.
# Processed 246 out of 5657 images.
# Processed 247 out of 5657 images.
# Processed 248 out of 5657 images.
# Processed 249 out of 5657 images.
# Processed 250 out of 5657 images.
# Processed 251 out of 5657 images.
# Processed 252 out of 5657 images.
# Processed 253 out of 5657 images.
# Processed 254 out of 5657 images.
# Processed 255 out of 5657 images.
# Processed 256 out of 5657 images.
# Processed 257 out of 5657 images.
# Processed 258 out of 5657 images.
# Processed 259 out of 5657 images.
# Processed 260 out of 5657 images.
# Processed 261 out of 5657 images.
# Processed 262 out of 5657 images.
# Processed 263 out of 5657 images.
# Processed 264 out of 5657 images.
# Processed 265 out of 5657 images.
# Processed 266 out of 5657 images.
# Processed 267 out of 5657 images.
# Processed 268 out of 5657 images.
# Processed 269 out of 5657 images.
# Processed 270 out of 5657 images.
# Processed 271 out of 5657 images.
# Processed 272 out of 5657 images.
# Processed 273 out of 5657 images.
# Processed 274 out of 5657 images.
# Processed 275 out of 5657 images.
# Processed 276 out of 5657 images.
# Processed 277 out of 5657 images.
# Processed 278 out of 5657 images.
# Processed 279 out of 5657 images.
# Processed 280 out of 5657 images.
# Processed 281 out of 5657 images.
# Processed 282 out of 5657 images.
# Processed 283 out of 5657 images.
# Processed 284 out of 5657 images.
# Processed 285 out of 5657 images.
# Processed 286 out of 5657 images.
# Processed 287 out of 5657 images.
# Processed 288 out of 5657 images.
# Processed 289 out of 5657 images.
# Processed 290 out of 5657 images.
# Processed 291 out of 5657 images.
# Processed 292 out of 5657 images.
# Processed 293 out of 5657 images.
# Processed 294 out of 5657 images.
# Processed 295 out of 5657 images.
# Processed 296 out of 5657 images.
# Processed 297 out of 5657 images.
# Processed 298 out of 5657 images.
# Processed 299 out of 5657 images.
# Processed 300 out of 5657 images.
# Processed 301 out of 5657 images.
# Processed 302 out of 5657 images.
# Processed 303 out of 5657 images.
# Processed 304 out of 5657 images.
# Processed 305 out of 5657 images.
# Processed 306 out of 5657 images.
# Processed 307 out of 5657 images.
# Processed 308 out of 5657 images.
# Processed 309 out of 5657 images.
# Processed 310 out of 5657 images.
# Processed 311 out of 5657 images.
# Processed 312 out of 5657 images.
# Processed 313 out of 5657 images.
# Processed 314 out of 5657 images.
# Processed 315 out of 5657 images.
# Processed 316 out of 5657 images.
# Processed 317 out of 5657 images.
# Processed 318 out of 5657 images.
# Processed 319 out of 5657 images.
# Processed 320 out of 5657 images.
# Processed 321 out of 5657 images.
# Processed 322 out of 5657 images.
# Processed 323 out of 5657 images.
# Processed 324 out of 5657 images.
# Processed 325 out of 5657 images.
# Processed 326 out of 5657 images.
# Processed 327 out of 5657 images.
# Processed 328 out of 5657 images.
# Processed 329 out of 5657 images.
# Processed 330 out of 5657 images.
# Processed 331 out of 5657 images.
# Processed 332 out of 5657 images.
# Processed 333 out of 5657 images.
# Processed 334 out of 5657 images.
# Processed 335 out of 5657 images.
# Processed 336 out of 5657 images.
# Processed 337 out of 5657 images.
# Processed 338 out of 5657 images.
# Processed 339 out of 5657 images.
# Processed 340 out of 5657 images.
# Processed 341 out of 5657 images.
# Processed 342 out of 5657 images.
# Processed 343 out of 5657 images.
# Processed 344 out of 5657 images.
# Processed 345 out of 5657 images.
# Processed 346 out of 5657 images.
# Processed 347 out of 5657 images.
# Processed 348 out of 5657 images.
# Processed 349 out of 5657 images.
# Processed 350 out of 5657 images.
# Processed 351 out of 5657 images.
# Processed 352 out of 5657 images.
# Processed 353 out of 5657 images.
# Processed 354 out of 5657 images.
# Processed 355 out of 5657 images.
# Processed 356 out of 5657 images.
# Processed 357 out of 5657 images.
# Processed 358 out of 5657 images.
# Processed 359 out of 5657 images.
# Processed 360 out of 5657 images.
# Processed 361 out of 5657 images.
# Processed 362 out of 5657 images.
# Processed 363 out of 5657 images.
# Processed 364 out of 5657 images.
# Processed 365 out of 5657 images.
# Processed 366 out of 5657 images.
# Processed 367 out of 5657 images.
# Processed 368 out of 5657 images.
# Processed 369 out of 5657 images.
# Processed 370 out of 5657 images.
# Processed 371 out of 5657 images.
# Processed 372 out of 5657 images.
# Processed 373 out of 5657 images.
# Processed 374 out of 5657 images.
# Processed 375 out of 5657 images.
# Processed 376 out of 5657 images.
# Processed 377 out of 5657 images.
# Processed 378 out of 5657 images.
# Processed 379 out of 5657 images.
# Processed 380 out of 5657 images.
# Processed 381 out of 5657 images.
# Processed 382 out of 5657 images.
# Processed 383 out of 5657 images.
# Processed 384 out of 5657 images.
# Processed 385 out of 5657 images.
# Processed 386 out of 5657 images.
# Processed 387 out of 5657 images.
# Processed 388 out of 5657 images.
# Processed 389 out of 5657 images.
# Processed 390 out of 5657 images.
# Processed 391 out of 5657 images.
# Processed 392 out of 5657 images.
# Processed 393 out of 5657 images.
# Processed 394 out of 5657 images.
# Processed 395 out of 5657 images.
# Processed 396 out of 5657 images.
# Processed 397 out of 5657 images.
# Processed 398 out of 5657 images.
# Processed 399 out of 5657 images.
# Processed 400 out of 5657 images.
# Processed 401 out of 5657 images.
# Processed 402 out of 5657 images.
# Processed 403 out of 5657 images.
# Processed 404 out of 5657 images.
# Processed 405 out of 5657 images.
# Processed 406 out of 5657 images.
# Processed 407 out of 5657 images.
# Processed 408 out of 5657 images.
# Processed 409 out of 5657 images.
# Processed 410 out of 5657 images.
# Processed 411 out of 5657 images.
# Processed 412 out of 5657 images.
# Processed 413 out of 5657 images.
# Processed 414 out of 5657 images.
# Processed 415 out of 5657 images.
# Processed 416 out of 5657 images.
# Processed 417 out of 5657 images.
# Processed 418 out of 5657 images.
# Processed 419 out of 5657 images.
# Processed 420 out of 5657 images.
# Processed 421 out of 5657 images.
# Processed 422 out of 5657 images.
# Processed 423 out of 5657 images.
# Processed 424 out of 5657 images.
# Processed 425 out of 5657 images.
# Processed 426 out of 5657 images.
# Processed 427 out of 5657 images.
# Processed 428 out of 5657 images.
# Processed 429 out of 5657 images.
# Processed 430 out of 5657 images.
# Processed 431 out of 5657 images.
# Processed 432 out of 5657 images.
# Processed 433 out of 5657 images.
# Processed 434 out of 5657 images.
# Processed 435 out of 5657 images.
# Processed 436 out of 5657 images.
# Processed 437 out of 5657 images.
# Processed 438 out of 5657 images.
# Processed 439 out of 5657 images.
# Processed 440 out of 5657 images.
# Processed 441 out of 5657 images.
# Processed 442 out of 5657 images.
# Processed 443 out of 5657 images.
# Processed 444 out of 5657 images.
# Processed 445 out of 5657 images.
# Processed 446 out of 5657 images.
# Processed 447 out of 5657 images.
# Processed 448 out of 5657 images.
# Processed 449 out of 5657 images.
# Processed 450 out of 5657 images.
# Processed 451 out of 5657 images.
# Processed 452 out of 5657 images.
# Processed 453 out of 5657 images.
# Processed 454 out of 5657 images.
# Processed 455 out of 5657 images.
# Processed 456 out of 5657 images.
# Processed 457 out of 5657 images.
# Processed 458 out of 5657 images.
# Processed 459 out of 5657 images.
# Processed 460 out of 5657 images.
# Processed 461 out of 5657 images.
# Processed 462 out of 5657 images.
# Processed 463 out of 5657 images.
# Processed 464 out of 5657 images.
# Processed 465 out of 5657 images.
# Processed 466 out of 5657 images.
# Processed 467 out of 5657 images.
# Processed 468 out of 5657 images.
# Processed 469 out of 5657 images.
# Processed 470 out of 5657 images.
# Processed 471 out of 5657 images.
# Processed 472 out of 5657 images.
# Processed 473 out of 5657 images.
# Processed 474 out of 5657 images.
# Processed 475 out of 5657 images.
# Processed 476 out of 5657 images.
# Processed 477 out of 5657 images.
# Processed 478 out of 5657 images.
# Processed 479 out of 5657 images.
# Processed 480 out of 5657 images.
# Processed 481 out of 5657 images.
# Processed 482 out of 5657 images.
# Processed 483 out of 5657 images.
# Processed 484 out of 5657 images.
# Processed 485 out of 5657 images.
# Processed 486 out of 5657 images.
# Processed 487 out of 5657 images.
# Processed 488 out of 5657 images.
# Processed 489 out of 5657 images.
# Processed 490 out of 5657 images.
# Processed 491 out of 5657 images.
# Processed 492 out of 5657 images.
# Processed 493 out of 5657 images.
# Processed 494 out of 5657 images.
# Processed 495 out of 5657 images.
# Processed 496 out of 5657 images.
# Processed 497 out of 5657 images.
# Processed 498 out of 5657 images.
# Processed 499 out of 5657 images.
# Processed 500 out of 5657 images.
# Processed 501 out of 5657 images.
# Processed 502 out of 5657 images.
# Processed 503 out of 5657 images.
# Processed 504 out of 5657 images.
# Processed 505 out of 5657 images.
# Processed 506 out of 5657 images.
# Processed 507 out of 5657 images.
# Processed 508 out of 5657 images.
# Processed 509 out of 5657 images.
# Processed 510 out of 5657 images.
# Processed 511 out of 5657 images.
# Processed 512 out of 5657 images.
# Processed 513 out of 5657 images.
# Processed 514 out of 5657 images.
# Processed 515 out of 5657 images.
# Processed 516 out of 5657 images.
# Processed 517 out of 5657 images.
# Processed 518 out of 5657 images.
# Processed 519 out of 5657 images.
# Processed 520 out of 5657 images.
# Processed 521 out of 5657 images.
# Processed 522 out of 5657 images.
# Processed 523 out of 5657 images.
# Processed 524 out of 5657 images.
# Processed 525 out of 5657 images.
# Processed 526 out of 5657 images.
# Processed 527 out of 5657 images.
# Processed 528 out of 5657 images.
# Processed 529 out of 5657 images.
# Processed 530 out of 5657 images.
# Processed 531 out of 5657 images.
# Processed 532 out of 5657 images.
# Processed 533 out of 5657 images.
# Processed 534 out of 5657 images.
# Processed 535 out of 5657 images.
# Processed 536 out of 5657 images.
# Processed 537 out of 5657 images.
# Processed 538 out of 5657 images.
# Processed 539 out of 5657 images.
# Processed 540 out of 5657 images.
# Processed 541 out of 5657 images.
# Processed 542 out of 5657 images.
# Processed 543 out of 5657 images.
# Processed 544 out of 5657 images.
# Processed 545 out of 5657 images.
# Processed 546 out of 5657 images.
# Processed 547 out of 5657 images.
# Processed 548 out of 5657 images.
# Processed 549 out of 5657 images.
# Processed 550 out of 5657 images.
# Processed 551 out of 5657 images.
# Processed 552 out of 5657 images.
# Processed 553 out of 5657 images.
# Processed 554 out of 5657 images.
# Processed 555 out of 5657 images.
# Processed 556 out of 5657 images.
# Processed 557 out of 5657 images.
# Processed 558 out of 5657 images.
# Processed 559 out of 5657 images.
# Processed 560 out of 5657 images.
# Processed 561 out of 5657 images.
# Processed 562 out of 5657 images.
# Processed 563 out of 5657 images.
# Processed 564 out of 5657 images.
# Processed 565 out of 5657 images.
# Processed 566 out of 5657 images.
# Processed 567 out of 5657 images.
# Processed 568 out of 5657 images.
# Processed 569 out of 5657 images.
# Processed 570 out of 5657 images.
# Processed 571 out of 5657 images.
# Processed 572 out of 5657 images.
# Processed 573 out of 5657 images.
# Processed 574 out of 5657 images.
# Processed 575 out of 5657 images.
# Processed 576 out of 5657 images.
# Processed 577 out of 5657 images.
# Processed 578 out of 5657 images.
# Processed 579 out of 5657 images.
# Processed 580 out of 5657 images.
# Processed 581 out of 5657 images.
# Processed 582 out of 5657 images.
# Processed 583 out of 5657 images.
# Processed 584 out of 5657 images.
# Processed 585 out of 5657 images.
# Processed 586 out of 5657 images.
# Processed 587 out of 5657 images.
# Processed 588 out of 5657 images.
# Processed 589 out of 5657 images.
# Processed 590 out of 5657 images.
# Processed 591 out of 5657 images.
# Processed 592 out of 5657 images.
# Processed 593 out of 5657 images.
# Processed 594 out of 5657 images.
# Processed 595 out of 5657 images.
# Processed 596 out of 5657 images.
# Processed 597 out of 5657 images.
# Processed 598 out of 5657 images.
# Processed 599 out of 5657 images.
# Processed 600 out of 5657 images.
# Processed 601 out of 5657 images.
# Processed 602 out of 5657 images.
# Processed 603 out of 5657 images.
# Processed 604 out of 5657 images.
# Processed 605 out of 5657 images.
# Processed 606 out of 5657 images.
# Processed 607 out of 5657 images.
# Processed 608 out of 5657 images.
# Processed 609 out of 5657 images.
# Processed 610 out of 5657 images.
# Processed 611 out of 5657 images.
# Processed 612 out of 5657 images.
# Processed 613 out of 5657 images.
# Processed 614 out of 5657 images.
# Processed 615 out of 5657 images.
# Processed 616 out of 5657 images.
# Processed 617 out of 5657 images.
# Processed 618 out of 5657 images.
# Processed 619 out of 5657 images.
# Processed 620 out of 5657 images.
# Processed 621 out of 5657 images.
# Processed 622 out of 5657 images.
# Processed 623 out of 5657 images.
# Processed 624 out of 5657 images.
# Processed 625 out of 5657 images.
# Processed 626 out of 5657 images.
# Processed 627 out of 5657 images.
# Processed 628 out of 5657 images.
# Processed 629 out of 5657 images.
# Processed 630 out of 5657 images.
# Processed 631 out of 5657 images.
# Processed 632 out of 5657 images.
# Processed 633 out of 5657 images.
# Processed 634 out of 5657 images.
# Processed 635 out of 5657 images.
# Processed 636 out of 5657 images.
# Processed 637 out of 5657 images.
# Processed 638 out of 5657 images.
# Processed 639 out of 5657 images.
# Processed 640 out of 5657 images.
# Processed 641 out of 5657 images.
# Processed 642 out of 5657 images.
# Processed 643 out of 5657 images.
# Processed 644 out of 5657 images.
# Processed 645 out of 5657 images.
# Processed 646 out of 5657 images.
# Processed 647 out of 5657 images.
# Processed 648 out of 5657 images.
# Processed 649 out of 5657 images.
# Processed 650 out of 5657 images.
# Processed 651 out of 5657 images.
# Processed 652 out of 5657 images.
# Processed 653 out of 5657 images.
# Processed 654 out of 5657 images.
# Processed 655 out of 5657 images.
# Processed 656 out of 5657 images.
# Processed 657 out of 5657 images.
# Processed 658 out of 5657 images.
# Processed 659 out of 5657 images.
# Processed 660 out of 5657 images.
# Processed 661 out of 5657 images.
# Processed 662 out of 5657 images.
# Processed 663 out of 5657 images.
# Processed 664 out of 5657 images.
# Processed 665 out of 5657 images.
# Processed 666 out of 5657 images.
# Processed 667 out of 5657 images.
# Processed 668 out of 5657 images.
# Processed 669 out of 5657 images.
# Processed 670 out of 5657 images.
# Processed 671 out of 5657 images.
# Processed 672 out of 5657 images.
# Processed 673 out of 5657 images.
# Processed 674 out of 5657 images.
# Processed 675 out of 5657 images.
# Processed 676 out of 5657 images.
# Processed 677 out of 5657 images.
# Processed 678 out of 5657 images.
# Processed 679 out of 5657 images.
# Processed 680 out of 5657 images.
# Processed 681 out of 5657 images.
# Processed 682 out of 5657 images.
# Processed 683 out of 5657 images.
# Processed 684 out of 5657 images.
# Processed 685 out of 5657 images.
# Processed 686 out of 5657 images.
# Processed 687 out of 5657 images.
# Processed 688 out of 5657 images.
# Processed 689 out of 5657 images.
# Processed 690 out of 5657 images.
# Processed 691 out of 5657 images.
# Processed 692 out of 5657 images.
# Processed 693 out of 5657 images.
# Processed 694 out of 5657 images.
# Processed 695 out of 5657 images.
# Processed 696 out of 5657 images.
# Processed 697 out of 5657 images.
# Processed 698 out of 5657 images.
# Processed 699 out of 5657 images.
# Processed 700 out of 5657 images.
# Processed 701 out of 5657 images.
# Processed 702 out of 5657 images.
# Processed 703 out of 5657 images.
# Processed 704 out of 5657 images.
# Processed 705 out of 5657 images.
# Processed 706 out of 5657 images.
# Processed 707 out of 5657 images.
# Processed 708 out of 5657 images.
# Processed 709 out of 5657 images.
# Processed 710 out of 5657 images.
# Processed 711 out of 5657 images.
# Processed 712 out of 5657 images.
# Processed 713 out of 5657 images.
# Processed 714 out of 5657 images.
# Processed 715 out of 5657 images.
# Processed 716 out of 5657 images.
# Processed 717 out of 5657 images.
# Processed 718 out of 5657 images.
# Processed 719 out of 5657 images.
# Processed 720 out of 5657 images.
# Processed 721 out of 5657 images.
# Processed 722 out of 5657 images.
# Processed 723 out of 5657 images.
# Processed 724 out of 5657 images.
# Processed 725 out of 5657 images.
# Processed 726 out of 5657 images.
# Processed 727 out of 5657 images.
# Processed 728 out of 5657 images.
# Processed 729 out of 5657 images.
# Processed 730 out of 5657 images.
# Processed 731 out of 5657 images.
# Processed 732 out of 5657 images.
# Processed 733 out of 5657 images.
# Processed 734 out of 5657 images.
# Processed 735 out of 5657 images.
# Processed 736 out of 5657 images.
# Processed 737 out of 5657 images.
# Processed 738 out of 5657 images.
# Processed 739 out of 5657 images.
# Processed 740 out of 5657 images.
# Processed 741 out of 5657 images.
# Processed 742 out of 5657 images.
# Processed 743 out of 5657 images.
# Processed 744 out of 5657 images.
# Processed 745 out of 5657 images.
# Processed 746 out of 5657 images.
# Processed 747 out of 5657 images.
# Processed 748 out of 5657 images.
# Processed 749 out of 5657 images.
# Processed 750 out of 5657 images.
# Processed 751 out of 5657 images.
# Processed 752 out of 5657 images.
# Processed 753 out of 5657 images.
# Processed 754 out of 5657 images.
# Processed 755 out of 5657 images.
# Processed 756 out of 5657 images.
# Processed 757 out of 5657 images.
# Processed 758 out of 5657 images.
# Processed 759 out of 5657 images.
# Processed 760 out of 5657 images.
# Processed 761 out of 5657 images.
# Processed 762 out of 5657 images.
# Processed 763 out of 5657 images.
# Processed 764 out of 5657 images.
# Processed 765 out of 5657 images.
# Processed 766 out of 5657 images.
# Processed 767 out of 5657 images.
# Processed 768 out of 5657 images.
# Processed 769 out of 5657 images.
# Processed 770 out of 5657 images.
# Processed 771 out of 5657 images.
# Processed 772 out of 5657 images.
# Processed 773 out of 5657 images.
# Processed 774 out of 5657 images.
# Processed 775 out of 5657 images.
# Processed 776 out of 5657 images.
# Processed 777 out of 5657 images.
# Processed 778 out of 5657 images.
# Processed 779 out of 5657 images.
# Processed 780 out of 5657 images.
# Processed 781 out of 5657 images.
# Processed 782 out of 5657 images.
# Processed 783 out of 5657 images.
# Processed 784 out of 5657 images.
# Processed 785 out of 5657 images.
# Processed 786 out of 5657 images.
# Processed 787 out of 5657 images.
# Processed 788 out of 5657 images.
# Processed 789 out of 5657 images.
# Processed 790 out of 5657 images.
# Processed 791 out of 5657 images.
# Processed 792 out of 5657 images.
# Processed 793 out of 5657 images.
# Processed 794 out of 5657 images.
# Processed 795 out of 5657 images.
# Processed 796 out of 5657 images.
# Processed 797 out of 5657 images.
# Processed 798 out of 5657 images.
# Processed 799 out of 5657 images.
# Processed 800 out of 5657 images.
# Processed 801 out of 5657 images.
# Processed 802 out of 5657 images.
# Processed 803 out of 5657 images.
# Processed 804 out of 5657 images.
# Processed 805 out of 5657 images.
# Processed 806 out of 5657 images.
# Processed 807 out of 5657 images.
# Processed 808 out of 5657 images.
# Processed 809 out of 5657 images.
# Processed 810 out of 5657 images.
# Processed 811 out of 5657 images.
# Processed 812 out of 5657 images.
# Processed 813 out of 5657 images.
# Processed 814 out of 5657 images.
# Processed 815 out of 5657 images.
# Processed 816 out of 5657 images.
# Processed 817 out of 5657 images.
# Processed 818 out of 5657 images.
# Processed 819 out of 5657 images.
# Processed 820 out of 5657 images.
# Processed 821 out of 5657 images.
# Processed 822 out of 5657 images.
# Processed 823 out of 5657 images.
# Processed 824 out of 5657 images.
# Processed 825 out of 5657 images.
# Processed 826 out of 5657 images.
# Processed 827 out of 5657 images.
# Processed 828 out of 5657 images.
# Processed 829 out of 5657 images.
# Processed 830 out of 5657 images.
# Processed 831 out of 5657 images.
# Processed 832 out of 5657 images.
# Processed 833 out of 5657 images.
# Processed 834 out of 5657 images.
# Processed 835 out of 5657 images.
# Processed 836 out of 5657 images.
# Processed 837 out of 5657 images.
# Processed 838 out of 5657 images.
# Processed 839 out of 5657 images.
# Processed 840 out of 5657 images.
# Processed 841 out of 5657 images.
# Processed 842 out of 5657 images.
# Processed 843 out of 5657 images.
# Processed 844 out of 5657 images.
# Processed 845 out of 5657 images.
# Processed 846 out of 5657 images.
# Processed 847 out of 5657 images.
# Processed 848 out of 5657 images.
# Processed 849 out of 5657 images.
# Processed 850 out of 5657 images.
# Processed 851 out of 5657 images.
# Processed 852 out of 5657 images.
# Processed 853 out of 5657 images.
# Processed 854 out of 5657 images.
# Processed 855 out of 5657 images.
# Processed 856 out of 5657 images.
# Processed 857 out of 5657 images.
# Processed 858 out of 5657 images.
# Processed 859 out of 5657 images.
# Processed 860 out of 5657 images.
# Processed 861 out of 5657 images.
# Processed 862 out of 5657 images.
# Processed 863 out of 5657 images.
# Processed 864 out of 5657 images.
# Processed 865 out of 5657 images.
# Processed 866 out of 5657 images.
# Processed 867 out of 5657 images.
# Processed 868 out of 5657 images.
# Processed 869 out of 5657 images.
# Processed 870 out of 5657 images.
# Processed 871 out of 5657 images.
# Processed 872 out of 5657 images.
# Processed 873 out of 5657 images.
# Processed 874 out of 5657 images.
# Processed 875 out of 5657 images.
# Processed 876 out of 5657 images.
# Processed 877 out of 5657 images.
# Processed 878 out of 5657 images.
# Processed 879 out of 5657 images.
# Processed 880 out of 5657 images.
# Processed 881 out of 5657 images.
# Processed 882 out of 5657 images.
# Processed 883 out of 5657 images.
# Processed 884 out of 5657 images.
# Processed 885 out of 5657 images.
# Processed 886 out of 5657 images.
# Processed 887 out of 5657 images.
# Processed 888 out of 5657 images.
# Processed 889 out of 5657 images.
# Processed 890 out of 5657 images.
# Processed 891 out of 5657 images.
# Processed 892 out of 5657 images.
# Processed 893 out of 5657 images.
# Processed 894 out of 5657 images.
# Processed 895 out of 5657 images.
# Processed 896 out of 5657 images.
# Processed 897 out of 5657 images.
# Processed 898 out of 5657 images.
# Processed 899 out of 5657 images.
# Processed 900 out of 5657 images.
# Processed 901 out of 5657 images.
# Processed 902 out of 5657 images.
# Processed 903 out of 5657 images.
# Processed 904 out of 5657 images.
# Processed 905 out of 5657 images.
# Processed 906 out of 5657 images.
# Processed 907 out of 5657 images.
# Processed 908 out of 5657 images.
# Processed 909 out of 5657 images.
# Processed 910 out of 5657 images.
# Processed 911 out of 5657 images.
# Processed 912 out of 5657 images.
# Processed 913 out of 5657 images.
# Processed 914 out of 5657 images.
# Processed 915 out of 5657 images.
# Processed 916 out of 5657 images.
# Processed 917 out of 5657 images.
# Processed 918 out of 5657 images.
# Processed 919 out of 5657 images.
# Processed 920 out of 5657 images.
# Processed 921 out of 5657 images.
# Processed 922 out of 5657 images.
# Processed 923 out of 5657 images.
# Processed 924 out of 5657 images.
# Processed 925 out of 5657 images.
# Processed 926 out of 5657 images.
# Processed 927 out of 5657 images.
# Processed 928 out of 5657 images.
# Processed 929 out of 5657 images.
# Processed 930 out of 5657 images.
# Processed 931 out of 5657 images.
# Processed 932 out of 5657 images.
# Processed 933 out of 5657 images.
# Processed 934 out of 5657 images.
# Processed 935 out of 5657 images.
# Processed 936 out of 5657 images.
# Processed 937 out of 5657 images.
# Processed 938 out of 5657 images.
# Processed 939 out of 5657 images.
# Processed 940 out of 5657 images.
# Processed 941 out of 5657 images.
# Processed 942 out of 5657 images.
# Processed 943 out of 5657 images.
# Processed 944 out of 5657 images.
# Processed 945 out of 5657 images.
# Processed 946 out of 5657 images.
# Processed 947 out of 5657 images.
# Processed 948 out of 5657 images.
# Processed 949 out of 5657 images.
# Processed 950 out of 5657 images.
# Processed 951 out of 5657 images.
# Processed 952 out of 5657 images.
# Processed 953 out of 5657 images.
# Processed 954 out of 5657 images.
# Processed 955 out of 5657 images.
# Processed 956 out of 5657 images.
# Processed 957 out of 5657 images.
# Processed 958 out of 5657 images.
# Processed 959 out of 5657 images.
# Processed 960 out of 5657 images.
# Processed 961 out of 5657 images.
# Processed 962 out of 5657 images.
# Processed 963 out of 5657 images.
# Processed 964 out of 5657 images.
# Processed 965 out of 5657 images.
# Processed 966 out of 5657 images.
# Processed 967 out of 5657 images.
# Processed 968 out of 5657 images.
# Processed 969 out of 5657 images.
# Processed 970 out of 5657 images.
# Processed 971 out of 5657 images.
# Processed 972 out of 5657 images.
# Processed 973 out of 5657 images.
# Processed 974 out of 5657 images.
# Processed 975 out of 5657 images.
# Processed 976 out of 5657 images.
# Processed 977 out of 5657 images.
# Processed 978 out of 5657 images.
# Processed 979 out of 5657 images.
# Processed 980 out of 5657 images.
# Processed 981 out of 5657 images.
# Processed 982 out of 5657 images.
# Processed 983 out of 5657 images.
# Processed 984 out of 5657 images.
# Processed 985 out of 5657 images.
# Processed 986 out of 5657 images.
# Processed 987 out of 5657 images.
# Processed 988 out of 5657 images.
# Processed 989 out of 5657 images.
# Processed 990 out of 5657 images.
# Processed 991 out of 5657 images.
# Processed 992 out of 5657 images.
# Processed 993 out of 5657 images.
# Processed 994 out of 5657 images.
# Processed 995 out of 5657 images.
# Processed 996 out of 5657 images.
# Processed 997 out of 5657 images.
# Processed 998 out of 5657 images.
# Processed 999 out of 5657 images.
# Processed 1000 out of 5657 images.
# Processed 1001 out of 5657 images.
# Processed 1002 out of 5657 images.
# Processed 1003 out of 5657 images.
# Processed 1004 out of 5657 images.
# Processed 1005 out of 5657 images.
# Processed 1006 out of 5657 images.
# Processed 1007 out of 5657 images.
# Processed 1008 out of 5657 images.
# Processed 1009 out of 5657 images.
# Processed 1010 out of 5657 images.
# Processed 1011 out of 5657 images.
# Processed 1012 out of 5657 images.
# Processed 1013 out of 5657 images.
# Processed 1014 out of 5657 images.
# Processed 1015 out of 5657 images.
# Processed 1016 out of 5657 images.
# Processed 1017 out of 5657 images.
# Processed 1018 out of 5657 images.
# Processed 1019 out of 5657 images.
# Processed 1020 out of 5657 images.
# Processed 1021 out of 5657 images.
# Processed 1022 out of 5657 images.
# Processed 1023 out of 5657 images.
# Processed 1024 out of 5657 images.
# Processed 1025 out of 5657 images.
# Processed 1026 out of 5657 images.
# Processed 1027 out of 5657 images.
# Processed 1028 out of 5657 images.
# Processed 1029 out of 5657 images.
# Processed 1030 out of 5657 images.
# Processed 1031 out of 5657 images.
# Processed 1032 out of 5657 images.
# Processed 1033 out of 5657 images.
# Processed 1034 out of 5657 images.
# Processed 1035 out of 5657 images.
# Processed 1036 out of 5657 images.
# Processed 1037 out of 5657 images.
# Processed 1038 out of 5657 images.
# Processed 1039 out of 5657 images.
# Processed 1040 out of 5657 images.
# Processed 1041 out of 5657 images.
# Processed 1042 out of 5657 images.
# Processed 1043 out of 5657 images.
# Processed 1044 out of 5657 images.
# Processed 1045 out of 5657 images.
# Processed 1046 out of 5657 images.
# Processed 1047 out of 5657 images.
# Processed 1048 out of 5657 images.
# Processed 1049 out of 5657 images.
# Processed 1050 out of 5657 images.
# Processed 1051 out of 5657 images.
# Processed 1052 out of 5657 images.
# Processed 1053 out of 5657 images.
# Processed 1054 out of 5657 images.
# Processed 1055 out of 5657 images.
# Processed 1056 out of 5657 images.
# Processed 1057 out of 5657 images.
# Processed 1058 out of 5657 images.
# Processed 1059 out of 5657 images.
# Processed 1060 out of 5657 images.
# Processed 1061 out of 5657 images.
# Processed 1062 out of 5657 images.
# Processed 1063 out of 5657 images.
# Processed 1064 out of 5657 images.
# Processed 1065 out of 5657 images.
# Processed 1066 out of 5657 images.
# Processed 1067 out of 5657 images.
# Processed 1068 out of 5657 images.
# Processed 1069 out of 5657 images.
# Processed 1070 out of 5657 images.
# Processed 1071 out of 5657 images.
# Processed 1072 out of 5657 images.
# Processed 1073 out of 5657 images.
# Processed 1074 out of 5657 images.
# Processed 1075 out of 5657 images.
# Processed 1076 out of 5657 images.
# Processed 1077 out of 5657 images.
# Processed 1078 out of 5657 images.
# Processed 1079 out of 5657 images.
# Processed 1080 out of 5657 images.
# Processed 1081 out of 5657 images.
# Processed 1082 out of 5657 images.
# Processed 1083 out of 5657 images.
# Processed 1084 out of 5657 images.
# Processed 1085 out of 5657 images.
# Processed 1086 out of 5657 images.
# Processed 1087 out of 5657 images.
# Processed 1088 out of 5657 images.
# Processed 1089 out of 5657 images.
# Processed 1090 out of 5657 images.
# Processed 1091 out of 5657 images.
# Processed 1092 out of 5657 images.
# Processed 1093 out of 5657 images.
# Processed 1094 out of 5657 images.
# Processed 1095 out of 5657 images.
# Processed 1096 out of 5657 images.
# Processed 1097 out of 5657 images.
# Processed 1098 out of 5657 images.
# Processed 1099 out of 5657 images.
# Processed 1100 out of 5657 images.
# Processed 1101 out of 5657 images.
# Processed 1102 out of 5657 images.
# Processed 1103 out of 5657 images.
# Processed 1104 out of 5657 images.
# Processed 1105 out of 5657 images.
# Processed 1106 out of 5657 images.
# Processed 1107 out of 5657 images.
# Processed 1108 out of 5657 images.
# Processed 1109 out of 5657 images.
# Processed 1110 out of 5657 images.
# Processed 1111 out of 5657 images.
# Processed 1112 out of 5657 images.
# Processed 1113 out of 5657 images.
# Processed 1114 out of 5657 images.
# Processed 1115 out of 5657 images.
# Processed 1116 out of 5657 images.
# Processed 1117 out of 5657 images.
# Processed 1118 out of 5657 images.
# Processed 1119 out of 5657 images.
# Processed 1120 out of 5657 images.
# Processed 1121 out of 5657 images.
# Processed 1122 out of 5657 images.
# Processed 1123 out of 5657 images.
# Processed 1124 out of 5657 images.
# Processed 1125 out of 5657 images.
# Processed 1126 out of 5657 images.
# Processed 1127 out of 5657 images.
# Processed 1128 out of 5657 images.
# Processed 1129 out of 5657 images.
# Processed 1130 out of 5657 images.
# Processed 1131 out of 5657 images.
# Processed 1132 out of 5657 images.
# Processed 1133 out of 5657 images.
# Processed 1134 out of 5657 images.
# Processed 1135 out of 5657 images.
# Processed 1136 out of 5657 images.
# Processed 1137 out of 5657 images.
# Processed 1138 out of 5657 images.
# Processed 1139 out of 5657 images.
# Processed 1140 out of 5657 images.
# Processed 1141 out of 5657 images.
# Processed 1142 out of 5657 images.
# Processed 1143 out of 5657 images.
# Processed 1144 out of 5657 images.
# Processed 1145 out of 5657 images.
# Processed 1146 out of 5657 images.
# Processed 1147 out of 5657 images.
# Processed 1148 out of 5657 images.
# Processed 1149 out of 5657 images.
# Processed 1150 out of 5657 images.
# Processed 1151 out of 5657 images.
# Processed 1152 out of 5657 images.
# Processed 1153 out of 5657 images.
# Processed 1154 out of 5657 images.
# Processed 1155 out of 5657 images.
# Processed 1156 out of 5657 images.
# Processed 1157 out of 5657 images.
# Processed 1158 out of 5657 images.
# Processed 1159 out of 5657 images.
# Processed 1160 out of 5657 images.
# Processed 1161 out of 5657 images.
# Processed 1162 out of 5657 images.
# Processed 1163 out of 5657 images.
# Processed 1164 out of 5657 images.
# Processed 1165 out of 5657 images.
# Processed 1166 out of 5657 images.
# Processed 1167 out of 5657 images.
# Processed 1168 out of 5657 images.
# Processed 1169 out of 5657 images.
# Processed 1170 out of 5657 images.
# Processed 1171 out of 5657 images.
# Processed 1172 out of 5657 images.
# Processed 1173 out of 5657 images.
# Processed 1174 out of 5657 images.
# Processed 1175 out of 5657 images.
# Processed 1176 out of 5657 images.
# Processed 1177 out of 5657 images.
# Processed 1178 out of 5657 images.
# Processed 1179 out of 5657 images.
# Processed 1180 out of 5657 images.
# Processed 1181 out of 5657 images.
# Processed 1182 out of 5657 images.
# Processed 1183 out of 5657 images.
# Processed 1184 out of 5657 images.
# Processed 1185 out of 5657 images.
# Processed 1186 out of 5657 images.
# Processed 1187 out of 5657 images.
# Processed 1188 out of 5657 images.
# Processed 1189 out of 5657 images.
# Processed 1190 out of 5657 images.
# Processed 1191 out of 5657 images.
# Processed 1192 out of 5657 images.
# Processed 1193 out of 5657 images.
# Processed 1194 out of 5657 images.
# Processed 1195 out of 5657 images.
# Processed 1196 out of 5657 images.
# Processed 1197 out of 5657 images.
# Processed 1198 out of 5657 images.
# Processed 1199 out of 5657 images.
# Processed 1200 out of 5657 images.
# Processed 1201 out of 5657 images.
# Processed 1202 out of 5657 images.
# Processed 1203 out of 5657 images.
# Processed 1204 out of 5657 images.
# Processed 1205 out of 5657 images.
# Processed 1206 out of 5657 images.
# Processed 1207 out of 5657 images.
# Processed 1208 out of 5657 images.
# Processed 1209 out of 5657 images.
# Processed 1210 out of 5657 images.
# Processed 1211 out of 5657 images.
# Processed 1212 out of 5657 images.
# Processed 1213 out of 5657 images.
# Processed 1214 out of 5657 images.
# Processed 1215 out of 5657 images.
# Processed 1216 out of 5657 images.
# Processed 1217 out of 5657 images.
# Processed 1218 out of 5657 images.
# Processed 1219 out of 5657 images.
# Processed 1220 out of 5657 images.
# Processed 1221 out of 5657 images.
# Processed 1222 out of 5657 images.
# Processed 1223 out of 5657 images.
# Processed 1224 out of 5657 images.
# Processed 1225 out of 5657 images.
# Processed 1226 out of 5657 images.
# Processed 1227 out of 5657 images.
# Processed 1228 out of 5657 images.
# Processed 1229 out of 5657 images.
# Processed 1230 out of 5657 images.
# Processed 1231 out of 5657 images.
# Processed 1232 out of 5657 images.
# Processed 1233 out of 5657 images.
# Processed 1234 out of 5657 images.
# Processed 1235 out of 5657 images.
# Processed 1236 out of 5657 images.
# Processed 1237 out of 5657 images.
# Processed 1238 out of 5657 images.
# Processed 1239 out of 5657 images.
# Processed 1240 out of 5657 images.
# Processed 1241 out of 5657 images.
# Processed 1242 out of 5657 images.
# Processed 1243 out of 5657 images.
# Processed 1244 out of 5657 images.
# Processed 1245 out of 5657 images.
# Processed 1246 out of 5657 images.
# Processed 1247 out of 5657 images.
# Processed 1248 out of 5657 images.
# Processed 1249 out of 5657 images.
# Processed 1250 out of 5657 images.
# Processed 1251 out of 5657 images.
# Processed 1252 out of 5657 images.
# Processed 1253 out of 5657 images.
# Processed 1254 out of 5657 images.
# Processed 1255 out of 5657 images.
# Processed 1256 out of 5657 images.
# Processed 1257 out of 5657 images.
# Processed 1258 out of 5657 images.
# Processed 1259 out of 5657 images.
# Processed 1260 out of 5657 images.
# Processed 1261 out of 5657 images.
# Processed 1262 out of 5657 images.
# Processed 1263 out of 5657 images.
# Processed 1264 out of 5657 images.
# Processed 1265 out of 5657 images.
# Processed 1266 out of 5657 images.
# Processed 1267 out of 5657 images.
# Processed 1268 out of 5657 images.
# Processed 1269 out of 5657 images.
# Processed 1270 out of 5657 images.
# Processed 1271 out of 5657 images.
# Processed 1272 out of 5657 images.
# Processed 1273 out of 5657 images.
# Processed 1274 out of 5657 images.
# Processed 1275 out of 5657 images.
# Processed 1276 out of 5657 images.
# Processed 1277 out of 5657 images.
# Processed 1278 out of 5657 images.
# Processed 1279 out of 5657 images.
# Processed 1280 out of 5657 images.
# Processed 1281 out of 5657 images.
# Processed 1282 out of 5657 images.
# Processed 1283 out of 5657 images.
# Processed 1284 out of 5657 images.
# Processed 1285 out of 5657 images.
# Processed 1286 out of 5657 images.
# Processed 1287 out of 5657 images.
# Processed 1288 out of 5657 images.
# Processed 1289 out of 5657 images.
# Processed 1290 out of 5657 images.
# Processed 1291 out of 5657 images.
# Processed 1292 out of 5657 images.
# Processed 1293 out of 5657 images.
# Processed 1294 out of 5657 images.
# Processed 1295 out of 5657 images.
# Processed 1296 out of 5657 images.
# Processed 1297 out of 5657 images.
# Processed 1298 out of 5657 images.
# Processed 1299 out of 5657 images.
# Processed 1300 out of 5657 images.
# Processed 1301 out of 5657 images.
# Processed 1302 out of 5657 images.
# Processed 1303 out of 5657 images.
# Processed 1304 out of 5657 images.
# Processed 1305 out of 5657 images.
# Processed 1306 out of 5657 images.
# Processed 1307 out of 5657 images.
# Processed 1308 out of 5657 images.
# Processed 1309 out of 5657 images.
# Processed 1310 out of 5657 images.
# Processed 1311 out of 5657 images.
# Processed 1312 out of 5657 images.
# Processed 1313 out of 5657 images.
# Processed 1314 out of 5657 images.
# Processed 1315 out of 5657 images.
# Processed 1316 out of 5657 images.
# Processed 1317 out of 5657 images.
# Processed 1318 out of 5657 images.
# Processed 1319 out of 5657 images.
# Processed 1320 out of 5657 images.
# Processed 1321 out of 5657 images.
# Processed 1322 out of 5657 images.
# Processed 1323 out of 5657 images.
# Processed 1324 out of 5657 images.
# Processed 1325 out of 5657 images.
# Processed 1326 out of 5657 images.
# Processed 1327 out of 5657 images.
# Processed 1328 out of 5657 images.
# Processed 1329 out of 5657 images.
# Processed 1330 out of 5657 images.
# Processed 1331 out of 5657 images.
# Processed 1332 out of 5657 images.
# Processed 1333 out of 5657 images.
# Processed 1334 out of 5657 images.
# Processed 1335 out of 5657 images.
# Processed 1336 out of 5657 images.
# Processed 1337 out of 5657 images.
# Processed 1338 out of 5657 images.
# Processed 1339 out of 5657 images.
# Processed 1340 out of 5657 images.
# Processed 1341 out of 5657 images.
# Processed 1342 out of 5657 images.
# Processed 1343 out of 5657 images.
# Processed 1344 out of 5657 images.
# Processed 1345 out of 5657 images.
# Processed 1346 out of 5657 images.
# Processed 1347 out of 5657 images.
# Processed 1348 out of 5657 images.
# Processed 1349 out of 5657 images.
# Processed 1350 out of 5657 images.
# Processed 1351 out of 5657 images.
# Processed 1352 out of 5657 images.
# Processed 1353 out of 5657 images.
# Processed 1354 out of 5657 images.
# Processed 1355 out of 5657 images.
# Processed 1356 out of 5657 images.
# Processed 1357 out of 5657 images.
# Processed 1358 out of 5657 images.
# Processed 1359 out of 5657 images.
# Processed 1360 out of 5657 images.
# Processed 1361 out of 5657 images.
# Processed 1362 out of 5657 images.
# Processed 1363 out of 5657 images.
# Processed 1364 out of 5657 images.
# Processed 1365 out of 5657 images.
# Processed 1366 out of 5657 images.
# Processed 1367 out of 5657 images.
# Processed 1368 out of 5657 images.
# Processed 1369 out of 5657 images.
# Processed 1370 out of 5657 images.
# Processed 1371 out of 5657 images.
# Processed 1372 out of 5657 images.
# Processed 1373 out of 5657 images.
# Processed 1374 out of 5657 images.
# Processed 1375 out of 5657 images.
# Processed 1376 out of 5657 images.
# Processed 1377 out of 5657 images.
# Processed 1378 out of 5657 images.
# Processed 1379 out of 5657 images.
# Processed 1380 out of 5657 images.
# Processed 1381 out of 5657 images.
# Processed 1382 out of 5657 images.
# Processed 1383 out of 5657 images.
# Processed 1384 out of 5657 images.
# Processed 1385 out of 5657 images.
# Processed 1386 out of 5657 images.
# Processed 1387 out of 5657 images.
# Processed 1388 out of 5657 images.
# Processed 1389 out of 5657 images.
# ...
# Processed 5201 out of 5657 images.
# Processed 5202 out of 5657 images.
# Processed 5203 out of 5657 images.
# Processed 5204 out of 5657 images.
# Processed 5205 out of 5657 images.
# Processed 5206 out of 5657 images.
# Processed 5207 out of 5657 images.
# Processed 5208 out of 5657 images.
# Processed 5209 out of 5657 images.
# Processed 5210 out of 5657 images.
# Processed 5211 out of 5657 images.
# Processed 5212 out of 5657 images.
# Processed 5213 out of 5657 images.
# Processed 5214 out of 5657 images.
# Processed 5215 out of 5657 images.
# Processed 5216 out of 5657 images.
# Processed 5217 out of 5657 images.
# Processed 5218 out of 5657 images.
# Processed 5219 out of 5657 images.
# Processed 5220 out of 5657 images.
# Processed 5221 out of 5657 images.
# Processed 5222 out of 5657 images.
# Processed 5223 out of 5657 images.
# Processed 5224 out of 5657 images.
# Processed 5225 out of 5657 images.
# Processed 5226 out of 5657 images.
# Processed 5227 out of 5657 images.
# Processed 5228 out of 5657 images.
# Processed 5229 out of 5657 images.
# Processed 5230 out of 5657 images.
# Processed 5231 out of 5657 images.
# Processed 5232 out of 5657 images.
# Processed 5233 out of 5657 images.
# Processed 5234 out of 5657 images.
# Processed 5235 out of 5657 images.
# Processed 5236 out of 5657 images.
# Processed 5237 out of 5657 images.
# Processed 5238 out of 5657 images.
# Processed 5239 out of 5657 images.
# Processed 5240 out of 5657 images.
# Processed 5241 out of 5657 images.
# Processed 5242 out of 5657 images.
# Processed 5243 out of 5657 images.
# Processed 5244 out of 5657 images.
# Processed 5245 out of 5657 images.
# Processed 5246 out of 5657 images.
# Processed 5247 out of 5657 images.
# Processed 5248 out of 5657 images.
# Processed 5249 out of 5657 images.
# Processed 5250 out of 5657 images.
# Processed 5251 out of 5657 images.
# Processed 5252 out of 5657 images.
# Processed 5253 out of 5657 images.
# Processed 5254 out of 5657 images.
# Processed 5255 out of 5657 images.
# Processed 5256 out of 5657 images.
# Processed 5257 out of 5657 images.
# Processed 5258 out of 5657 images.
# Processed 5259 out of 5657 images.
# Processed 5260 out of 5657 images.
# Processed 5261 out of 5657 images.
# Processed 5262 out of 5657 images.
# Processed 5263 out of 5657 images.
# Processed 5264 out of 5657 images.
# Processed 5265 out of 5657 images.
# Processed 5266 out of 5657 images.
# Processed 5267 out of 5657 images.
# Processed 5268 out of 5657 images.
# Processed 5269 out of 5657 images.
# Processed 5270 out of 5657 images.
# Processed 5271 out of 5657 images.
# Processed 5272 out of 5657 images.
# Processed 5273 out of 5657 images.
# Processed 5274 out of 5657 images.
# Processed 5275 out of 5657 images.
# Processed 5276 out of 5657 images.
# Processed 5277 out of 5657 images.
# Processed 5278 out of 5657 images.
# Processed 5279 out of 5657 images.
# Processed 5280 out of 5657 images.
# Processed 5281 out of 5657 images.
# Processed 5282 out of 5657 images.
# Processed 5283 out of 5657 images.
# Processed 5284 out of 5657 images.
# Processed 5285 out of 5657 images.
# Processed 5286 out of 5657 images.
# Processed 5287 out of 5657 images.
# Processed 5288 out of 5657 images.
# Processed 5289 out of 5657 images.
# Processed 5290 out of 5657 images.
# Processed 5291 out of 5657 images.
# Processed 5292 out of 5657 images.
# Processed 5293 out of 5657 images.
# Processed 5294 out of 5657 images.
# Processed 5295 out of 5657 images.
# Processed 5296 out of 5657 images.
# Processed 5297 out of 5657 images.
# Processed 5298 out of 5657 images.
# Processed 5299 out of 5657 images.
# Processed 5300 out of 5657 images.
# Processed 5301 out of 5657 images.
# Processed 5302 out of 5657 images.
# Processed 5303 out of 5657 images.
# Processed 5304 out of 5657 images.
# Processed 5305 out of 5657 images.
# Processed 5306 out of 5657 images.
# Processed 5307 out of 5657 images.
# Processed 5308 out of 5657 images.
# Processed 5309 out of 5657 images.
# Processed 5310 out of 5657 images.
# Processed 5311 out of 5657 images.
# Processed 5312 out of 5657 images.
# Processed 5313 out of 5657 images.
# Processed 5314 out of 5657 images.
# Processed 5315 out of 5657 images.
# Processed 5316 out of 5657 images.
# Processed 5317 out of 5657 images.
# Processed 5318 out of 5657 images.
# Processed 5319 out of 5657 images.
# Processed 5320 out of 5657 images.
# Processed 5321 out of 5657 images.
# Processed 5322 out of 5657 images.
# Processed 5323 out of 5657 images.
# Processed 5324 out of 5657 images.
# Processed 5325 out of 5657 images.
# Processed 5326 out of 5657 images.
# Processed 5327 out of 5657 images.
# Processed 5328 out of 5657 images.
# Processed 5329 out of 5657 images.
# Processed 5330 out of 5657 images.
# Processed 5331 out of 5657 images.
# Processed 5332 out of 5657 images.
# Processed 5333 out of 5657 images.
# Processed 5334 out of 5657 images.
# Processed 5335 out of 5657 images.
# Processed 5336 out of 5657 images.
# Processed 5337 out of 5657 images.
# Processed 5338 out of 5657 images.
# Processed 5339 out of 5657 images.
# Processed 5340 out of 5657 images.
# Processed 5341 out of 5657 images.
# Processed 5342 out of 5657 images.
# Processed 5343 out of 5657 images.
# Processed 5344 out of 5657 images.
# Processed 5345 out of 5657 images.
# Processed 5346 out of 5657 images.
# Processed 5347 out of 5657 images.
# Processed 5348 out of 5657 images.
# Processed 5349 out of 5657 images.
# Processed 5350 out of 5657 images.
# Processed 5351 out of 5657 images.
# Processed 5352 out of 5657 images.
# Processed 5353 out of 5657 images.
# Processed 5354 out of 5657 images.
# Processed 5355 out of 5657 images.
# Processed 5356 out of 5657 images.
# Processed 5357 out of 5657 images.
# Processed 5358 out of 5657 images.
# Processed 5359 out of 5657 images.
# Processed 5360 out of 5657 images.
# Processed 5361 out of 5657 images.
# Processed 5362 out of 5657 images.
# Processed 5363 out of 5657 images.
# Processed 5364 out of 5657 images.
# Processed 5365 out of 5657 images.
# Processed 5366 out of 5657 images.
# Processed 5367 out of 5657 images.
# Processed 5368 out of 5657 images.
# Processed 5369 out of 5657 images.
# Processed 5370 out of 5657 images.
# Processed 5371 out of 5657 images.
# Processed 5372 out of 5657 images.
# Processed 5373 out of 5657 images.
# Processed 5374 out of 5657 images.
# Processed 5375 out of 5657 images.
# Processed 5376 out of 5657 images.
# Processed 5377 out of 5657 images.
# Processed 5378 out of 5657 images.
# Processed 5379 out of 5657 images.
# Processed 5380 out of 5657 images.
# Processed 5381 out of 5657 images.
# Processed 5382 out of 5657 images.
# Processed 5383 out of 5657 images.
# Processed 5384 out of 5657 images.
# Processed 5385 out of 5657 images.
# Processed 5386 out of 5657 images.
# Processed 5387 out of 5657 images.
# Processed 5388 out of 5657 images.
# Processed 5389 out of 5657 images.
# Processed 5390 out of 5657 images.
# Processed 5391 out of 5657 images.
# Processed 5392 out of 5657 images.
# Processed 5393 out of 5657 images.
# Processed 5394 out of 5657 images.
# Processed 5395 out of 5657 images.
# Processed 5396 out of 5657 images.
# Processed 5397 out of 5657 images.
# Processed 5398 out of 5657 images.
# Processed 5399 out of 5657 images.
# Processed 5400 out of 5657 images.
# Processed 5401 out of 5657 images.
# Processed 5402 out of 5657 images.
# Processed 5403 out of 5657 images.
# Processed 5404 out of 5657 images.
# Processed 5405 out of 5657 images.
# Processed 5406 out of 5657 images.
# Processed 5407 out of 5657 images.
# Processed 5408 out of 5657 images.
# Processed 5409 out of 5657 images.
# Processed 5410 out of 5657 images.
# Processed 5411 out of 5657 images.
# Processed 5412 out of 5657 images.
# Processed 5413 out of 5657 images.
# Processed 5414 out of 5657 images.
# Processed 5415 out of 5657 images.
# Processed 5416 out of 5657 images.
# Processed 5417 out of 5657 images.
# Processed 5418 out of 5657 images.
# Processed 5419 out of 5657 images.
# Processed 5420 out of 5657 images.
# Processed 5421 out of 5657 images.
# Processed 5422 out of 5657 images.
# Processed 5423 out of 5657 images.
# Processed 5424 out of 5657 images.
# Processed 5425 out of 5657 images.
# Processed 5426 out of 5657 images.
# Processed 5427 out of 5657 images.
# Processed 5428 out of 5657 images.
# Processed 5429 out of 5657 images.
# Processed 5430 out of 5657 images.
# Processed 5431 out of 5657 images.
# Processed 5432 out of 5657 images.
# Processed 5433 out of 5657 images.
# Processed 5434 out of 5657 images.
# Processed 5435 out of 5657 images.
# Processed 5436 out of 5657 images.
# Processed 5437 out of 5657 images.
# Processed 5438 out of 5657 images.
# Processed 5439 out of 5657 images.
# Processed 5440 out of 5657 images.
# Processed 5441 out of 5657 images.
# Processed 5442 out of 5657 images.
# Processed 5443 out of 5657 images.
# Processed 5444 out of 5657 images.
# Processed 5445 out of 5657 images.
# Processed 5446 out of 5657 images.
# Processed 5447 out of 5657 images.
# Processed 5448 out of 5657 images.
# Processed 5449 out of 5657 images.
# Processed 5450 out of 5657 images.
# Processed 5451 out of 5657 images.
# Processed 5452 out of 5657 images.
# Processed 5453 out of 5657 images.
# Processed 5454 out of 5657 images.
# Processed 5455 out of 5657 images.
# Processed 5456 out of 5657 images.
# Processed 5457 out of 5657 images.
# Processed 5458 out of 5657 images.
# Processed 5459 out of 5657 images.
# Processed 5460 out of 5657 images.
# Processed 5461 out of 5657 images.
# Processed 5462 out of 5657 images.
# Processed 5463 out of 5657 images.
# Processed 5464 out of 5657 images.
# Processed 5465 out of 5657 images.
# Processed 5466 out of 5657 images.
# Processed 5467 out of 5657 images.
# Processed 5468 out of 5657 images.
# Processed 5469 out of 5657 images.
# Processed 5470 out of 5657 images.
# Processed 5471 out of 5657 images.
# Processed 5472 out of 5657 images.
# Processed 5473 out of 5657 images.
# Processed 5474 out of 5657 images.
# Processed 5475 out of 5657 images.
# Processed 5476 out of 5657 images.
# Processed 5477 out of 5657 images.
# Processed 5478 out of 5657 images.
# Processed 5479 out of 5657 images.
# Processed 5480 out of 5657 images.
# Processed 5481 out of 5657 images.
# Processed 5482 out of 5657 images.
# Processed 5483 out of 5657 images.
# Processed 5484 out of 5657 images.
# Processed 5485 out of 5657 images.
# Processed 5486 out of 5657 images.
# Processed 5487 out of 5657 images.
# Processed 5488 out of 5657 images.
# Processed 5489 out of 5657 images.
# Processed 5490 out of 5657 images.
# Processed 5491 out of 5657 images.
# Processed 5492 out of 5657 images.
# Processed 5493 out of 5657 images.
# Processed 5494 out of 5657 images.
# Processed 5495 out of 5657 images.
# Processed 5496 out of 5657 images.
# Processed 5497 out of 5657 images.
# Processed 5498 out of 5657 images.
# Processed 5499 out of 5657 images.
# Processed 5500 out of 5657 images.
# Processed 5501 out of 5657 images.
# Processed 5502 out of 5657 images.
# Processed 5503 out of 5657 images.
# Processed 5504 out of 5657 images.
# Processed 5505 out of 5657 images.
# Processed 5506 out of 5657 images.
# Processed 5507 out of 5657 images.
# Processed 5508 out of 5657 images.
# Processed 5509 out of 5657 images.
# Processed 5510 out of 5657 images.
# Processed 5511 out of 5657 images.
# Processed 5512 out of 5657 images.
# Processed 5513 out of 5657 images.
# Processed 5514 out of 5657 images.
# Processed 5515 out of 5657 images.
# Processed 5516 out of 5657 images.
# Processed 5517 out of 5657 images.
# Processed 5518 out of 5657 images.
# Processed 5519 out of 5657 images.
# Processed 5520 out of 5657 images.
# Processed 5521 out of 5657 images.
# Processed 5522 out of 5657 images.
# Processed 5523 out of 5657 images.
# Processed 5524 out of 5657 images.
# Processed 5525 out of 5657 images.
# Processed 5526 out of 5657 images.
# Processed 5527 out of 5657 images.
# Processed 5528 out of 5657 images.
# Processed 5529 out of 5657 images.
# Processed 5530 out of 5657 images.
# Processed 5531 out of 5657 images.
# Processed 5532 out of 5657 images.
# Processed 5533 out of 5657 images.
# Processed 5534 out of 5657 images.
# Processed 5535 out of 5657 images.
# Processed 5536 out of 5657 images.
# Processed 5537 out of 5657 images.
# Processed 5538 out of 5657 images.
# Processed 5539 out of 5657 images.
# Processed 5540 out of 5657 images.
# Processed 5541 out of 5657 images.
# Processed 5542 out of 5657 images.
# Processed 5543 out of 5657 images.
# Processed 5544 out of 5657 images.
# Processed 5545 out of 5657 images.
# Processed 5546 out of 5657 images.
# Processed 5547 out of 5657 images.
# Processed 5548 out of 5657 images.
# Processed 5549 out of 5657 images.
# Processed 5550 out of 5657 images.
# Processed 5551 out of 5657 images.
# Processed 5552 out of 5657 images.
# Processed 5553 out of 5657 images.
# Processed 5554 out of 5657 images.
# Processed 5555 out of 5657 images.
# Processed 5556 out of 5657 images.
# Processed 5557 out of 5657 images.
# Processed 5558 out of 5657 images.
# Processed 5559 out of 5657 images.
# Processed 5560 out of 5657 images.
# Processed 5561 out of 5657 images.
# Processed 5562 out of 5657 images.
# Processed 5563 out of 5657 images.
# Processed 5564 out of 5657 images.
# Processed 5565 out of 5657 images.
# Processed 5566 out of 5657 images.
# Processed 5567 out of 5657 images.
# Processed 5568 out of 5657 images.
# Processed 5569 out of 5657 images.
# Processed 5570 out of 5657 images.
# Processed 5571 out of 5657 images.
# Processed 5572 out of 5657 images.
# Processed 5573 out of 5657 images.
# Processed 5574 out of 5657 images.
# Processed 5575 out of 5657 images.
# Processed 5576 out of 5657 images.
# Processed 5577 out of 5657 images.
# Processed 5578 out of 5657 images.
# Processed 5579 out of 5657 images.
# Processed 5580 out of 5657 images.
# Processed 5581 out of 5657 images.
# Processed 5582 out of 5657 images.
# Processed 5583 out of 5657 images.
# Processed 5584 out of 5657 images.
# Processed 5585 out of 5657 images.
# Processed 5586 out of 5657 images.
# Processed 5587 out of 5657 images.
# Processed 5588 out of 5657 images.
# Processed 5589 out of 5657 images.
# Processed 5590 out of 5657 images.
# Processed 5591 out of 5657 images.
# Processed 5592 out of 5657 images.
# Processed 5593 out of 5657 images.
# Processed 5594 out of 5657 images.
# Processed 5595 out of 5657 images.
# Processed 5596 out of 5657 images.
# Processed 5597 out of 5657 images.
# Processed 5598 out of 5657 images.
# Processed 5599 out of 5657 images.
# Processed 5600 out of 5657 images.
# Processed 5601 out of 5657 images.
# Processed 5602 out of 5657 images.
# Processed 5603 out of 5657 images.
# Processed 5604 out of 5657 images.
# Processed 5605 out of 5657 images.
# Processed 5606 out of 5657 images.
# Processed 5607 out of 5657 images.
# Processed 5608 out of 5657 images.
# Processed 5609 out of 5657 images.
# Processed 5610 out of 5657 images.
# Processed 5611 out of 5657 images.
# Processed 5612 out of 5657 images.
# Processed 5613 out of 5657 images.
# Processed 5614 out of 5657 images.
# Processed 5615 out of 5657 images.
# Processed 5616 out of 5657 images.
# Processed 5617 out of 5657 images.
# Processed 5618 out of 5657 images.
# Processed 5619 out of 5657 images.
# Processed 5620 out of 5657 images.
# Processed 5621 out of 5657 images.
# Processed 5622 out of 5657 images.
# Processed 5623 out of 5657 images.
# Processed 5624 out of 5657 images.
# Processed 5625 out of 5657 images.
# Processed 5626 out of 5657 images.
# Processed 5627 out of 5657 images.
# Processed 5628 out of 5657 images.
# Processed 5629 out of 5657 images.
# Processed 5630 out of 5657 images.
# Processed 5631 out of 5657 images.
# Processed 5632 out of 5657 images.
# Processed 5633 out of 5657 images.
# Processed 5634 out of 5657 images.
# Processed 5635 out of 5657 images.
# Processed 5636 out of 5657 images.
# Processed 5637 out of 5657 images.
# Processed 5638 out of 5657 images.
# Processed 5639 out of 5657 images.
# Processed 5640 out of 5657 images.
# Processed 5641 out of 5657 images.
# Processed 5642 out of 5657 images.
# Processed 5643 out of 5657 images.
# Processed 5644 out of 5657 images.
# Processed 5645 out of 5657 images.
# Processed 5646 out of 5657 images.
# Processed 5647 out of 5657 images.
# Processed 5648 out of 5657 images.
# Processed 5649 out of 5657 images.
# Processed 5650 out of 5657 images.
# Processed 5651 out of 5657 images.
# Processed 5652 out of 5657 images.
# Processed 5653 out of 5657 images.
# Processed 5654 out of 5657 images.
# Processed 5655 out of 5657 images.
# Processed 5656 out of 5657 images.
# Processed 5657 out of 5657 images.

# %%
ioa_thr = 0.9
topk_boxes = 20
rel_peak_thr = 0.7
rel_rel_thr = 0.7

# %%
def postprocess(imgid):
    features_blob = model_output[imgid]['features_blobs']
    class_idx = model_output[imgid]['sorted_labels']
    class_probs = model_output[imgid]['sorted_probs']
    
    nc, h, w = features_blob.shape
    
    detections = []

    for ii in range(class_idx.shape[0]):
        if all_labels[class_idx[ii]] == 'background':
            break
        cam = weight_softmax[class_idx[ii]].dot(features_blob.reshape((nc, h*w)))
        cam = cam.reshape(h, w)
        cam = cam - np.min(cam)
        cam = cam / np.max(cam)

        bboxes = []
        box_scores = []

        peak_coords = peak_local_max(cam, exclude_border=False, threshold_rel=rel_peak_thr)

        heat_resized = cv2.resize(cam, img_shape[imgid])
        
        peak_coords_resized = ((peak_coords + 0.5) * 
                               np.asarray([list(reversed(img_shape[imgid]))]) / 
                               np.asarray([[h, w]])
                              ).astype('int32')

        for pk_coord in peak_coords_resized:
            pk_value = heat_resized[tuple(pk_coord)]
            mask = heat_resized > pk_value * rel_rel_thr
            labeled, n = ndi.label(mask) 
            l = labeled[tuple(pk_coord)]
            yy, xx = np.where(labeled == l)
            min_x = np.min(xx)
            min_y = np.min(yy)
            max_x = np.max(xx)
            max_y = np.max(yy)
            bboxes.append((min_x, min_y, max_x, max_y))
            box_scores.append(pk_value * class_probs[ii])

        box_idx = np.argsort(-np.asarray(box_scores))
        box_idx = box_idx[:min(topk_boxes, len(box_scores))]
        bboxes = [bboxes[i] for i in box_idx]
        box_scores = [box_scores[i] for i in box_idx]

        to_remove = []
        for iii in range(len(bboxes)):
            for iiii in range(iii):
                if iiii in to_remove:
                    continue
                b1 = bboxes[iii]
                b2 = bboxes[iiii]
                isec = max(min(b1[2], b2[2]) - max(b1[0], b2[0]), 0) * max(min(b1[3], b2[3]) - max(b1[1], b2[1]), 0)
                ioa1 = isec / ((b1[2] - b1[0]) * (b1[3] - b1[1]))
                ioa2 = isec / ((b2[2] - b2[0]) * (b2[3] - b2[1]))
                if ioa1 > ioa_thr and ioa1 == ioa2:
                    to_remove.append(iii)
                elif ioa1 > ioa_thr and ioa1 >= ioa2:
                    to_remove.append(iii)
                elif ioa2 > ioa_thr and ioa2 >= ioa1:
                    to_remove.append(iiii)

        for i in range(len(bboxes)): 
            if i not in to_remove:
                detections.append({
                    'label': all_labels[class_idx[ii]],
                    'score': box_scores[i],
                    'bbox': bboxes[i],
                    'bbox_normalized': np.asarray([
                        bboxes[i][0] / heat_resized.shape[1],
                        bboxes[i][1] / heat_resized.shape[0],
                        bboxes[i][2] / heat_resized.shape[1],
                        bboxes[i][3] / heat_resized.shape[0],
                    ]),
                    'model': 'WS'
                })
    
    
    return imgid, detections

# %%
det_results = {}
cnt = 0
with Pool(20) as p:
    for i, res in enumerate(p.imap_unordered(postprocess, model_output.keys())):
        key, val = res
        det_results[key] = val
        cnt += 1
        if cnt % 100 == 0:
            print(f'Postprocessed {cnt} out of {len(model_output)} images.')
# Out:
# Postprocessed 100 out of 5656 images.
# Postprocessed 200 out of 5656 images.
# Postprocessed 300 out of 5656 images.
# Postprocessed 400 out of 5656 images.
# Postprocessed 500 out of 5656 images.
# Postprocessed 600 out of 5656 images.
# Postprocessed 700 out of 5656 images.
# Postprocessed 800 out of 5656 images.
# Postprocessed 900 out of 5656 images.
# Postprocessed 1000 out of 5656 images.
# Postprocessed 1100 out of 5656 images.
# Postprocessed 1200 out of 5656 images.
# Postprocessed 1300 out of 5656 images.
# Postprocessed 1400 out of 5656 images.
# Postprocessed 1500 out of 5656 images.
# Postprocessed 1600 out of 5656 images.
# Postprocessed 1700 out of 5656 images.
# Postprocessed 1800 out of 5656 images.
# Postprocessed 1900 out of 5656 images.
# Postprocessed 2000 out of 5656 images.
# Postprocessed 2100 out of 5656 images.
# Postprocessed 2200 out of 5656 images.
# Postprocessed 2300 out of 5656 images.
# Postprocessed 2400 out of 5656 images.
# Postprocessed 2500 out of 5656 images.
# Postprocessed 2600 out of 5656 images.
# Postprocessed 2700 out of 5656 images.
# Postprocessed 2800 out of 5656 images.
# Postprocessed 2900 out of 5656 images.
# Postprocessed 3000 out of 5656 images.
# Postprocessed 3100 out of 5656 images.
# Postprocessed 3200 out of 5656 images.
# Postprocessed 3300 out of 5656 images.
# Postprocessed 3400 out of 5656 images.
# Postprocessed 3500 out of 5656 images.
# Postprocessed 3600 out of 5656 images.
# Postprocessed 3700 out of 5656 images.
# Postprocessed 3800 out of 5656 images.
# Postprocessed 3900 out of 5656 images.
# Postprocessed 4000 out of 5656 images.
# Postprocessed 4100 out of 5656 images.
# Postprocessed 4200 out of 5656 images.
# Postprocessed 4300 out of 5656 images.
# Postprocessed 4400 out of 5656 images.
# Postprocessed 4500 out of 5656 images.
# Postprocessed 4600 out of 5656 images.
# Postprocessed 4700 out of 5656 images.
# Postprocessed 4800 out of 5656 images.
# Postprocessed 4900 out of 5656 images.
# Postprocessed 5000 out of 5656 images.
# Postprocessed 5100 out of 5656 images.
# Postprocessed 5200 out of 5656 images.
# Postprocessed 5300 out of 5656 images.
# Postprocessed 5400 out of 5656 images.
# Postprocessed 5500 out of 5656 images.
# Postprocessed 5600 out of 5656 images.

# %%
save_obj(det_results, f'../../results/det_results_{exp_name}')
