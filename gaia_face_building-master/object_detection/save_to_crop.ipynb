# %%
import pickle
#with open('/home/brian/google-images-download/google_images_download/country_flag.pickle', 'rb') as handle:
#    OD_result = pickle.load(handle)
#with open('/home/brian/google-images-download/google_images_download/Germany_flag_real.pickle', 'rb') as handle:
#    OD_result = pickle.load(handle)
#with open('pickle/country_flag_all.pickle', 'rb') as handle:
flag_dir_name = 'm18'
with open('pickle/m18.pickle', 'rb') as handle:
    OD_result = pickle.load(handle)

# %%
for x,y in OD_result.items():
    print x
    break
# Out:
# /home/brian/facenet-master/datasets/m18/m18/HC0001YSA.jpg

# %%
i=0
# %pylab inline
import matplotlib
matplotlib.use("Pdf")
from matplotlib import pyplot as plt
from PIL import Image
import pickle
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

directory = flag_dir_name+'/'
if not os.path.exists(directory):
    os.makedirs(directory)
import cv2
bbox = {}
for x,y in OD_result.items():
    i+=1
    print x
    image = Image.open(x)
    #print image
  #print image_path
  # the array based representation of the image will be used later in order to prepare the
  # result image with boxes and labels on it.

    """
    vis_util.visualize_boxes_and_labels_on_image_array(
          image_np,
          y['detection_boxes'],
          y['detection_classes'],
          y['detection_scores'],
          category_index,
          instance_masks=y.get('detection_masks'),
          use_normalized_coordinates=True,
          line_thickness=8)
    """
    #print y['detection_boxes']
    #print y['detection_classes']
    data =x.split('/')[-1][:-4]
    #print data
    count = 0
    flag_n = 0
    for class_t in y['detection_classes']:
        
        if class_t == 85:
            #print y['detection_boxes'][count]
            cor = y['detection_boxes'][count]

            width, height = image.size
            #crop_img = img[int(width*cor[0]):int(width*cor[2]), int(height*cor[1]):int(height*cor[3])]
            area = (int(width*cor[1]),int(height*cor[0]), int(width*cor[3]),int(height*cor[2]))
            #area = (200,0,300,200) #l u r d
            #print area
            #print image.size
            cropped_img = image.crop(area)
            directory2 =directory+'/'+x.split('/')[-2]
            if not os.path.exists(directory2):
                os.makedirs(directory2)
            cropped_img.save(directory2+'/'+data+"_"+str(flag_n)+'.jpg')
            bbox[data+"_"+str(flag_n)] = area
            plt.show()
            flag_n+=1
        count+=1
    #plt.figure(figsize=IMAGE_SIZE)
    #plt.imshow(image_np)
    #print x
    """
    img=mpimg.imread(x)
    imgplot = plt.imshow(img)
    plt.show()
    """
    #if i==5:
    #break
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/brian/facenet-master/datasets/m18/m18/HC0001YSA.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00021N4.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3OH.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC00165YP.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015X5D.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0003GKM.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000879.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001KP.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L46P.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001JK.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001FX.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015PJL.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002NU4.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000RU5.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000SYES.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000SN6B.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3B1.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0011WQX.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001JE.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015PAJ.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002VDH.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC00160Z6.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UF.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015PMG.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00010V8.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00032ON.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001LN.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015OYP.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y5.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000303V.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015QUJ.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000QD9F.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000SRNI.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000ZJ52.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001KF.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002VTY.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000THF6.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015LAM.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00021XD.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000C6X.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3YF.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000R2EG.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002JZY.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000TPVN.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L30B.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015O6T.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QH.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00008J4.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00020JG.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000STCF.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000QSMV.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3SH.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00010VA.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GS.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3B4.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000THEY.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00009VP.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015LAC.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001UV.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0016270.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000R2EK.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000L4K.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015OYM.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002VT4.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015V90.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3AQ.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000SYEU.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002KQW.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0003D9Z.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015OR9.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001JO.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3O9.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000BKQ.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000RYD.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000295W.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000QLTK.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000TPVK.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002SFD.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000ZE8.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015LB2.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0019WE7.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000SWGE.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001FZ.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002KQZ.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00010VE.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002SFB.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000SV3J.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000R3FY.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001613X.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001KD.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L3SI.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC00160YK.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000289K.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001L8.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0001KCM.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015OYL.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0015OIA.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L484.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00032OK.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000STCA.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC00169XV.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002SFE.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0001BRB.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002HIM.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC00160A7.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC00162HF.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L30A.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002VTX.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00009VN.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001JM.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0001SUN.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0001BRA.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001IC.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC00160AA.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC00169LB.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000BKO.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001KB.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001LE.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001GI.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00004I4.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC0019WDU.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000RYE.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001610D.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0002VT3.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0003GKK.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0000YM8.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC000R3G2.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001K8.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC00001J8.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC00160ZR.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001L46Q.jpg
# /home/brian/facenet-master/datasets/m18/m18/HC0001YSB.jpg
# /home/brian/facenet-master/datasets/m18/m18/IC001612U.jpg

# %%
#with open('pickle/bbox.pickle', 'wb') as f:
#    pickle.dump(bbox,f,protocol=pickle.HIGHEST_PROTOCOL)

# %%
"""
from glob import glob
from collections import Counter
countryDic = Counter()
for name in glob('country_flag/*/*'):
    #print name
    data = name.split('/')[-2]
    countryDic[data] +=1
    #break
print countryDic
"""

# %%
"""
count = 0
for x,y in countryDic.items():
    if y<500:
        count+=1
print count
"""
# Out:
# 194
