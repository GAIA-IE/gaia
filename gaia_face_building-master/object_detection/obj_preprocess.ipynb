# %% [markdown]
# # Object Detection Demo
# Welcome to the object detection inference walkthrough!  This notebook will walk you step by step through the process of using a pre-trained model to detect objects in an image. Make sure to follow the [installation instructions](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/installation.md) before you start.

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
import os

folder_path = '/home/brian/facenet-master/datasets/m18'
flag_dic_name = 'm18'

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"
#os.environ['CUDA_VISIBLE_DEVICES'] = '2'

if tf.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found")

from collections import defaultdict
from io import StringIO
import matplotlib
matplotlib.use("Pdf")
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops

if tf.__version__ < '1.4.0':
  raise ImportError('Please upgrade your tensorflow installation to v1.4.* or later!')
# Out:
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/h5py/__init__.py:36: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._conv import register_converters as _register_converters
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/h5py/__init__.py:45: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import h5a, h5d, h5ds, h5f, h5fd, h5g, h5r, h5s, h5t, h5p, h5z
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/h5py/_hl/group.py:22: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .. import h5g, h5i, h5o, h5r, h5t, h5l, h5p
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/sparse/lil.py:19: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import _csparsetools
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/sparse/csgraph/__init__.py:165: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._shortest_path import shortest_path, floyd_warshall, dijkstra,\
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/sparse/csgraph/_validation.py:5: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._tools import csgraph_to_dense, csgraph_from_dense,\
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/sparse/csgraph/__init__.py:167: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._traversal import breadth_first_order, depth_first_order, \
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/sparse/csgraph/__init__.py:169: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._min_spanning_tree import minimum_spanning_tree
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/sparse/csgraph/__init__.py:170: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._reordering import reverse_cuthill_mckee, maximum_bipartite_matching, \
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/linalg/basic.py:17: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._solve_toeplitz import levinson
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/linalg/__init__.py:207: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._decomp_update import *
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/special/__init__.py:640: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._ufuncs import *
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/special/_ellip_harm.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._ellip_harm_2 import _ellipsoid, _ellipsoid_norm
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/interpolate/_bsplines.py:10: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import _bspl
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/spatial/__init__.py:95: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .ckdtree import *
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/spatial/__init__.py:96: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .qhull import *
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/spatial/_spherical_voronoi.py:18: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import _voronoi
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/spatial/distance.py:122: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import _hausdorff
# /dvmm-filer2/users/brian/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/ndimage/measurements.py:36: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import _ni_label
# GPU found

# %% [markdown]
# # Imports

# %% [markdown]
# ## Env setup

# %%
# This is needed to display the images.
# %matplotlib inline

# %% [markdown]
# ## Object detection imports
# Here are the imports from the object detection module.

# %%
from utils import label_map_util

from utils import visualization_utils as vis_util

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Variables
#
# Any model exported using the `export_inference_graph.py` tool can be loaded here simply by changing `PATH_TO_CKPT` to point to a new .pb file.
#
# By default we use an "SSD with Mobilenet" model here. See the [detection model zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md) for a list of other models that can be run out-of-the-box with varying speeds and accuracies.

# %%
# What model to download.
MODEL_NAME = 'ssd_mobilenet_v1_coco_2017_11_17'
MODEL_NAME ='faster_rcnn_inception_resnet_v2_atrous_oid_2018_01_28'
MODEL_FILE = MODEL_NAME + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('data', 'oid_bbox_trainable_label_map.pbtxt')

NUM_CLASSES = 90

# %% [markdown]
# ## Download Model

# %%
#opener = urllib.request.URLopener()
#opener.retrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)
tar_file = tarfile.open(MODEL_FILE)
for file in tar_file.getmembers():
  file_name = os.path.basename(file.name)
  if 'frozen_inference_graph.pb' in file_name:
    tar_file.extract(file, os.getcwd())

# %% [markdown]
# ## Load a (frozen) Tensorflow model into memory.

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.GraphDef()
  with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# %% [markdown]
# ## Loading label map
# Label maps map indices to category names, so that when our convolution network predicts `5`, we know that this corresponds to `airplane`.  Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine

# %%
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %% [markdown]
# ## Helper code

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Detection

# %%
# For the sake of simplicity we will use only 2 images:
# image1.jpg
# image2.jpg
# If you want to test the code with your images, just add path to the images to the TEST_IMAGE_PATHS.
PATH_TO_TEST_IMAGES_DIR = 'test_images'
TEST_IMAGE_PATHS = [ os.path.join(PATH_TO_TEST_IMAGES_DIR, 'image{}.jpg'.format(i)) for i in range(1, 3) ]

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)

# %%
def run_inference_for_single_image(image, graph):
  with graph.as_default():
    with tf.Session() as sess:
      # Get handles to input and output tensors
      ops = tf.get_default_graph().get_operations()
      all_tensor_names = {output.name for op in ops for output in op.outputs}
      tensor_dict = {}
      for key in [
          'num_detections', 'detection_boxes', 'detection_scores',
          'detection_classes', 'detection_masks'
      ]:
        tensor_name = key + ':0'
        if tensor_name in all_tensor_names:
          tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
              tensor_name)
      if 'detection_masks' in tensor_dict:
        # The following processing is only for single image
        detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
        detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
        # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
        real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
        detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
        detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
        detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
            detection_masks, detection_boxes, image.shape[0], image.shape[1])
        detection_masks_reframed = tf.cast(
            tf.greater(detection_masks_reframed, 0.5), tf.uint8)
        # Follow the convention by adding back the batch dimension
        tensor_dict['detection_masks'] = tf.expand_dims(
            detection_masks_reframed, 0)
      image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

      # Run inference
      output_dict = sess.run(tensor_dict,
                             feed_dict={image_tensor: np.expand_dims(image, 0)})

      # all outputs are float32 numpy arrays, so convert types as appropriate
      output_dict['num_detections'] = int(output_dict['num_detections'][0])
      output_dict['detection_classes'] = output_dict[
          'detection_classes'][0].astype(np.uint8)
      output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
      output_dict['detection_scores'] = output_dict['detection_scores'][0]
      if 'detection_masks' in output_dict:
        output_dict['detection_masks'] = output_dict['detection_masks'][0]
  return output_dict

# %%
from glob import glob
import pickle
import time
from collections import defaultdict
import scipy.misc
flag_dict = defaultdict()
building_list = []
building_label = [9,44,46,49]
graph = detection_graph
with graph.as_default():
    with tf.Session() as sess:
      # Get handles to input and output tensors
      ops = tf.get_default_graph().get_operations()
      all_tensor_names = {output.name for op in ops for output in op.outputs}
      tensor_dict = {}
      for key in [
          'num_detections', 'detection_boxes', 'detection_scores',
          'detection_classes', 'detection_masks'
      ]:
        tensor_name = key + ':0'
        if tensor_name in all_tensor_names:
          tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
              tensor_name)
      if 'detection_masks' in tensor_dict:
        # The following processing is only for single image
        detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
        detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
        # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
        real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
        detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
        detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
        detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
            detection_masks, detection_boxes, image.shape[0], image.shape[1])
        detection_masks_reframed = tf.cast(
            tf.greater(detection_masks_reframed, 0.5), tf.uint8)
        # Follow the convention by adding back the batch dimension
        tensor_dict['detection_masks'] = tf.expand_dims(
            detection_masks_reframed, 0)
      image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

      # Run inference
      #for image_path in glob('/home/brian/google-images-download/google_images_download/country_flag_s/U.S._flag_on_building/*.jpg'):
      #for image_path in glob('/home/brian/google-images-download/google_images_download/north_korea_flag/*/*.jpg'):
      for image_path in glob(folder_path+'/*/*.jpg'):
      #for image_path in glob('/home/brian/facenet-master/datasets/ldc_isi_dryrun3/*.jpg'):
          #if 'HC000SYGW.jpg' not in image_path:
          #      continue
          image = Image.open(image_path)
          start_time = time.time()

          print image_path
          # the array based representation of the image will be used later in order to prepare the
          # result image with boxes and labels on it.
          image_np = load_image_into_numpy_array(image)
          # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
          image_np_expanded = np.expand_dims(image_np, axis=0)
          output_dict = sess.run(tensor_dict,
                                 feed_dict={image_tensor: np.expand_dims(image_np, 0)})

          # all outputs are float32 numpy arrays, so convert types as appropriate
          output_dict['num_detections'] = int(output_dict['num_detections'][0])
          output_dict['detection_classes'] = output_dict[
              'detection_classes'][0].astype(np.uint8)
          output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
          output_dict['detection_scores'] = output_dict['detection_scores'][0]
          if 'detection_masks' in output_dict:
            output_dict['detection_masks'] = output_dict['detection_masks'][0]
          if 85 in output_dict['detection_classes']:
            flag_dict[image_path] = output_dict
          for b_label in building_label:
            if b_label in output_dict['detection_classes']:
                building_list.append(image_path)
                break
          print("--- %s seconds ---" % (time.time() - start_time))
          """
          vis_util.visualize_boxes_and_labels_on_image_array(
          image_np,
          output_dict['detection_boxes'],
          output_dict['detection_classes'],
          output_dict['detection_scores'],
          category_index,
          instance_masks=output_dict.get('detection_masks'),
          use_normalized_coordinates=True,
          line_thickness=8)

          plt.figure(figsize=IMAGE_SIZE)
          plt.imshow(image_np)
          
          scipy.misc.imsave('outfile.jpg', image_np)
          """
          #print(output_dict['detection_classes'])
with open('pickle/'+flag_dic_name+'.pickle', 'wb') as f:
    pickle.dump(flag_dict,f,protocol=pickle.HIGHEST_PROTOCOL)
    
#building 9, Tower 44, Skyscraper 46, Sculpture 49
# Out:
# /home/brian/facenet-master/datasets/m18/m18/HC000003F.jpg
# --- 53.0955569744 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000003K.jpg
# --- 1.65471792221 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000F2.jpg
# --- 1.91738605499 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000HW.jpg
# --- 1.57232499123 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000HX.jpg
# --- 0.909727096558 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000HY.jpg
# --- 0.919847011566 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000HZ.jpg
# --- 0.909960985184 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I0.jpg
# --- 0.901139974594 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I1.jpg
# --- 1.56207609177 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I2.jpg
# --- 1.02225494385 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I3.jpg
# --- 0.926597118378 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I4.jpg
# --- 0.922077178955 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I5.jpg
# --- 0.895092010498 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I6.jpg
# --- 1.58599591255 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I7.jpg
# --- 0.925248861313 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I8.jpg
# --- 0.908648967743 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000I9.jpg
# --- 0.90732884407 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000IA.jpg
# --- 0.90549492836 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000IC.jpg
# --- 0.918550014496 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000ID.jpg
# --- 0.905407905579 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000IE.jpg
# --- 0.920773983002 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000IF.jpg
# --- 0.894747018814 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000IG.jpg
# --- 0.90626502037 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000IH.jpg
# --- 0.95198392868 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000II.jpg
# --- 0.877948045731 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000IJ.jpg
# --- 0.928507089615 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00000IK.jpg
# --- 0.894752979279 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000016N.jpg
# --- 1.42226600647 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000016O.jpg
# --- 1.59918379784 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000016P.jpg
# --- 1.80701684952 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001DS.jpg
# --- 6.80093383789 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001DT.jpg
# --- 1.447234869 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001DU.jpg
# --- 1.71079301834 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001DV.jpg
# --- 1.47824382782 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001DZ.jpg
# --- 1.00469708443 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001E0.jpg
# --- 0.875133037567 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FK.jpg
# --- 1.16965603828 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FL.jpg
# --- 1.14139604568 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FM.jpg
# --- 1.4514029026 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FN.jpg
# --- 1.38565707207 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FO.jpg
# --- 1.37195181847 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FP.jpg
# --- 0.845190048218 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FQ.jpg
# --- 1.14169287682 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FR.jpg
# --- 1.16365003586 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FS.jpg
# --- 1.16803216934 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FT.jpg
# --- 1.14214086533 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FU.jpg
# --- 1.11361408234 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FV.jpg
# --- 1.11052083969 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FW.jpg
# --- 1.14490103722 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FX.jpg
# --- 1.11408901215 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FY.jpg
# --- 1.38141512871 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001FZ.jpg
# --- 1.39448904991 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G0.jpg
# --- 1.39854001999 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G1.jpg
# --- 1.37652611732 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G2.jpg
# --- 1.39859104156 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G3.jpg
# --- 1.43293094635 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G4.jpg
# --- 1.40847611427 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G5.jpg
# --- 1.38039588928 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G6.jpg
# --- 1.41683793068 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G7.jpg
# --- 1.42758393288 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G8.jpg
# --- 1.40999293327 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001G9.jpg
# --- 1.39378285408 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GA.jpg
# --- 1.40208292007 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GB.jpg
# --- 1.37252998352 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GC.jpg
# --- 1.3569920063 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GD.jpg
# --- 1.37785506248 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GE.jpg
# --- 1.38080215454 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GF.jpg
# --- 1.40152001381 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GG.jpg
# --- 1.38874411583 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GH.jpg
# --- 1.38719391823 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GI.jpg
# --- 1.42155504227 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GJ.jpg
# --- 0.807643890381 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GK.jpg
# --- 0.819993019104 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GL.jpg
# --- 0.828490972519 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GM.jpg
# --- 0.821717977524 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GN.jpg
# --- 0.834619045258 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GO.jpg
# --- 0.800319910049 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GP.jpg
# --- 0.82714509964 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GQ.jpg
# --- 0.814877033234 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GR.jpg
# --- 0.83429312706 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GS.jpg
# --- 0.819926977158 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GT.jpg
# --- 0.825454950333 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GU.jpg
# --- 0.83735203743 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GV.jpg
# --- 0.826940059662 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GW.jpg
# --- 0.822587966919 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GX.jpg
# --- 0.802587985992 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GY.jpg
# --- 0.820340871811 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001GZ.jpg
# --- 0.827727079391 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H0.jpg
# --- 0.81805896759 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H1.jpg
# --- 0.81026506424 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H2.jpg
# --- 0.829493045807 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H3.jpg
# --- 0.827160835266 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H4.jpg
# --- 1.35899400711 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H5.jpg
# --- 1.41057014465 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H6.jpg
# --- 1.4300301075 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H7.jpg
# --- 1.42009806633 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H8.jpg
# --- 1.44614219666 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001H9.jpg
# --- 1.41766405106 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HA.jpg
# --- 1.40400004387 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HB.jpg
# --- 1.41095900536 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HD.jpg
# --- 1.39466905594 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HE.jpg
# --- 1.41431903839 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HF.jpg
# --- 1.42013597488 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HG.jpg
# --- 1.41717410088 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HH.jpg
# --- 1.41090416908 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HI.jpg
# --- 1.42131495476 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HJ.jpg
# --- 1.43352794647 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HK.jpg
# --- 1.40529417992 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HL.jpg
# --- 1.4075961113 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HM.jpg
# --- 1.39083480835 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HN.jpg
# --- 1.46231913567 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HO.jpg
# --- 1.40511488914 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HP.jpg
# --- 1.40962600708 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HQ.jpg
# --- 1.44289016724 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HR.jpg
# --- 1.42026400566 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HS.jpg
# --- 1.41429400444 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HT.jpg
# --- 1.43708300591 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HU.jpg
# --- 1.35627102852 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HV.jpg
# --- 1.41494703293 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HW.jpg
# --- 1.39737701416 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HX.jpg
# --- 1.43809700012 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HY.jpg
# --- 1.38529992104 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001HZ.jpg
# --- 1.38610005379 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001I0.jpg
# --- 1.4096930027 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001I1.jpg
# --- 1.40560102463 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001I2.jpg
# --- 1.37754487991 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001I3.jpg
# --- 1.40285110474 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001I5.jpg
# --- 1.41659498215 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001I6.jpg
# --- 1.42452812195 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001I7.jpg
# --- 1.41312599182 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001I8.jpg
# --- 1.37766599655 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001I9.jpg
# --- 1.36264300346 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IA.jpg
# --- 1.45301198959 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IB.jpg
# --- 1.41138005257 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IC.jpg
# --- 1.36838006973 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001ID.jpg
# --- 1.40529799461 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IE.jpg
# --- 1.41334199905 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IF.jpg
# --- 1.38915300369 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IG.jpg
# --- 1.39342594147 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IH.jpg
# --- 1.38680315018 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001II.jpg
# --- 1.34295201302 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IJ.jpg
# --- 1.3204741478 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IK.jpg
# --- 1.38323497772 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IL.jpg
# --- 1.3780670166 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IM.jpg
# --- 1.34527492523 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IN.jpg
# --- 1.38698601723 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IO.jpg
# --- 1.40577483177 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IP.jpg
# --- 1.36038804054 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IQ.jpg
# --- 1.4204211235 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IR.jpg
# --- 1.40319108963 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IS.jpg
# --- 1.41939401627 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IT.jpg
# --- 1.4020152092 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IU.jpg
# --- 1.41667580605 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IV.jpg
# --- 1.37882399559 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IW.jpg
# --- 1.35920405388 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IX.jpg
# --- 1.41460108757 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IY.jpg
# --- 1.39348292351 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001IZ.jpg
# --- 1.40353989601 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J0.jpg
# --- 1.37367010117 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J1.jpg
# --- 1.42552900314 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J2.jpg
# --- 1.43679499626 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J3.jpg
# --- 1.42247104645 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J4.jpg
# --- 1.39746189117 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J5.jpg
# --- 1.39204406738 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J6.jpg
# --- 1.3399169445 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J7.jpg
# --- 1.38444399834 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J8.jpg
# --- 1.41034293175 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001J9.jpg
# --- 1.3718791008 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JA.jpg
# --- 1.38001990318 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JB.jpg
# --- 1.37409591675 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JC.jpg
# --- 1.37867903709 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JD.jpg
# --- 1.37024307251 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JE.jpg
# --- 1.36651611328 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JF.jpg
# --- 1.38581705093 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JG.jpg
# --- 1.37027907372 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JH.jpg
# --- 1.35640501976 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JI.jpg
# --- 1.42965102196 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JJ.jpg
# --- 1.38373589516 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JK.jpg
# --- 1.37930202484 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JL.jpg
# --- 1.42694401741 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JM.jpg
# --- 1.37020802498 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JN.jpg
# --- 1.3676109314 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JO.jpg
# --- 1.39106893539 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JP.jpg
# --- 1.38958501816 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JQ.jpg
# --- 1.36976003647 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JR.jpg
# --- 1.39573502541 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JS.jpg
# --- 1.38016700745 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JT.jpg
# --- 1.38869380951 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JU.jpg
# --- 1.35462403297 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JV.jpg
# --- 1.37220311165 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JW.jpg
# --- 1.37603497505 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JX.jpg
# --- 1.37329888344 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JY.jpg
# --- 1.3850569725 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001JZ.jpg
# --- 1.37574195862 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K0.jpg
# --- 1.33310294151 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K1.jpg
# --- 1.36357092857 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K2.jpg
# --- 1.37985396385 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K3.jpg
# --- 1.40074110031 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K4.jpg
# --- 1.39446091652 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K5.jpg
# --- 1.41470384598 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K6.jpg
# --- 1.39630103111 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K7.jpg
# --- 1.38703393936 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K8.jpg
# --- 1.43550181389 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001K9.jpg
# --- 1.41640281677 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KA.jpg
# --- 1.34495091438 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KB.jpg
# --- 1.39654493332 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KC.jpg
# --- 1.37055182457 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KD.jpg
# --- 1.35611391068 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KE.jpg
# --- 1.38715696335 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KF.jpg
# --- 1.37457799911 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KG.jpg
# --- 1.36275792122 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KH.jpg
# --- 1.39743614197 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KI.jpg
# --- 1.36960601807 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KJ.jpg
# --- 1.36662983894 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KK.jpg
# --- 1.37250804901 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KL.jpg
# --- 1.3542599678 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KM.jpg
# --- 1.35787415504 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KN.jpg
# --- 1.35333204269 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KO.jpg
# --- 1.37385201454 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KP.jpg
# --- 1.40320611 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KQ.jpg
# --- 1.40416288376 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KR.jpg
# --- 1.36368894577 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KS.jpg
# --- 1.35855197906 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KT.jpg
# --- 1.39635396004 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KU.jpg
# --- 1.37548804283 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KV.jpg
# --- 1.38419890404 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KW.jpg
# --- 1.37046694756 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KX.jpg
# --- 1.36217188835 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KY.jpg
# --- 1.3774728775 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001KZ.jpg
# --- 1.36412501335 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L0.jpg
# --- 1.37075018883 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L1.jpg
# --- 1.40087914467 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L2.jpg
# --- 1.34893798828 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L3.jpg
# --- 1.38182997704 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L4.jpg
# --- 1.37627887726 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L5.jpg
# --- 1.37278985977 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L6.jpg
# --- 1.35489988327 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L7.jpg
# --- 1.37115502357 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L8.jpg
# --- 1.41089200974 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001L9.jpg
# --- 1.36824607849 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LB.jpg
# --- 1.35868191719 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LC.jpg
# --- 1.37241697311 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LD.jpg
# --- 1.35144305229 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LE.jpg
# --- 1.38390803337 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LF.jpg
# --- 1.35538387299 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LG.jpg
# --- 1.37136101723 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LH.jpg
# --- 1.35198092461 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LI.jpg
# --- 1.39042186737 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LJ.jpg
# --- 1.33901691437 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LK.jpg
# --- 1.36730694771 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LL.jpg
# --- 1.38256287575 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LM.jpg
# --- 1.36602687836 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LN.jpg
# --- 1.36187791824 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LO.jpg
# --- 1.37382388115 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LP.jpg
# --- 1.38664007187 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LQ.jpg
# --- 1.34551215172 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LR.jpg
# --- 1.40272712708 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LS.jpg
# --- 0.770468950272 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LT.jpg
# --- 0.771791934967 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LU.jpg
# --- 0.781732082367 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LV.jpg
# --- 0.793292999268 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LW.jpg
# --- 0.783810138702 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LX.jpg
# --- 0.771664142609 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LY.jpg
# --- 0.785089969635 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001LZ.jpg
# --- 0.787304162979 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M0.jpg
# --- 0.777390003204 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M1.jpg
# --- 0.772001028061 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M2.jpg
# --- 0.785322904587 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M3.jpg
# --- 0.779583930969 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M4.jpg
# --- 0.776287078857 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M5.jpg
# --- 0.791614055634 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M6.jpg
# --- 0.83290886879 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M7.jpg
# --- 0.806191921234 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M8.jpg
# --- 0.805855035782 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001M9.jpg
# --- 0.812088012695 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MA.jpg
# --- 0.810013055801 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MB.jpg
# --- 0.822449207306 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MC.jpg
# --- 0.827519893646 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MD.jpg
# --- 0.820240020752 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001ME.jpg
# --- 0.815611839294 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MF.jpg
# --- 0.817146062851 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MG.jpg
# --- 0.809427976608 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MH.jpg
# --- 0.814154863358 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MI.jpg
# --- 0.81937789917 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MJ.jpg
# --- 0.806934118271 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MK.jpg
# --- 0.830358982086 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001ML.jpg
# --- 0.804020881653 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MM.jpg
# --- 0.819373130798 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MN.jpg
# --- 0.8298869133 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MO.jpg
# --- 0.821017980576 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MP.jpg
# --- 0.793390989304 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MQ.jpg
# --- 0.8215508461 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MR.jpg
# --- 0.829778194427 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MS.jpg
# --- 0.815155029297 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MT.jpg
# --- 0.817224979401 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MU.jpg
# --- 0.806890964508 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MV.jpg
# --- 0.815721988678 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MW.jpg
# --- 0.805290222168 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MX.jpg
# --- 0.83278799057 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MY.jpg
# --- 0.814358949661 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001MZ.jpg
# --- 0.804109096527 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N0.jpg
# --- 0.827357053757 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N1.jpg
# --- 0.827442884445 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N2.jpg
# --- 0.827758073807 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N3.jpg
# --- 0.820917129517 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N4.jpg
# --- 0.818278074265 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N5.jpg
# --- 0.813883066177 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N6.jpg
# --- 0.825597047806 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N7.jpg
# --- 0.81946182251 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N8.jpg
# --- 0.830155134201 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001N9.jpg
# --- 0.827069997787 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NA.jpg
# --- 0.807892084122 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NB.jpg
# --- 0.816279888153 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NC.jpg
# --- 0.829087018967 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001ND.jpg
# --- 0.795747995377 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NE.jpg
# --- 0.820717096329 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NF.jpg
# --- 0.827542066574 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NG.jpg
# --- 0.828882932663 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NH.jpg
# --- 0.820663928986 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NI.jpg
# --- 0.834154129028 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NJ.jpg
# --- 0.821519136429 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NK.jpg
# --- 0.816573858261 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NL.jpg
# --- 0.827764034271 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NM.jpg
# --- 0.826888084412 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NN.jpg
# --- 0.82553601265 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NO.jpg
# --- 0.810039997101 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NP.jpg
# --- 0.834434986115 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NQ.jpg
# --- 0.828454971313 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NR.jpg
# --- 0.826381921768 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NS.jpg
# --- 0.81122803688 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NT.jpg
# --- 0.793524026871 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NU.jpg
# --- 0.830223083496 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NV.jpg
# --- 0.813220977783 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NW.jpg
# --- 0.826414108276 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NX.jpg
# --- 0.822700977325 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NY.jpg
# --- 0.816200971603 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001NZ.jpg
# --- 0.82763004303 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O0.jpg
# --- 0.805452823639 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O1.jpg
# --- 0.817521095276 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O2.jpg
# --- 0.819628000259 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O3.jpg
# --- 0.811637163162 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O4.jpg
# --- 0.817385911942 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O5.jpg
# --- 0.827378034592 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O6.jpg
# --- 0.822813987732 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O7.jpg
# --- 0.835724115372 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O8.jpg
# --- 0.816436767578 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001O9.jpg
# --- 0.811232089996 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OA.jpg
# --- 0.79913187027 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OB.jpg
# --- 0.823586940765 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OC.jpg
# --- 0.838535070419 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OD.jpg
# --- 0.823393106461 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OE.jpg
# --- 0.827378988266 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OF.jpg
# --- 0.824981927872 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OG.jpg
# --- 0.811918020248 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OH.jpg
# --- 0.82058095932 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OI.jpg
# --- 0.825421094894 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OJ.jpg
# --- 0.813272953033 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OK.jpg
# --- 0.807851076126 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OL.jpg
# --- 0.838809013367 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OM.jpg
# --- 0.841953039169 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001ON.jpg
# --- 0.824503183365 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OO.jpg
# --- 0.805500030518 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OP.jpg
# --- 0.831915140152 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OQ.jpg
# --- 0.82680606842 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OR.jpg
# --- 0.821539878845 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OS.jpg
# --- 0.817280054092 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OT.jpg
# --- 0.826730966568 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OU.jpg
# --- 0.816432952881 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OV.jpg
# --- 0.815833091736 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OW.jpg
# --- 0.818451881409 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OX.jpg
# --- 0.83850812912 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OY.jpg
# --- 0.818105220795 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001OZ.jpg
# --- 0.817371845245 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P0.jpg
# --- 0.830020904541 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P1.jpg
# --- 0.824573993683 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P2.jpg
# --- 0.826699018478 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P3.jpg
# --- 0.819420099258 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P4.jpg
# --- 0.818445920944 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P5.jpg
# --- 0.805700063705 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P6.jpg
# --- 0.816806077957 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P7.jpg
# --- 0.823727846146 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P8.jpg
# --- 0.81926202774 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001P9.jpg
# --- 0.823360204697 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PA.jpg
# --- 0.800295114517 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PB.jpg
# --- 0.836246967316 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PC.jpg
# --- 0.828985929489 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PD.jpg
# --- 0.834520101547 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PE.jpg
# --- 0.822835922241 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PF.jpg
# --- 0.821416139603 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PG.jpg
# --- 0.823536872864 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PH.jpg
# --- 0.810801029205 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PI.jpg
# --- 0.831677913666 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PJ.jpg
# --- 0.824395179749 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PK.jpg
# --- 0.822194099426 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PL.jpg
# --- 0.81130194664 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PM.jpg
# --- 0.807503938675 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PN.jpg
# --- 0.831150054932 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PO.jpg
# --- 0.81452703476 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PP.jpg
# --- 0.819161891937 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PQ.jpg
# --- 0.844414949417 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PR.jpg
# --- 0.832353830338 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PS.jpg
# --- 0.810927152634 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PT.jpg
# --- 0.800057888031 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PU.jpg
# --- 0.795229196548 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PV.jpg
# --- 0.81973695755 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PW.jpg
# --- 0.821158885956 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PX.jpg
# --- 0.813797950745 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PY.jpg
# --- 0.805451869965 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001PZ.jpg
# --- 0.818504095078 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q0.jpg
# --- 0.807888031006 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q1.jpg
# --- 0.835592985153 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q2.jpg
# --- 0.827247858047 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q3.jpg
# --- 0.81117606163 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q4.jpg
# --- 0.795660018921 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q5.jpg
# --- 0.824631929398 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q6.jpg
# --- 0.819276094437 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q7.jpg
# --- 0.829777956009 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q8.jpg
# --- 0.821810007095 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001Q9.jpg
# --- 0.798444986343 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001QA.jpg
# --- 0.838786840439 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001QB.jpg
# --- 0.832981109619 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001QC.jpg
# --- 0.813638925552 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001QD.jpg
# --- 0.817448139191 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001QE.jpg
# --- 0.831395864487 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001QF.jpg
# --- 0.835260868073 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001QW.jpg
# --- 2.25190496445 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001QZ.jpg
# --- 2.17770504951 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001R7.jpg
# --- 2.03687405586 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001R8.jpg
# --- 1.4669380188 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001RN.jpg
# --- 1.2513449192 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001RO.jpg
# --- 1.38969492912 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001RP.jpg
# --- 1.49546790123 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001RQ.jpg
# --- 2.99891519547 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001RZ.jpg
# --- 2.48560214043 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001S0.jpg
# --- 1.38632917404 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001UV.jpg
# --- 4.54584002495 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00001UW.jpg
# --- 0.773938894272 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000023D.jpg
# --- 2.24340820312 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000023H.jpg
# --- 0.836494922638 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000025I.jpg
# --- 1.47525501251 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000025J.jpg
# --- 1.4445040226 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000026C.jpg
# --- 1.43749403954 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000026G.jpg
# --- 0.956321954727 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000026T.jpg
# --- 1.39820814133 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000026X.jpg
# --- 0.942715883255 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000027A.jpg
# --- 1.74852776527 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000027B.jpg
# --- 0.941534042358 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC0000290.jpg
# --- 1.2468559742 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC0000331.jpg
# --- 1.4377450943 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000034E.jpg
# --- 1.26500105858 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000038M.jpg
# --- 1.13838005066 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000038O.jpg
# --- 1.00116705894 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000038P.jpg
# --- 1.12400889397 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00003A1.jpg
# --- 1.11858987808 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00003OD.jpg
# --- 1.4541349411 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00003PE.jpg
# --- 1.19659399986 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00003PG.jpg
# --- 0.897789955139 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00003QQ.jpg
# --- 1.80311989784 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004H1.jpg
# --- 1.18491196632 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004H3.jpg
# --- 1.43289208412 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004H4.jpg
# --- 2.60416007042 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004H5.jpg
# --- 2.15188598633 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004HQ.jpg
# --- 1.26599979401 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004HT.jpg
# --- 1.38292312622 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004HU.jpg
# --- 1.57976198196 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004HV.jpg
# --- 0.896815061569 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004HW.jpg
# --- 0.922780990601 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004HX.jpg
# --- 0.940889120102 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004HY.jpg
# --- 0.95218205452 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004HZ.jpg
# --- 0.917042016983 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004I0.jpg
# --- 1.62227511406 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004I1.jpg
# --- 0.96706199646 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004I2.jpg
# --- 1.14140820503 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004I3.jpg
# --- 1.11898779869 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004I4.jpg
# --- 0.969321012497 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004I5.jpg
# --- 0.9700050354 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004I6.jpg
# --- 0.971930980682 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004I8.jpg
# --- 1.06779098511 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004KU.jpg
# --- 0.955175161362 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004RT.jpg
# --- 2.04670715332 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VO.jpg
# --- 1.39419603348 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VP.jpg
# --- 0.803804159164 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VQ.jpg
# --- 0.806512832642 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VR.jpg
# --- 0.816841125488 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VS.jpg
# --- 0.820550918579 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VT.jpg
# --- 0.821218013763 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VU.jpg
# --- 0.820426940918 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VV.jpg
# --- 0.811272859573 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VW.jpg
# --- 0.810127019882 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VX.jpg
# --- 0.799759149551 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VY.jpg
# --- 0.818833827972 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004VZ.jpg
# --- 0.809322118759 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004W0.jpg
# --- 0.783850908279 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004W5.jpg
# --- 0.990764856339 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004W6.jpg
# --- 0.967656135559 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004W7.jpg
# --- 0.976927995682 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004WM.jpg
# --- 0.966459989548 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004XA.jpg
# --- 0.991190910339 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004XB.jpg
# --- 0.958765983582 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004XC.jpg
# --- 0.981258869171 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00004XD.jpg
# --- 0.967689990997 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC0000517.jpg
# --- 1.13087391853 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000051M.jpg
# --- 1.53414797783 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00005AO.jpg
# --- 1.18817710876 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00005I1.jpg
# --- 1.1220741272 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00005P8.jpg
# --- 0.969713926315 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00005P9.jpg
# --- 0.963387012482 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00005PG.jpg
# --- 1.74342298508 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00005PY.jpg
# --- 1.04221892357 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00005PZ.jpg
# --- 1.00825190544 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00005Q0.jpg
# --- 1.02343821526 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000063N.jpg
# --- 1.13437199593 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000063O.jpg
# --- 0.923233985901 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000063P.jpg
# --- 0.928780078888 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000063Q.jpg
# --- 0.932926177979 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC0000641.jpg
# --- 1.15684199333 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006CN.jpg
# --- 1.40230298042 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006CO.jpg
# --- 0.928447961807 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006I1.jpg
# --- 0.937970876694 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006I4.jpg
# --- 0.968581199646 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006I5.jpg
# --- 0.998697042465 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006PW.jpg
# --- 1.3164088726 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006TF.jpg
# --- 2.10114502907 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006TG.jpg
# --- 1.55180382729 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006TH.jpg
# --- 1.43374705315 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006TI.jpg
# --- 1.29215502739 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC00006WK.jpg
# --- 1.50915503502 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000085X.jpg
# --- 1.70058488846 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC0000860.jpg
# --- 1.0697081089 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC0000877.jpg
# --- 0.772662162781 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC0000879.jpg
# --- 1.05482506752 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087A.jpg
# --- 1.10259604454 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087B.jpg
# --- 1.84938192368 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087C.jpg
# --- 1.05953192711 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087D.jpg
# --- 1.07925105095 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087E.jpg
# --- 1.09008789062 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087F.jpg
# --- 1.06091594696 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087G.jpg
# --- 1.06424212456 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087H.jpg
# --- 1.05809521675 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087I.jpg
# --- 1.09208893776 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087J.jpg
# --- 1.10400700569 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087K.jpg
# --- 1.11251187325 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/HC000087L.jpg
# --- 1.14387083054 seconds ---
# ...
# --- 0.903072834015 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3P0.jpg
# --- 0.955497026443 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3P1.jpg
# --- 0.973909139633 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QC.jpg
# --- 1.15826296806 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QD.jpg
# --- 1.14073896408 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QE.jpg
# --- 1.22099590302 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QF.jpg
# --- 1.21865701675 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QH.jpg
# --- 1.14671301842 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QI.jpg
# --- 1.12858390808 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QJ.jpg
# --- 0.86000084877 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QK.jpg
# --- 1.22645020485 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QL.jpg
# --- 1.12640714645 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QM.jpg
# --- 0.87832403183 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QN.jpg
# --- 1.14385604858 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QO.jpg
# --- 1.69180798531 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QS.jpg
# --- 0.960954904556 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QT.jpg
# --- 0.941246986389 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QV.jpg
# --- 0.969393014908 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QW.jpg
# --- 1.14127397537 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QX.jpg
# --- 0.957570075989 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3QY.jpg
# --- 0.956259965897 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3SH.jpg
# --- 0.996272087097 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3SI.jpg
# --- 0.87623000145 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3TI.jpg
# --- 1.22045111656 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3TJ.jpg
# --- 1.44047307968 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3TK.jpg
# --- 1.33466887474 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3TL.jpg
# --- 1.33272504807 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3TM.jpg
# --- 1.37900900841 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3U9.jpg
# --- 0.941586017609 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UA.jpg
# --- 0.931293964386 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UB.jpg
# --- 0.949859142303 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UC.jpg
# --- 0.929757118225 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UD.jpg
# --- 0.935655117035 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UE.jpg
# --- 0.91548204422 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UF.jpg
# --- 0.897301197052 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UG.jpg
# --- 0.920512914658 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UH.jpg
# --- 0.926846027374 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UJ.jpg
# --- 0.908936977386 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UK.jpg
# --- 0.919787883759 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UL.jpg
# --- 0.894031047821 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UM.jpg
# --- 0.876317977905 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UN.jpg
# --- 0.866669178009 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UO.jpg
# --- 0.857677221298 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UP.jpg
# --- 0.855484962463 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UQ.jpg
# --- 0.841345071793 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UR.jpg
# --- 0.860524177551 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3US.jpg
# --- 1.07881903648 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3UT.jpg
# --- 0.948441982269 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3V6.jpg
# --- 0.899436950684 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3V7.jpg
# --- 0.924100875854 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3V8.jpg
# --- 0.909858942032 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3X1.jpg
# --- 0.907360076904 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3XC.jpg
# --- 1.07894802094 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y0.jpg
# --- 1.09815001488 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y2.jpg
# --- 0.840168952942 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y3.jpg
# --- 1.19202685356 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y4.jpg
# --- 1.07118296623 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y5.jpg
# --- 1.13779592514 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y6.jpg
# --- 1.32332897186 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y7.jpg
# --- 1.1036028862 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y8.jpg
# --- 1.11031198502 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3Y9.jpg
# --- 1.08694386482 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3YA.jpg
# --- 1.15065288544 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3YB.jpg
# --- 1.05845499039 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3YC.jpg
# --- 1.17173504829 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3YD.jpg
# --- 1.11613202095 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3YE.jpg
# --- 0.938846111298 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3YF.jpg
# --- 1.19382810593 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L3YG.jpg
# --- 1.09199714661 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L457.jpg
# --- 1.44046807289 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L46O.jpg
# --- 0.983125925064 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L46P.jpg
# --- 0.993839979172 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L46Q.jpg
# --- 1.00108790398 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L46R.jpg
# --- 0.996047973633 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L47D.jpg
# --- 0.990668058395 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L47E.jpg
# --- 0.990909099579 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L47F.jpg
# --- 0.933429002762 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L47X.jpg
# --- 1.26397299767 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L47Y.jpg
# --- 1.25976705551 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L47Z.jpg
# --- 0.896540880203 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L480.jpg
# --- 1.06932282448 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L481.jpg
# --- 1.11783695221 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L482.jpg
# --- 1.07222819328 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L483.jpg
# --- 1.12456202507 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L484.jpg
# --- 1.11718893051 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L485.jpg
# --- 1.1331179142 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L486.jpg
# --- 1.10699009895 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L487.jpg
# --- 1.147564888 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L488.jpg
# --- 1.12293505669 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L489.jpg
# --- 1.12064814568 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L48B.jpg
# --- 1.12843990326 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L48C.jpg
# --- 1.12577700615 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L48D.jpg
# --- 1.1181139946 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4AR.jpg
# --- 1.08076405525 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4AS.jpg
# --- 1.0595908165 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4BR.jpg
# --- 1.13496398926 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DI.jpg
# --- 0.945878982544 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DJ.jpg
# --- 0.932330131531 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DK.jpg
# --- 0.940627098083 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DM.jpg
# --- 0.954349994659 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DN.jpg
# --- 0.929323196411 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DO.jpg
# --- 0.947498083115 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DP.jpg
# --- 0.945904970169 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DQ.jpg
# --- 0.939041852951 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DR.jpg
# --- 0.936515808105 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DW.jpg
# --- 0.951861858368 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DX.jpg
# --- 0.946053981781 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DY.jpg
# --- 0.930130958557 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4DZ.jpg
# --- 0.945500850677 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4E0.jpg
# --- 0.925048112869 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4E2.jpg
# --- 0.978560209274 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4E3.jpg
# --- 0.920516014099 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4E4.jpg
# --- 0.937907218933 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4E5.jpg
# --- 0.93488907814 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4E6.jpg
# --- 0.953459978104 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4E7.jpg
# --- 0.956566095352 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EA.jpg
# --- 0.977298021317 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EB.jpg
# --- 0.976202011108 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EC.jpg
# --- 0.985486984253 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4ED.jpg
# --- 0.9681391716 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EE.jpg
# --- 0.955408811569 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EG.jpg
# --- 0.964524030685 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EH.jpg
# --- 1.64573597908 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EI.jpg
# --- 0.928176164627 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EJ.jpg
# --- 0.933214187622 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EM.jpg
# --- 0.954066038132 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4EN.jpg
# --- 0.985864162445 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4FI.jpg
# --- 0.988406896591 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4FJ.jpg
# --- 0.969493865967 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4FK.jpg
# --- 0.992663860321 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4FP.jpg
# --- 0.989003181458 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4FQ.jpg
# --- 1.67066693306 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4FU.jpg
# --- 0.943409919739 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4FV.jpg
# --- 0.937597990036 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4G9.jpg
# --- 0.938741207123 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GA.jpg
# --- 0.937777042389 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GP.jpg
# --- 0.971441030502 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GQ.jpg
# --- 0.948090076447 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GR.jpg
# --- 0.902793884277 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GS.jpg
# --- 0.935535907745 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GT.jpg
# --- 0.950833797455 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GV.jpg
# --- 0.819594144821 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GW.jpg
# --- 0.96448302269 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4GX.jpg
# --- 0.941650152206 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4H0.jpg
# --- 0.826455116272 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4H1.jpg
# --- 0.955266952515 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4H3.jpg
# --- 1.62103295326 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4HT.jpg
# --- 0.950464963913 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4HU.jpg
# --- 1.63782501221 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4I6.jpg
# --- 0.966619968414 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4IF.jpg
# --- 0.948732852936 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4IO.jpg
# --- 0.958791017532 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4JZ.jpg
# --- 0.984781980515 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4K6.jpg
# --- 1.71404790878 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KO.jpg
# --- 1.02994394302 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KP.jpg
# --- 1.01749897003 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KQ.jpg
# --- 1.00370812416 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KR.jpg
# --- 1.02384996414 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KS.jpg
# --- 1.02092313766 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KT.jpg
# --- 1.00141406059 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KU.jpg
# --- 0.995825052261 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KV.jpg
# --- 1.00022602081 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KW.jpg
# --- 1.00781083107 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4KX.jpg
# --- 0.970263004303 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LB.jpg
# --- 1.0046210289 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LC.jpg
# --- 0.973605871201 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LD.jpg
# --- 1.00988817215 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LE.jpg
# --- 1.01420497894 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LF.jpg
# --- 1.01917290688 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LG.jpg
# --- 1.00964689255 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LH.jpg
# --- 0.970580101013 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LI.jpg
# --- 0.982328891754 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LJ.jpg
# --- 0.999479055405 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LK.jpg
# --- 1.01310706139 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LL.jpg
# --- 1.0204398632 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4LM.jpg
# --- 0.992577075958 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4TO.jpg
# --- 1.14450001717 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4UP.jpg
# --- 2.20848608017 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L4VQ.jpg
# --- 0.995754003525 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L500.jpg
# --- 3.33620214462 seconds ---
# /home/brian/facenet-master/datasets/m18/m18/IC001L580.jpg
# --- 1.26257896423 seconds ---

# %%
#print(building_list)
file1= open('building_list.txt','w')
for name in building_list:
    file1.write(name+'\n')
file1.close()

# %%
"""
from glob import glob
import pickle
from collections import defaultdict
flag_dict = defaultdict()
i=0
for image_path in glob('/home/brian/google-images-download/google_images_download/country_flag_s/*/*.jpg'):
#for image_path in glob('/home/brian/facenet-master/datasets/ldc_isi_dryrun/*/*.jpg'):
  image = Image.open(image_path)
  print image_path
  # the array based representation of the image will be used later in order to prepare the
  # result image with boxes and labels on it.
  image_np = load_image_into_numpy_array(image)
  # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
  image_np_expanded = np.expand_dims(image_np, axis=0)
  # Actual detection.
  output_dict = run_inference_for_single_image(image_np, detection_graph)
  # Visualization of the results of a detection.
  #print output_dict['detection_classes']
  if 85 in output_dict['detection_classes']:
      flag_dict[image_path] = output_dict
      
      vis_util.visualize_boxes_and_labels_on_image_array(
          image_np,
          output_dict['detection_boxes'],
          output_dict['detection_classes'],
          output_dict['detection_scores'],
          category_index,
          instance_masks=output_dict.get('detection_masks'),
          use_normalized_coordinates=True,
          line_thickness=8)

      plt.figure(figsize=IMAGE_SIZE)
      plt.imshow(image_np)
      i+=1
      
  #if i==20:
  #  break
  
with open('/home/brian/google-images-download/google_images_download/country_flag_real.pickle', 'wb') as f:
    pickle.dump(flag_dict,f,protocol=pickle.HIGHEST_PROTOCOL)
"""
# Out:
# "\nfrom glob import glob\nimport pickle\nfrom collections import defaultdict\nflag_dict = defaultdict()\ni=0\nfor image_path in glob('/home/brian/google-images-download/google_images_download/country_flag_s/*/*.jpg'):\n#for image_path in glob('/home/brian/facenet-master/datasets/ldc_isi_dryrun/*/*.jpg'):\n  image = Image.open(image_path)\n  print image_path\n  # the array based representation of the image will be used later in order to prepare the\n  # result image with boxes and labels on it.\n  image_np = load_image_into_numpy_array(image)\n  # Expand dimensions since the model expects images to have shape: [1, None, None, 3]\n  image_np_expanded = np.expand_dims(image_np, axis=0)\n  # Actual detection.\n  output_dict = run_inference_for_single_image(image_np, detection_graph)\n  # Visualization of the results of a detection.\n  #print output_dict['detection_classes']\n  if 85 in output_dict['detection_classes']:\n      flag_dict[image_path] = output_dict\n      \n      vis_util.visualize_boxes_and_labels_on_image_array(\n          image_np,\n          output_dict['detection_boxes'],\n          output_dict['detection_classes'],\n          output_dict['detection_scores'],\n          category_index,\n          instance_masks=output_dict.get('detection_masks'),\n          use_normalized_coordinates=True,\n          line_thickness=8)\n\n      plt.figure(figsize=IMAGE_SIZE)\n      plt.imshow(image_np)\n      i+=1\n      \n  #if i==20:\n  #  break\n  \nwith open('/home/brian/google-images-download/google_images_download/country_flag_real.pickle', 'wb') as f:\n    pickle.dump(flag_dict,f,protocol=pickle.HIGHEST_PROTOCOL)\n"

# %%
#print category_index
#for x,y in category_index.items():
#    print x,y

# %%
#for x,y in flag_dict.items():
#    print x,y
#    break

# %%
#import pickle
#with open('/home/brian/google-images-download/google_images_download/country_flag.pickle', 'rb') as handle:
#    OD_result = pickle.load(handle)

# %%
#print len(OD_result)

# %%
#print len(flag_dict)

# %%
#print(building_list)
